# %% [markdown]
# <a href="https://colab.research.google.com/github/VishnuSriraj/Data-Influence/blob/main/DataToDelete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pandas as pd
import scipy
import math

# %%
# A sample torch model with layer attribute
# inps: Number of input features
# hiddens: Number of neurons on each layer, 
#     e.g., [] means no hidden layer, 
#     [128] means one hidden layer with 128 neurons
# bias: Decide if there is a bias on each layer, must be true in the example
# seed: Reproductivity, None means random seed, otherwise specifiy a integer
# hidden_activation: Activation function after each hidden layer

class TorchNNCore(torch.nn.Module):
    def __init__(
        self, inps, hiddens=[], bias=True, seed=None, hidden_activation=torch.nn.ReLU
    ):
        super(TorchNNCore, self).__init__()
        if seed is not None:
            torch.manual_seed(seed)
        struct = [inps] + hiddens + [1]
        self.layers = [] # This layer attribute is required under 
        for i in range(1, len(struct)):
            self.layers.append(
                torch.nn.Linear(
                    in_features=struct[i - 1], out_features=struct[i], bias=bias
                )
            )
            if i == len(struct) - 1:
                self.layers.append(torch.nn.Sigmoid())
            else:
                self.layers.append(hidden_activation())
        self.model = torch.nn.Sequential(*self.layers)

    def forward(self, x):
        output = self.model(x)
        return output

# %%
# Prepare training & testing dataset
data1 = pd.read_csv('./adult.csv').to_numpy()
data2 = pd.read_csv('./broward.csv').to_numpy()
data3 = pd.read_csv('./hospital.csv').to_numpy()

X_train1 = torch.tensor(data1[:,:-1], dtype=torch.float)
y_train1 = torch.tensor(data1[:,-1].reshape(-1,1), dtype=torch.float)

X_train2 = torch.tensor(data2[:,:-1], dtype=torch.float)
y_train2 = torch.tensor(data2[:,-1].reshape(-1,1), dtype=torch.float)

X_train3 = torch.tensor(data3[:,:-1], dtype=torch.float)
y_train3 = torch.tensor(data3[:,-1].reshape(-1,1), dtype=torch.float)

print("\nData1: ",X_train1.shape, y_train1.shape)
print("\nData2: ",X_train2.shape, y_train2.shape)
print("\nData3: ",X_train3.shape, y_train3.shape)
# Out:
# Data1:  torch.Size([45222, 98]) torch.Size([45222, 1])
#
# Data2:  torch.Size([7214, 8]) torch.Size([7214, 1])
#
# Data3:  torch.Size([52778, 124]) torch.Size([52778, 1])

# %%
# Specify loss function, define model and optimizer
loss_func = torch.nn.BCELoss()

model1 = TorchNNCore(inps=X_train1.shape[1], hiddens=[128], hidden_activation=torch.nn.LeakyReLU)
optim1 = torch.optim.Adam(model1.parameters(),lr=0.001)
model2 = TorchNNCore(inps=X_train2.shape[1], hiddens=[128], hidden_activation=torch.nn.LeakyReLU)
optim2 = torch.optim.Adam(model2.parameters(),lr=0.001)
model3 = TorchNNCore(inps=X_train3.shape[1], hiddens=[128], hidden_activation=torch.nn.LeakyReLU)
optim3 = torch.optim.Adam(model3.parameters(),lr=0.001)

# Before using influence function, we show the structure of the model
print(model1)
print(model2)
print(model3)

# And we print the "layer" attribute, which is used to fetch the layers above
print("\nModel 1:")
for item in model1.layers:
    print(item)
print("\nModel 2:")
for item in model2.layers:
    print(item)
print("\nModel 3:")
for item in model3.layers:
    print(item)
# Out:
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=98, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=8, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=124, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=1, bias=True)
#     (3): Sigmoid()
#   )
# )
#
# Model 1:
# Linear(in_features=98, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()
#
# Model 2:
# Linear(in_features=8, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()
#
# Model 3:
# Linear(in_features=124, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()

# %%
sum_influences1 = np.zeros(X_train1.shape[0])
sum_influences2 = np.zeros(X_train2.shape[0])
sum_influences3 = np.zeros(X_train3.shape[0])

# For 10 times averaged result
for i in range(0,10):
  y_train_np1 = y_train1.detach().numpy()
  y_train_np2 = y_train2.detach().numpy()
  y_train_np3 = y_train3.detach().numpy()
  for epoch in range(0,200):
      optim1.zero_grad()
      optim2.zero_grad()
      optim3.zero_grad()
      
      y_pred1 = model1(X_train1)
      y_pred2 = model2(X_train2)
      y_pred3 = model3(X_train3)
      
      loss1 = loss_func(y_pred1, y_train1)
      loss2 = loss_func(y_pred2, y_train2)
      loss3 = loss_func(y_pred3, y_train3)
      
      loss1.backward()
      loss2.backward()
      loss3.backward()

      optim1.step()
      optim2.step()
      optim3.step()
      if epoch%10==0:
          y_pred_np1 = (y_pred1.detach().numpy()) > 0.5
          y_pred_np2 = (y_pred2.detach().numpy()) > 0.5
          y_pred_np3 = (y_pred3.detach().numpy()) > 0.5

          accuracy1 = sum(y_pred_np1 == y_train_np1)/y_train_np1.shape[0]
          accuracy2 = sum(y_pred_np2 == y_train_np2)/y_train_np2.shape[0]
          accuracy3 = sum(y_pred_np3 == y_train_np3)/y_train_np3.shape[0]

          print('\nEpoch = %d, loss1 = %.4f, accuracy=%.4f'%(epoch, loss1.tolist(), accuracy1))
          print('Epoch = %d, loss2 = %.4f, accuracy=%.4f'%(epoch, loss2.tolist(), accuracy2))
          print('Epoch = %d, loss3 = %.4f, accuracy=%.4f'%(epoch, loss3.tolist(), accuracy3))

  optim1.zero_grad()
  optim2.zero_grad()
  optim3.zero_grad()

  from InfluenceFunction import InfluenceFunction

  infl1 = InfluenceFunction(
      model = model1, # Warning: the class will take a snapshot of the model, any further change requires new instance
      X_train = X_train1, # Features, must be torch.Tensor
      y_train = y_train1, # Labels, must be torch.Tensor
      loss_func = loss_func, # In this example, it's BCELoss
      layer_index = -2, # In this example, as shown in the model structure, we use the second last layer 
  )
  infl2 = InfluenceFunction(
      model = model2, # Warning: the class will take a snapshot of the model, any further change requires new instance
      X_train = X_train2, # Features, must be torch.Tensor
      y_train = y_train2, # Labels, must be torch.Tensor
      loss_func = loss_func, # In this example, it's BCELoss
      layer_index = -2, # In this example, as shown in the model structure, we use the second last layer 
  )
  infl3 = InfluenceFunction(
      model = model3, # Warning: the class will take a snapshot of the model, any further change requires new instance
      X_train = X_train3, # Features, must be torch.Tensor
      y_train = y_train3, # Labels, must be torch.Tensor
      loss_func = loss_func, # In this example, it's BCELoss
      layer_index = -2, # In this example, as shown in the model structure, we use the second last layer 
  )

  # Measuring the influence of data by removing records
  influences1 = []
  influences2 = []
  influences3 = []

  for index in range(0, X_train1.shape[0]):
      influences1.append(infl1.influence_remove_single(index))

  for index in range(0, X_train2.shape[0]):
      influences2.append(infl2.influence_remove_single(index))

  for index in range(0, X_train3.shape[0]):
      influences3.append(infl3.influence_remove_single(index))

  # Note: The influence scores depend the current status of the model,
  # even for the same model configuration with different random seed,
  # the model may converge to different point in hyperspace, which will
  # result in different score for the same records.
  # Note2: The absolute value of the influece score is meaningless, but
  # they are comparable with each other.

  sum_influences1 = [sum_influences1[i] + influences1[i] for i in range(len(influences1))]
  sum_influences2 = [sum_influences2[i] + influences2[i] for i in range(len(influences2))]
  sum_influences3 = [sum_influences3[i] + influences3[i] for i in range(len(influences3))]
# Out:
# Epoch = 0, loss1 = 3.3331, accuracy=0.2466
# Epoch = 0, loss2 = 1.9113, accuracy=0.4507
# Epoch = 0, loss3 = 0.7275, accuracy=0.3456
#
# Epoch = 10, loss1 = 3.5739, accuracy=0.7734
# Epoch = 10, loss2 = 0.8434, accuracy=0.5495
# Epoch = 10, loss3 = 0.6549, accuracy=0.6544
#
# Epoch = 20, loss1 = 3.5605, accuracy=0.7734
# Epoch = 20, loss2 = 0.7380, accuracy=0.5549
# Epoch = 20, loss3 = 0.6360, accuracy=0.6544
#
# Epoch = 30, loss1 = 3.5060, accuracy=0.7761
# Epoch = 30, loss2 = 0.6931, accuracy=0.4831
# Epoch = 30, loss3 = 0.6293, accuracy=0.6544
#
# Epoch = 40, loss1 = 3.4929, accuracy=0.7771
# Epoch = 40, loss2 = 0.6379, accuracy=0.6297
# Epoch = 40, loss3 = 0.6215, accuracy=0.6545
#
# Epoch = 50, loss1 = 3.4772, accuracy=0.7768
# Epoch = 50, loss2 = 0.6145, accuracy=0.6654
# Epoch = 50, loss3 = 0.6131, accuracy=0.6565
#
# Epoch = 60, loss1 = 3.4618, accuracy=0.7804
# Epoch = 60, loss2 = 0.6089, accuracy=0.6770
# Epoch = 60, loss3 = 0.6040, accuracy=0.6637
#
# Epoch = 70, loss1 = 3.4462, accuracy=0.7844
# Epoch = 70, loss2 = 0.6075, accuracy=0.6748
# Epoch = 70, loss3 = 0.5956, accuracy=0.6765
#
# Epoch = 80, loss1 = 3.4331, accuracy=0.7856
# Epoch = 80, loss2 = 0.6062, accuracy=0.6805
# Epoch = 80, loss3 = 0.5894, accuracy=0.6822
#
# Epoch = 90, loss1 = 3.4202, accuracy=0.7854
# Epoch = 90, loss2 = 0.6050, accuracy=0.6783
# Epoch = 90, loss3 = 0.5856, accuracy=0.6849
#
# Epoch = 100, loss1 = 3.4013, accuracy=0.7882
# Epoch = 100, loss2 = 0.6041, accuracy=0.6813
# Epoch = 100, loss3 = 0.5833, accuracy=0.6866
#
# Epoch = 110, loss1 = 3.2803, accuracy=0.7915
# Epoch = 110, loss2 = 0.6035, accuracy=0.6797
# Epoch = 110, loss3 = 0.5816, accuracy=0.6877
#
# Epoch = 120, loss1 = 2.7920, accuracy=0.7957
# Epoch = 120, loss2 = 0.6029, accuracy=0.6802
# Epoch = 120, loss3 = 0.5804, accuracy=0.6882
#
# Epoch = 130, loss1 = 3.1786, accuracy=0.8093
# Epoch = 130, loss2 = 0.6024, accuracy=0.6809
# Epoch = 130, loss3 = 0.5791, accuracy=0.6884
#
# Epoch = 140, loss1 = 3.2852, accuracy=0.8141
# Epoch = 140, loss2 = 0.6020, accuracy=0.6801
# Epoch = 140, loss3 = 0.5778, accuracy=0.6892
#
# Epoch = 150, loss1 = 3.2834, accuracy=0.8164
# Epoch = 150, loss2 = 0.6016, accuracy=0.6817
# Epoch = 150, loss3 = 0.5765, accuracy=0.6900
#
# Epoch = 160, loss1 = 3.2424, accuracy=0.8200
# Epoch = 160, loss2 = 0.6012, accuracy=0.6812
# Epoch = 160, loss3 = 0.5750, accuracy=0.6905
#
# Epoch = 170, loss1 = 3.2193, accuracy=0.8223
# Epoch = 170, loss2 = 0.6009, accuracy=0.6799
# Epoch = 170, loss3 = 0.5735, accuracy=0.6914
#
# Epoch = 180, loss1 = 3.1205, accuracy=0.8234
# Epoch = 180, loss2 = 0.6006, accuracy=0.6797
# Epoch = 180, loss3 = 0.5719, accuracy=0.6927
#
# Epoch = 190, loss1 = 0.8543, accuracy=0.8238
# Epoch = 190, loss2 = 0.6003, accuracy=0.6823
# Epoch = 190, loss3 = 0.5702, accuracy=0.6943
#
# Epoch = 0, loss1 = 0.4853, accuracy=0.8185
# Epoch = 0, loss2 = 0.6000, accuracy=0.6826
# Epoch = 0, loss3 = 0.5685, accuracy=0.6958
#
# Epoch = 10, loss1 = 0.5457, accuracy=0.8160
# Epoch = 10, loss2 = 0.5998, accuracy=0.6819
# Epoch = 10, loss3 = 0.5668, accuracy=0.6972
#
# Epoch = 20, loss1 = 0.4016, accuracy=0.8275
# Epoch = 20, loss2 = 0.5995, accuracy=0.6816
# Epoch = 20, loss3 = 0.5652, accuracy=0.6981
#
# Epoch = 30, loss1 = 2.6493, accuracy=0.8182
# Epoch = 30, loss2 = 0.5993, accuracy=0.6809
# Epoch = 30, loss3 = 0.5635, accuracy=0.7000
#
# Epoch = 40, loss1 = 3.3404, accuracy=0.8264
# Epoch = 40, loss2 = 0.5991, accuracy=0.6812
# Epoch = 40, loss3 = 0.5619, accuracy=0.7014
#
# Epoch = 50, loss1 = 3.4175, accuracy=0.8241
# Epoch = 50, loss2 = 0.5989, accuracy=0.6813
# Epoch = 50, loss3 = 0.5604, accuracy=0.7026
#
# Epoch = 60, loss1 = 3.4180, accuracy=0.8280
# Epoch = 60, loss2 = 0.5987, accuracy=0.6821
# Epoch = 60, loss3 = 0.5588, accuracy=0.7043
#
# Epoch = 70, loss1 = 3.4170, accuracy=0.8274
# Epoch = 70, loss2 = 0.5985, accuracy=0.6826
# Epoch = 70, loss3 = 0.5573, accuracy=0.7049
#
# Epoch = 80, loss1 = 3.4156, accuracy=0.8281
# Epoch = 80, loss2 = 0.5983, accuracy=0.6833
# Epoch = 80, loss3 = 0.5559, accuracy=0.7061
#
# Epoch = 90, loss1 = 3.4146, accuracy=0.8286
# Epoch = 90, loss2 = 0.5981, accuracy=0.6835
# Epoch = 90, loss3 = 0.5544, accuracy=0.7069
#
# Epoch = 100, loss1 = 3.4137, accuracy=0.8289
# Epoch = 100, loss2 = 0.5979, accuracy=0.6838
# Epoch = 100, loss3 = 0.5530, accuracy=0.7082
#
# Epoch = 110, loss1 = 3.4128, accuracy=0.8292
# Epoch = 110, loss2 = 0.5977, accuracy=0.6835
# Epoch = 110, loss3 = 0.5516, accuracy=0.7091
#
# Epoch = 120, loss1 = 3.4117, accuracy=0.8291
# Epoch = 120, loss2 = 0.5976, accuracy=0.6838
# Epoch = 120, loss3 = 0.5502, accuracy=0.7099
#
# Epoch = 130, loss1 = 3.4109, accuracy=0.8292
# Epoch = 130, loss2 = 0.5974, accuracy=0.6831
# Epoch = 130, loss3 = 0.5487, accuracy=0.7116
#
# Epoch = 140, loss1 = 3.4101, accuracy=0.8295
# Epoch = 140, loss2 = 0.5972, accuracy=0.6837
# Epoch = 140, loss3 = 0.5473, accuracy=0.7127
#
# Epoch = 150, loss1 = 3.4094, accuracy=0.8298
# Epoch = 150, loss2 = 0.5971, accuracy=0.6842
# Epoch = 150, loss3 = 0.5459, accuracy=0.7148
#
# Epoch = 160, loss1 = 3.4088, accuracy=0.8300
# Epoch = 160, loss2 = 0.5969, accuracy=0.6846
# Epoch = 160, loss3 = 0.5445, accuracy=0.7162
#
# Epoch = 170, loss1 = 3.4081, accuracy=0.8301
# Epoch = 170, loss2 = 0.5967, accuracy=0.6841
# Epoch = 170, loss3 = 0.5431, accuracy=0.7176
#
# Epoch = 180, loss1 = 3.4075, accuracy=0.8305
# Epoch = 180, loss2 = 0.5966, accuracy=0.6833
# Epoch = 180, loss3 = 0.5417, accuracy=0.7185
#
# Epoch = 190, loss1 = 3.4069, accuracy=0.8311
# Epoch = 190, loss2 = 0.5964, accuracy=0.6846
# Epoch = 190, loss3 = 0.5403, accuracy=0.7195
#
# Epoch = 0, loss1 = 3.4064, accuracy=0.8313
# Epoch = 0, loss2 = 0.5963, accuracy=0.6849
# Epoch = 0, loss3 = 0.5389, accuracy=0.7206
#
# Epoch = 10, loss1 = 3.4059, accuracy=0.8316
# Epoch = 10, loss2 = 0.5961, accuracy=0.6856
# Epoch = 10, loss3 = 0.5374, accuracy=0.7220
#
# Epoch = 20, loss1 = 3.4054, accuracy=0.8317
# Epoch = 20, loss2 = 0.5960, accuracy=0.6859
# Epoch = 20, loss3 = 0.5360, accuracy=0.7235
#
# Epoch = 30, loss1 = 3.4050, accuracy=0.8318
# Epoch = 30, loss2 = 0.5959, accuracy=0.6860
# Epoch = 30, loss3 = 0.5345, accuracy=0.7244
#
# Epoch = 40, loss1 = 3.4045, accuracy=0.8321
# Epoch = 40, loss2 = 0.5958, accuracy=0.6862
# Epoch = 40, loss3 = 0.5331, accuracy=0.7256
#
# Epoch = 50, loss1 = 3.4041, accuracy=0.8323
# Epoch = 50, loss2 = 0.5957, accuracy=0.6863
# Epoch = 50, loss3 = 0.5316, accuracy=0.7276
#
# Epoch = 60, loss1 = 3.4037, accuracy=0.8324
# Epoch = 60, loss2 = 0.5956, accuracy=0.6864
# Epoch = 60, loss3 = 0.5302, accuracy=0.7294
#
# Epoch = 70, loss1 = 3.4034, accuracy=0.8326
# Epoch = 70, loss2 = 0.5955, accuracy=0.6871
# Epoch = 70, loss3 = 0.5287, accuracy=0.7303
#
# Epoch = 80, loss1 = 3.4030, accuracy=0.8329
# Epoch = 80, loss2 = 0.5953, accuracy=0.6881
# Epoch = 80, loss3 = 0.5273, accuracy=0.7310
#
# Epoch = 90, loss1 = 3.4027, accuracy=0.8329
# Epoch = 90, loss2 = 0.5952, accuracy=0.6877
# Epoch = 90, loss3 = 0.5259, accuracy=0.7321
#
# Epoch = 100, loss1 = 3.4024, accuracy=0.8332
# Epoch = 100, loss2 = 0.5951, accuracy=0.6867
# Epoch = 100, loss3 = 0.5244, accuracy=0.7335
#
# Epoch = 110, loss1 = 3.4021, accuracy=0.8332
# Epoch = 110, loss2 = 0.5950, accuracy=0.6870
# Epoch = 110, loss3 = 0.5230, accuracy=0.7343
#
# Epoch = 120, loss1 = 3.4018, accuracy=0.8331
# Epoch = 120, loss2 = 0.5949, accuracy=0.6869
# Epoch = 120, loss3 = 0.5217, accuracy=0.7354
#
# Epoch = 130, loss1 = 3.4015, accuracy=0.8332
# Epoch = 130, loss2 = 0.5948, accuracy=0.6864
# Epoch = 130, loss3 = 0.5203, accuracy=0.7360
#
# Epoch = 140, loss1 = 3.4013, accuracy=0.8333
# Epoch = 140, loss2 = 0.5948, accuracy=0.6866
# Epoch = 140, loss3 = 0.5189, accuracy=0.7367
#
# Epoch = 150, loss1 = 3.4010, accuracy=0.8334
# Epoch = 150, loss2 = 0.5947, accuracy=0.6862
# Epoch = 150, loss3 = 0.5176, accuracy=0.7377
#
# Epoch = 160, loss1 = 3.4008, accuracy=0.8335
# Epoch = 160, loss2 = 0.5946, accuracy=0.6859
# Epoch = 160, loss3 = 0.5163, accuracy=0.7383
#
# Epoch = 170, loss1 = 3.4006, accuracy=0.8337
# Epoch = 170, loss2 = 0.5945, accuracy=0.6856
# Epoch = 170, loss3 = 0.5150, accuracy=0.7393
#
# Epoch = 180, loss1 = 3.4003, accuracy=0.8338
# Epoch = 180, loss2 = 0.5945, accuracy=0.6856
# Epoch = 180, loss3 = 0.5137, accuracy=0.7405
#
# Epoch = 190, loss1 = 3.4001, accuracy=0.8337
# Epoch = 190, loss2 = 0.5944, accuracy=0.6859
# Epoch = 190, loss3 = 0.5124, accuracy=0.7415
#
# Epoch = 0, loss1 = 3.3999, accuracy=0.8336
# Epoch = 0, loss2 = 0.5944, accuracy=0.6857
# Epoch = 0, loss3 = 0.5112, accuracy=0.7423
#
# Epoch = 10, loss1 = 3.3997, accuracy=0.8337
# Epoch = 10, loss2 = 0.5943, accuracy=0.6860
# Epoch = 10, loss3 = 0.5100, accuracy=0.7431
#
# Epoch = 20, loss1 = 3.3995, accuracy=0.8338
# Epoch = 20, loss2 = 0.5942, accuracy=0.6864
# Epoch = 20, loss3 = 0.5087, accuracy=0.7439
#
# Epoch = 30, loss1 = 3.3994, accuracy=0.8339
# Epoch = 30, loss2 = 0.5942, accuracy=0.6869
# Epoch = 30, loss3 = 0.5075, accuracy=0.7448
#
# Epoch = 40, loss1 = 3.3992, accuracy=0.8339
# Epoch = 40, loss2 = 0.5941, accuracy=0.6867
# Epoch = 40, loss3 = 0.5063, accuracy=0.7457
#
# Epoch = 50, loss1 = 3.3990, accuracy=0.8339
# Epoch = 50, loss2 = 0.5940, accuracy=0.6866
# Epoch = 50, loss3 = 0.5051, accuracy=0.7469
#
# Epoch = 60, loss1 = 3.3989, accuracy=0.8343
# Epoch = 60, loss2 = 0.5940, accuracy=0.6869
# Epoch = 60, loss3 = 0.5039, accuracy=0.7477
#
# Epoch = 70, loss1 = 3.3987, accuracy=0.8342
# Epoch = 70, loss2 = 0.5939, accuracy=0.6863
# Epoch = 70, loss3 = 0.5027, accuracy=0.7487
#
# Epoch = 80, loss1 = 3.3985, accuracy=0.8341
# Epoch = 80, loss2 = 0.5938, accuracy=0.6864
# Epoch = 80, loss3 = 0.5015, accuracy=0.7496
#
# Epoch = 90, loss1 = 3.3984, accuracy=0.8343
# Epoch = 90, loss2 = 0.5938, accuracy=0.6869
# Epoch = 90, loss3 = 0.5004, accuracy=0.7506
#
# Epoch = 100, loss1 = 3.3982, accuracy=0.8344
# Epoch = 100, loss2 = 0.5937, accuracy=0.6867
# Epoch = 100, loss3 = 0.4992, accuracy=0.7512
#
# Epoch = 110, loss1 = 3.3980, accuracy=0.8346
# Epoch = 110, loss2 = 0.5936, accuracy=0.6866
# Epoch = 110, loss3 = 0.4981, accuracy=0.7526
#
# Epoch = 120, loss1 = 3.3979, accuracy=0.8347
# Epoch = 120, loss2 = 0.5935, accuracy=0.6867
# Epoch = 120, loss3 = 0.4969, accuracy=0.7528
#
# Epoch = 130, loss1 = 3.3978, accuracy=0.8348
# Epoch = 130, loss2 = 0.5935, accuracy=0.6869
# Epoch = 130, loss3 = 0.4958, accuracy=0.7535
#
# Epoch = 140, loss1 = 3.3976, accuracy=0.8347
# Epoch = 140, loss2 = 0.5934, accuracy=0.6866
# Epoch = 140, loss3 = 0.4947, accuracy=0.7543
#
# Epoch = 150, loss1 = 3.3975, accuracy=0.8345
# Epoch = 150, loss2 = 0.5933, accuracy=0.6870
# Epoch = 150, loss3 = 0.4935, accuracy=0.7550
#
# Epoch = 160, loss1 = 3.3974, accuracy=0.8347
# Epoch = 160, loss2 = 0.5933, accuracy=0.6867
# Epoch = 160, loss3 = 0.4925, accuracy=0.7552
#
# Epoch = 170, loss1 = 3.3973, accuracy=0.8348
# Epoch = 170, loss2 = 0.5932, accuracy=0.6871
# Epoch = 170, loss3 = 0.4914, accuracy=0.7559
#
# Epoch = 180, loss1 = 3.3971, accuracy=0.8347
# Epoch = 180, loss2 = 0.5931, accuracy=0.6869
# Epoch = 180, loss3 = 0.4903, accuracy=0.7568
#
# Epoch = 190, loss1 = 3.3970, accuracy=0.8347
# Epoch = 190, loss2 = 0.5931, accuracy=0.6871
# Epoch = 190, loss3 = 0.4893, accuracy=0.7575
#
# Epoch = 0, loss1 = 3.3969, accuracy=0.8347
# Epoch = 0, loss2 = 0.5930, accuracy=0.6873
# Epoch = 0, loss3 = 0.4882, accuracy=0.7578
#
# Epoch = 10, loss1 = 3.3968, accuracy=0.8349
# Epoch = 10, loss2 = 0.5930, accuracy=0.6874
# Epoch = 10, loss3 = 0.4872, accuracy=0.7588
#
# Epoch = 20, loss1 = 3.3967, accuracy=0.8349
# Epoch = 20, loss2 = 0.5929, accuracy=0.6874
# Epoch = 20, loss3 = 0.4862, accuracy=0.7594
#
# Epoch = 30, loss1 = 3.3966, accuracy=0.8349
# Epoch = 30, loss2 = 0.5928, accuracy=0.6876
# Epoch = 30, loss3 = 0.4852, accuracy=0.7598
#
# Epoch = 40, loss1 = 3.3963, accuracy=0.8351
# Epoch = 40, loss2 = 0.5928, accuracy=0.6878
# Epoch = 40, loss3 = 0.4842, accuracy=0.7603
#
# Epoch = 50, loss1 = 3.3962, accuracy=0.8353
# Epoch = 50, loss2 = 0.5927, accuracy=0.6884
# Epoch = 50, loss3 = 0.4831, accuracy=0.7610
#
# Epoch = 60, loss1 = 3.3961, accuracy=0.8353
# Epoch = 60, loss2 = 0.5926, accuracy=0.6885
# Epoch = 60, loss3 = 0.4822, accuracy=0.7619
#
# Epoch = 70, loss1 = 3.3960, accuracy=0.8355
# Epoch = 70, loss2 = 0.5926, accuracy=0.6887
# Epoch = 70, loss3 = 0.4812, accuracy=0.7629
#
# Epoch = 80, loss1 = 3.3959, accuracy=0.8355
# Epoch = 80, loss2 = 0.5925, accuracy=0.6887
# Epoch = 80, loss3 = 0.4802, accuracy=0.7637
#
# Epoch = 90, loss1 = 3.3958, accuracy=0.8356
# Epoch = 90, loss2 = 0.5924, accuracy=0.6896
# Epoch = 90, loss3 = 0.4793, accuracy=0.7643
#
# Epoch = 100, loss1 = 3.3957, accuracy=0.8357
# Epoch = 100, loss2 = 0.5923, accuracy=0.6896
# Epoch = 100, loss3 = 0.4783, accuracy=0.7656
#
# Epoch = 110, loss1 = 3.3956, accuracy=0.8357
# Epoch = 110, loss2 = 0.5923, accuracy=0.6896
# Epoch = 110, loss3 = 0.4774, accuracy=0.7657
#
# Epoch = 120, loss1 = 3.3955, accuracy=0.8357
# Epoch = 120, loss2 = 0.5922, accuracy=0.6894
# Epoch = 120, loss3 = 0.4764, accuracy=0.7667
#
# Epoch = 130, loss1 = 3.3954, accuracy=0.8358
# Epoch = 130, loss2 = 0.5921, accuracy=0.6898
# Epoch = 130, loss3 = 0.4755, accuracy=0.7673
#
# Epoch = 140, loss1 = 3.3953, accuracy=0.8358
# Epoch = 140, loss2 = 0.5921, accuracy=0.6899
# Epoch = 140, loss3 = 0.4745, accuracy=0.7677
#
# Epoch = 150, loss1 = 3.3953, accuracy=0.8357
# Epoch = 150, loss2 = 0.5920, accuracy=0.6898
# Epoch = 150, loss3 = 0.4736, accuracy=0.7680
#
# Epoch = 160, loss1 = 3.3952, accuracy=0.8358
# Epoch = 160, loss2 = 0.5920, accuracy=0.6896
# Epoch = 160, loss3 = 0.4727, accuracy=0.7681
#
# Epoch = 170, loss1 = 3.3951, accuracy=0.8359
# Epoch = 170, loss2 = 0.5919, accuracy=0.6895
# Epoch = 170, loss3 = 0.4717, accuracy=0.7690
#
# Epoch = 180, loss1 = 3.3950, accuracy=0.8359
# Epoch = 180, loss2 = 0.5918, accuracy=0.6891
# Epoch = 180, loss3 = 0.4708, accuracy=0.7695
#
# Epoch = 190, loss1 = 3.3949, accuracy=0.8360
# Epoch = 190, loss2 = 0.5918, accuracy=0.6895
# Epoch = 190, loss3 = 0.4700, accuracy=0.7699
#
# Epoch = 0, loss1 = 3.3948, accuracy=0.8360
# Epoch = 0, loss2 = 0.5917, accuracy=0.6889
# Epoch = 0, loss3 = 0.4690, accuracy=0.7707
#
# Epoch = 10, loss1 = 3.3948, accuracy=0.8359
# Epoch = 10, loss2 = 0.5916, accuracy=0.6894
# Epoch = 10, loss3 = 0.4681, accuracy=0.7711
#
# Epoch = 20, loss1 = 3.3928, accuracy=0.8358
# Epoch = 20, loss2 = 0.5916, accuracy=0.6892
# Epoch = 20, loss3 = 0.4673, accuracy=0.7720
#
# Epoch = 30, loss1 = 3.3928, accuracy=0.8359
# Epoch = 30, loss2 = 0.5915, accuracy=0.6894
# Epoch = 30, loss3 = 0.4664, accuracy=0.7723
#
# Epoch = 40, loss1 = 3.3927, accuracy=0.8358
# Epoch = 40, loss2 = 0.5915, accuracy=0.6895
# Epoch = 40, loss3 = 0.4655, accuracy=0.7723
#
# Epoch = 50, loss1 = 3.3926, accuracy=0.8359
# Epoch = 50, loss2 = 0.5914, accuracy=0.6894
# Epoch = 50, loss3 = 0.4647, accuracy=0.7734
#
# Epoch = 60, loss1 = 3.3925, accuracy=0.8358
# Epoch = 60, loss2 = 0.5914, accuracy=0.6895
# Epoch = 60, loss3 = 0.4638, accuracy=0.7737
#
# Epoch = 70, loss1 = 3.3925, accuracy=0.8359
# Epoch = 70, loss2 = 0.5913, accuracy=0.6888
# Epoch = 70, loss3 = 0.4629, accuracy=0.7746
#
# Epoch = 80, loss1 = 3.3924, accuracy=0.8359
# Epoch = 80, loss2 = 0.5913, accuracy=0.6891
# Epoch = 80, loss3 = 0.4621, accuracy=0.7753
#
# Epoch = 90, loss1 = 3.3923, accuracy=0.8360
# Epoch = 90, loss2 = 0.5912, accuracy=0.6896
# Epoch = 90, loss3 = 0.4613, accuracy=0.7752
#
# Epoch = 100, loss1 = 3.3923, accuracy=0.8361
# Epoch = 100, loss2 = 0.5911, accuracy=0.6896
# Epoch = 100, loss3 = 0.4605, accuracy=0.7762
#
# Epoch = 110, loss1 = 3.3922, accuracy=0.8361
# Epoch = 110, loss2 = 0.5911, accuracy=0.6898
# Epoch = 110, loss3 = 0.4596, accuracy=0.7767
#
# Epoch = 120, loss1 = 3.3921, accuracy=0.8360
# Epoch = 120, loss2 = 0.5910, accuracy=0.6898
# Epoch = 120, loss3 = 0.4589, accuracy=0.7768
#
# Epoch = 130, loss1 = 3.3902, accuracy=0.8360
# Epoch = 130, loss2 = 0.5910, accuracy=0.6899
# Epoch = 130, loss3 = 0.4581, accuracy=0.7775
#
# Epoch = 140, loss1 = 3.3901, accuracy=0.8359
# Epoch = 140, loss2 = 0.5909, accuracy=0.6900
# Epoch = 140, loss3 = 0.4572, accuracy=0.7778
#
# Epoch = 150, loss1 = 3.3900, accuracy=0.8360
# Epoch = 150, loss2 = 0.5909, accuracy=0.6903
# Epoch = 150, loss3 = 0.4565, accuracy=0.7781
#
# Epoch = 160, loss1 = 3.3900, accuracy=0.8359
# Epoch = 160, loss2 = 0.5908, accuracy=0.6899
# Epoch = 160, loss3 = 0.4557, accuracy=0.7786
#
# Epoch = 170, loss1 = 3.3899, accuracy=0.8361
# Epoch = 170, loss2 = 0.5908, accuracy=0.6902
# Epoch = 170, loss3 = 0.4548, accuracy=0.7795
#
# Epoch = 180, loss1 = 3.3898, accuracy=0.8361
# Epoch = 180, loss2 = 0.5907, accuracy=0.6902
# Epoch = 180, loss3 = 0.4541, accuracy=0.7795
#
# Epoch = 190, loss1 = 3.3898, accuracy=0.8360
# Epoch = 190, loss2 = 0.5907, accuracy=0.6902
# Epoch = 190, loss3 = 0.4533, accuracy=0.7802
#
# Epoch = 0, loss1 = 3.3897, accuracy=0.8359
# Epoch = 0, loss2 = 0.5906, accuracy=0.6899
# Epoch = 0, loss3 = 0.4525, accuracy=0.7803
#
# Epoch = 10, loss1 = 3.3896, accuracy=0.8360
# Epoch = 10, loss2 = 0.5906, accuracy=0.6900
# Epoch = 10, loss3 = 0.4518, accuracy=0.7810
#
# Epoch = 20, loss1 = 3.3896, accuracy=0.8361
# Epoch = 20, loss2 = 0.5905, accuracy=0.6900
# Epoch = 20, loss3 = 0.4510, accuracy=0.7810
#
# Epoch = 30, loss1 = 3.3876, accuracy=0.8360
# Epoch = 30, loss2 = 0.5905, accuracy=0.6905
# Epoch = 30, loss3 = 0.4502, accuracy=0.7811
#
# Epoch = 40, loss1 = 3.3876, accuracy=0.8360
# Epoch = 40, loss2 = 0.5904, accuracy=0.6909
# Epoch = 40, loss3 = 0.4495, accuracy=0.7823
#
# Epoch = 50, loss1 = 3.3856, accuracy=0.8360
# Epoch = 50, loss2 = 0.5903, accuracy=0.6912
# Epoch = 50, loss3 = 0.4487, accuracy=0.7823
#
# Epoch = 60, loss1 = 3.3800, accuracy=0.8360
# Epoch = 60, loss2 = 0.5903, accuracy=0.6907
# Epoch = 60, loss3 = 0.4479, accuracy=0.7829
#
# Epoch = 70, loss1 = 3.3762, accuracy=0.8359
# Epoch = 70, loss2 = 0.5902, accuracy=0.6899
# Epoch = 70, loss3 = 0.4473, accuracy=0.7833
#
# Epoch = 80, loss1 = 3.3687, accuracy=0.8360
# Epoch = 80, loss2 = 0.5902, accuracy=0.6907
# Epoch = 80, loss3 = 0.4464, accuracy=0.7836
#
# Epoch = 90, loss1 = 3.3517, accuracy=0.8360
# Epoch = 90, loss2 = 0.5901, accuracy=0.6906
# Epoch = 90, loss3 = 0.4457, accuracy=0.7839
#
# Epoch = 100, loss1 = 3.3233, accuracy=0.8360
# Epoch = 100, loss2 = 0.5900, accuracy=0.6898
# Epoch = 100, loss3 = 0.4450, accuracy=0.7843
#
# Epoch = 110, loss1 = 3.3124, accuracy=0.8361
# Epoch = 110, loss2 = 0.5900, accuracy=0.6896
# Epoch = 110, loss3 = 0.4443, accuracy=0.7848
#
# Epoch = 120, loss1 = 3.3099, accuracy=0.8362
# Epoch = 120, loss2 = 0.5899, accuracy=0.6900
# Epoch = 120, loss3 = 0.4435, accuracy=0.7850
#
# Epoch = 130, loss1 = 3.2917, accuracy=0.8362
# Epoch = 130, loss2 = 0.5898, accuracy=0.6903
# Epoch = 130, loss3 = 0.4430, accuracy=0.7854
#
# Epoch = 140, loss1 = 3.1467, accuracy=0.8362
# Epoch = 140, loss2 = 0.5898, accuracy=0.6900
# Epoch = 140, loss3 = 0.4422, accuracy=0.7861
#
# Epoch = 150, loss1 = 3.0176, accuracy=0.8208
# Epoch = 150, loss2 = 0.5897, accuracy=0.6906
# Epoch = 150, loss3 = 0.4415, accuracy=0.7863
#
# Epoch = 160, loss1 = 3.3032, accuracy=0.8351
# Epoch = 160, loss2 = 0.5897, accuracy=0.6903
# Epoch = 160, loss3 = 0.4409, accuracy=0.7864
#
# Epoch = 170, loss1 = 3.3139, accuracy=0.8337
# Epoch = 170, loss2 = 0.5896, accuracy=0.6900
# Epoch = 170, loss3 = 0.4402, accuracy=0.7872
#
# Epoch = 180, loss1 = 3.3112, accuracy=0.8358
# Epoch = 180, loss2 = 0.5895, accuracy=0.6900
# Epoch = 180, loss3 = 0.4395, accuracy=0.7878
#
# Epoch = 190, loss1 = 3.3103, accuracy=0.8352
# Epoch = 190, loss2 = 0.5895, accuracy=0.6903
# Epoch = 190, loss3 = 0.4389, accuracy=0.7875
#
# Epoch = 0, loss1 = 3.3094, accuracy=0.8355
# Epoch = 0, loss2 = 0.5894, accuracy=0.6892
# Epoch = 0, loss3 = 0.4382, accuracy=0.7886
#
# Epoch = 10, loss1 = 3.3084, accuracy=0.8365
# Epoch = 10, loss2 = 0.5894, accuracy=0.6896
# Epoch = 10, loss3 = 0.4375, accuracy=0.7889
#
# Epoch = 20, loss1 = 3.3075, accuracy=0.8366
# Epoch = 20, loss2 = 0.5893, accuracy=0.6894
# Epoch = 20, loss3 = 0.4369, accuracy=0.7889
#
# Epoch = 30, loss1 = 3.3009, accuracy=0.8366
# Epoch = 30, loss2 = 0.5893, accuracy=0.6896
# Epoch = 30, loss3 = 0.4362, accuracy=0.7896
#
# Epoch = 40, loss1 = 3.2905, accuracy=0.8368
# Epoch = 40, loss2 = 0.5892, accuracy=0.6896
# Epoch = 40, loss3 = 0.4355, accuracy=0.7898
#
# Epoch = 50, loss1 = 3.2685, accuracy=0.8368
# Epoch = 50, loss2 = 0.5891, accuracy=0.6895
# Epoch = 50, loss3 = 0.4350, accuracy=0.7901
#
# Epoch = 60, loss1 = 3.2475, accuracy=0.8369
# Epoch = 60, loss2 = 0.5891, accuracy=0.6895
# Epoch = 60, loss3 = 0.4343, accuracy=0.7906
#
# Epoch = 70, loss1 = 3.1818, accuracy=0.8367
# Epoch = 70, loss2 = 0.5890, accuracy=0.6895
# Epoch = 70, loss3 = 0.4337, accuracy=0.7908
#
# Epoch = 80, loss1 = 3.1321, accuracy=0.8370
# Epoch = 80, loss2 = 0.5890, accuracy=0.6898
# Epoch = 80, loss3 = 0.4331, accuracy=0.7912
#
# Epoch = 90, loss1 = 2.9775, accuracy=0.8376
# Epoch = 90, loss2 = 0.5889, accuracy=0.6898
# Epoch = 90, loss3 = 0.4325, accuracy=0.7921
#
# Epoch = 100, loss1 = 1.0851, accuracy=0.8313
# Epoch = 100, loss2 = 0.5889, accuracy=0.6894
# Epoch = 100, loss3 = 0.4318, accuracy=0.7920
#
# Epoch = 110, loss1 = 3.2976, accuracy=0.8327
# Epoch = 110, loss2 = 0.5888, accuracy=0.6900
# Epoch = 110, loss3 = 0.4314, accuracy=0.7926
#
# Epoch = 120, loss1 = 3.3110, accuracy=0.8357
# Epoch = 120, loss2 = 0.5887, accuracy=0.6899
# Epoch = 120, loss3 = 0.4308, accuracy=0.7931
#
# Epoch = 130, loss1 = 3.3186, accuracy=0.8357
# Epoch = 130, loss2 = 0.5887, accuracy=0.6900
# Epoch = 130, loss3 = 0.4301, accuracy=0.7932
#
# Epoch = 140, loss1 = 3.3193, accuracy=0.8353
# Epoch = 140, loss2 = 0.5886, accuracy=0.6899
# Epoch = 140, loss3 = 0.4296, accuracy=0.7937
#
# Epoch = 150, loss1 = 3.3147, accuracy=0.8369
# Epoch = 150, loss2 = 0.5886, accuracy=0.6894
# Epoch = 150, loss3 = 0.4291, accuracy=0.7944
#
# Epoch = 160, loss1 = 3.3103, accuracy=0.8369
# Epoch = 160, loss2 = 0.5885, accuracy=0.6894
# Epoch = 160, loss3 = 0.4284, accuracy=0.7939
#
# Epoch = 170, loss1 = 3.3094, accuracy=0.8364
# Epoch = 170, loss2 = 0.5884, accuracy=0.6895
# Epoch = 170, loss3 = 0.4279, accuracy=0.7942
#
# Epoch = 180, loss1 = 3.3086, accuracy=0.8367
# Epoch = 180, loss2 = 0.5884, accuracy=0.6895
# Epoch = 180, loss3 = 0.4274, accuracy=0.7951
#
# Epoch = 190, loss1 = 3.3077, accuracy=0.8369
# Epoch = 190, loss2 = 0.5883, accuracy=0.6892
# Epoch = 190, loss3 = 0.4268, accuracy=0.7950
#
# Epoch = 0, loss1 = 3.3069, accuracy=0.8368
# Epoch = 0, loss2 = 0.5883, accuracy=0.6887
# Epoch = 0, loss3 = 0.4262, accuracy=0.7953
#
# Epoch = 10, loss1 = 3.3023, accuracy=0.8367
# Epoch = 10, loss2 = 0.5882, accuracy=0.6891
# Epoch = 10, loss3 = 0.4258, accuracy=0.7963
#
# Epoch = 20, loss1 = 3.2977, accuracy=0.8368
# Epoch = 20, loss2 = 0.5881, accuracy=0.6889
# Epoch = 20, loss3 = 0.4251, accuracy=0.7961
#
# Epoch = 30, loss1 = 3.2855, accuracy=0.8368
# Epoch = 30, loss2 = 0.5881, accuracy=0.6887
# Epoch = 30, loss3 = 0.4246, accuracy=0.7967
#
# Epoch = 40, loss1 = 3.2710, accuracy=0.8369
# Epoch = 40, loss2 = 0.5880, accuracy=0.6891
# Epoch = 40, loss3 = 0.4242, accuracy=0.7975
#
# Epoch = 50, loss1 = 3.2541, accuracy=0.8369
# Epoch = 50, loss2 = 0.5880, accuracy=0.6882
# Epoch = 50, loss3 = 0.4235, accuracy=0.7974
#
# Epoch = 60, loss1 = 3.2364, accuracy=0.8370
# Epoch = 60, loss2 = 0.5879, accuracy=0.6880
# Epoch = 60, loss3 = 0.4230, accuracy=0.7978
#
# Epoch = 70, loss1 = 3.1822, accuracy=0.8372
# Epoch = 70, loss2 = 0.5878, accuracy=0.6885
# Epoch = 70, loss3 = 0.4226, accuracy=0.7985
#
# Epoch = 80, loss1 = 3.1395, accuracy=0.8374
# Epoch = 80, loss2 = 0.5878, accuracy=0.6900
# Epoch = 80, loss3 = 0.4220, accuracy=0.7984
#
# Epoch = 90, loss1 = 3.0486, accuracy=0.8384
# Epoch = 90, loss2 = 0.5877, accuracy=0.6907
# Epoch = 90, loss3 = 0.4214, accuracy=0.7988
#
# Epoch = 100, loss1 = 2.3785, accuracy=0.8402
# Epoch = 100, loss2 = 0.5876, accuracy=0.6899
# Epoch = 100, loss3 = 0.4210, accuracy=0.7996
#
# Epoch = 110, loss1 = 3.0356, accuracy=0.8317
# Epoch = 110, loss2 = 0.5875, accuracy=0.6899
# Epoch = 110, loss3 = 0.4205, accuracy=0.7996
#
# Epoch = 120, loss1 = 3.2211, accuracy=0.8355
# Epoch = 120, loss2 = 0.5875, accuracy=0.6899
# Epoch = 120, loss3 = 0.4199, accuracy=0.7999
#
# Epoch = 130, loss1 = 3.2447, accuracy=0.8357
# Epoch = 130, loss2 = 0.5874, accuracy=0.6898
# Epoch = 130, loss3 = 0.4195, accuracy=0.8005
#
# Epoch = 140, loss1 = 3.2383, accuracy=0.8362
# Epoch = 140, loss2 = 0.5873, accuracy=0.6899
# Epoch = 140, loss3 = 0.4190, accuracy=0.8007
#
# Epoch = 150, loss1 = 3.2128, accuracy=0.8370
# Epoch = 150, loss2 = 0.5873, accuracy=0.6899
# Epoch = 150, loss3 = 0.4184, accuracy=0.8013
#
# Epoch = 160, loss1 = 3.1638, accuracy=0.8374
# Epoch = 160, loss2 = 0.5872, accuracy=0.6899
# Epoch = 160, loss3 = 0.4180, accuracy=0.8016
#
# Epoch = 170, loss1 = 3.1214, accuracy=0.8378
# Epoch = 170, loss2 = 0.5872, accuracy=0.6903
# Epoch = 170, loss3 = 0.4175, accuracy=0.8018
#
# Epoch = 180, loss1 = 3.0430, accuracy=0.8383
# Epoch = 180, loss2 = 0.5871, accuracy=0.6898
# Epoch = 180, loss3 = 0.4170, accuracy=0.8021
#
# Epoch = 190, loss1 = 2.6804, accuracy=0.8400
# Epoch = 190, loss2 = 0.5871, accuracy=0.6900
# Epoch = 190, loss3 = 0.4165, accuracy=0.8025
#
# Epoch = 0, loss1 = 0.4329, accuracy=0.8511
# Epoch = 0, loss2 = 0.5870, accuracy=0.6900
# Epoch = 0, loss3 = 0.4161, accuracy=0.8027
#
# Epoch = 10, loss1 = 0.5255, accuracy=0.8521
# Epoch = 10, loss2 = 0.5869, accuracy=0.6905
# Epoch = 10, loss3 = 0.4156, accuracy=0.8032
#
# Epoch = 20, loss1 = 0.3917, accuracy=0.8514
# Epoch = 20, loss2 = 0.5869, accuracy=0.6900
# Epoch = 20, loss3 = 0.4151, accuracy=0.8031
#
# Epoch = 30, loss1 = 0.3829, accuracy=0.8550
# Epoch = 30, loss2 = 0.5868, accuracy=0.6899
# Epoch = 30, loss3 = 0.4147, accuracy=0.8046
#
# Epoch = 40, loss1 = 0.3748, accuracy=0.8575
# Epoch = 40, loss2 = 0.5868, accuracy=0.6896
# Epoch = 40, loss3 = 0.4142, accuracy=0.8036
#
# Epoch = 50, loss1 = 0.3728, accuracy=0.8562
# Epoch = 50, loss2 = 0.5867, accuracy=0.6898
# Epoch = 50, loss3 = 0.4137, accuracy=0.8041
#
# Epoch = 60, loss1 = 0.3676, accuracy=0.8573
# Epoch = 60, loss2 = 0.5867, accuracy=0.6903
# Epoch = 60, loss3 = 0.4133, accuracy=0.8047
#
# Epoch = 70, loss1 = 0.3647, accuracy=0.8570
# Epoch = 70, loss2 = 0.5866, accuracy=0.6899
# Epoch = 70, loss3 = 0.4128, accuracy=0.8046
#
# Epoch = 80, loss1 = 0.3622, accuracy=0.8569
# Epoch = 80, loss2 = 0.5865, accuracy=0.6903
# Epoch = 80, loss3 = 0.4123, accuracy=0.8047
#
# Epoch = 90, loss1 = 0.3598, accuracy=0.8571
# Epoch = 90, loss2 = 0.5865, accuracy=0.6903
# Epoch = 90, loss3 = 0.4120, accuracy=0.8054
#
# Epoch = 100, loss1 = 0.3575, accuracy=0.8571
# Epoch = 100, loss2 = 0.5864, accuracy=0.6909
# Epoch = 100, loss3 = 0.4115, accuracy=0.8052
#
# Epoch = 110, loss1 = 0.3479, accuracy=0.8572
# Epoch = 110, loss2 = 0.5863, accuracy=0.6921
# Epoch = 110, loss3 = 0.4110, accuracy=0.8057
#
# Epoch = 120, loss1 = 0.3440, accuracy=0.8572
# Epoch = 120, loss2 = 0.5863, accuracy=0.6928
# Epoch = 120, loss3 = 0.4107, accuracy=0.8065
#
# Epoch = 130, loss1 = 0.3382, accuracy=0.8572
# Epoch = 130, loss2 = 0.5862, accuracy=0.6927
# Epoch = 130, loss3 = 0.4103, accuracy=0.8060
#
# Epoch = 140, loss1 = 0.3363, accuracy=0.8572
# Epoch = 140, loss2 = 0.5861, accuracy=0.6937
# Epoch = 140, loss3 = 0.4097, accuracy=0.8065
#
# Epoch = 150, loss1 = 0.3344, accuracy=0.8575
# Epoch = 150, loss2 = 0.5860, accuracy=0.6923
# Epoch = 150, loss3 = 0.4093, accuracy=0.8070
#
# Epoch = 160, loss1 = 0.3327, accuracy=0.8575
# Epoch = 160, loss2 = 0.5860, accuracy=0.6924
# Epoch = 160, loss3 = 0.4090, accuracy=0.8073
#
# Epoch = 170, loss1 = 0.3311, accuracy=0.8577
# Epoch = 170, loss2 = 0.5859, accuracy=0.6914
# Epoch = 170, loss3 = 0.4084, accuracy=0.8073
#
# Epoch = 180, loss1 = 0.3296, accuracy=0.8578
# Epoch = 180, loss2 = 0.5858, accuracy=0.6923
# Epoch = 180, loss3 = 0.4080, accuracy=0.8075
#
# Epoch = 190, loss1 = 0.3282, accuracy=0.8580
# Epoch = 190, loss2 = 0.5858, accuracy=0.6928
# Epoch = 190, loss3 = 0.4077, accuracy=0.8076

# %%
avg_influences1 = [val / 10 for val in sum_influences1]
avg_influences2 = [val / 10 for val in sum_influences2]
avg_influences3 = [val / 10 for val in sum_influences3]

# %%
# Converting the influence scores to absolute values
avg_influences1 = [abs(number) for number in avg_influences1]
avg_influences2 = [abs(number) for number in avg_influences2]
avg_influences3 = [abs(number) for number in avg_influences3]

# %%
avg_influences1
# Out:
# [0.021516909718732685,
#  0.3756625381141868,
#  3.0396977785765866,
#  0.0019505382192298068,
#  0.043563691566087845,
#  12.158091268883183,
#  0.005066887379295476,
#  0.17904857421523993,
#  0.005417241335956715,
#  2.918929776649961,
#  0.015607010479438813,
#  13.071861846579656,
#  0.13823279094706986,
#  0.006942787270344931,
#  0.4493900029920872,
#  0.020281575890839294,
#  0.44509991485881545,
#  0.021948961806303454,
#  0.12120779887425062,
#  0.5020084230483718,
#  0.012049622586393225,
#  0.011680856118083225,
#  0.009719983175509985,
#  0.08532473582928554,
#  0.3102019273821631,
#  0.0006840446855823989,
#  0.03976948322878706,
#  0.11206908511419082,
#  0.6097854827233765,
#  0.0410966526056171,
#  0.008318236854259331,
#  0.013695695255371737,
#  0.03198833751367991,
#  0.021402013341920843,
#  0.6123245906151342,
#  1.0032497356006727,
#  0.11391371007337563,
#  0.20930024166381775,
#  0.012635193746612367,
#  1.2458006177210041,
#  0.04208466725635782,
#  3.6330066823070473,
#  0.023243437975174232,
#  0.051732421247932,
#  0.0013071126033960686,
#  0.038105881151036636,
#  0.781928508115881,
#  1.3844501335280442e-06,
#  0.2660086880247118,
#  0.013281484403762206,
#  0.30628072976587445,
#  8.476234270460203,
#  0.027754732108009123,
#  0.532327040200183,
#  0.10866427542608428,
#  0.04321939355017822,
#  0.14354225344087052,
#  0.02476644200534561,
#  0.05942617753594841,
#  0.0,
#  0.0022548231107858813,
#  0.0009783535118667828,
#  0.7594697089754611,
#  0.0,
#  1.0322255732354129,
#  0.12242717849484838,
#  0.011455776163106099,
#  0.9416576984610254,
#  0.4695682269675753,
#  1.236597381895646,
#  0.09814746072322117,
#  0.003241590451457453,
#  0.1606924534464345,
#  0.10387529438108467,
#  1.8442532562408567,
#  0.09669201905180533,
#  0.011571502134054296,
#  0.008514719082119416,
#  0.02568034458126279,
#  0.01605943074966076,
#  0.003529697663739141,
#  0.02534094832183221,
#  0.025702468364021947,
#  0.05342510964523366,
#  0.016574883349242793,
#  0.024101622346787442,
#  0.027318964517185896,
#  0.02964989976570375,
#  0.01507304491348246,
#  0.0245611690035533,
#  0.02191592907657687,
#  0.01131356120827676,
#  0.024635930485904883,
#  0.0013692047730849198,
#  0.04924997779490077,
#  0.02034792181939138,
#  0.0323369393009255,
#  0.027292427362926162,
#  0.020620104154699843,
#  0.02338382324993518,
#  0.024117323833333575,
#  0.001867533530490123,
#  0.05964319453730953,
#  0.08527424651449592,
#  0.0339060225084178,
#  0.08071530001023455,
#  0.029909772078199958,
#  0.08630342932652049,
#  0.13648212786434202,
#  0.004053778388676851,
#  0.08772093536582234,
#  0.2143292654095756,
#  0.07736615714517102,
#  0.04933951050541574,
#  0.05591034074753606,
#  0.08289147259924631,
#  0.014390578997894995,
#  0.18916977059412413,
#  0.0961598722853892,
#  0.08103356218726859,
#  0.16174460669726648,
#  0.016952365922715824,
#  0.030288935072638874,
#  0.06554805941727171,
#  0.08308642816705906,
#  0.012599510567112091,
#  0.13028771167714004,
#  0.08380234391512312,
#  0.045413572735726646,
#  0.1432391385651025,
#  0.03149053113512296,
#  0.009577958920178434,
#  0.17544277183567702,
#  0.041198527945883565,
#  0.07576086499499504,
#  0.10694769570248223,
#  0.048105978535528726,
#  0.11128144086679989,
#  0.05820169923363688,
#  0.1976573293758252,
#  0.08515415169087275,
#  0.06404679277302149,
#  0.07185795762539107,
#  0.027583186482728672,
#  0.008728720118113922,
#  0.2853285732927323,
#  0.08996417655223336,
#  0.048169961450791776,
#  0.022692244691908385,
#  0.09473271667324876,
#  0.026519917486087757,
#  0.01457866367078372,
#  0.00032115820676315645,
#  0.025449004319726444,
#  0.04014031471535467,
#  0.047004139325286104,
#  0.07568492905103438,
#  0.32405924190133284,
#  0.11253959795375115,
#  0.07054168018355958,
#  ...]

# %%
# Implement Mean
def mn(data):
  mn = sum(data) / len(data)
  return mn

# Implementation of Variance
def variance(data):
  mean = mn(data)
  return sum((x - mean) ** 2 for x in data) / len(data)

# Implementation of Standard Deviation
def stdev(data):
  var = variance(data)
  std_dev = math.sqrt(var)
  return std_dev

# Count values under a certain threshold
def count_of_vals_under(num, infl):
  count = 0
  for i in infl:
    if i <= num:
      count += 1
  return count

# %%
# Analysing the data and printing the number of data below the certain influence scores
print("\nData1(Adult):")
print("Total number of values in Data 1:",X_train1.shape[0])
print("Standard Deviation of Data 1:",stdev(avg_influences1))
print("Mean of Data 1:", mn(avg_influences1))
print("Number of values under influence score of 1:",count_of_vals_under(1, avg_influences1))
print("Number of values under influence score of 0.5:",count_of_vals_under(0.5, avg_influences1))
print("Number of values under influence score of 0.1:",count_of_vals_under(0.1, avg_influences1))
print("Number of values under influence score of 0.05:",count_of_vals_under(0.05, avg_influences1))
print("Number of values under influence score of 0.01:",count_of_vals_under(0.01, avg_influences1))
print("Number of values with an influence score of 0:",count_of_vals_under(0, avg_influences1))

print("\nData2(Broward):")
print("Total number of values in Data 2:",X_train2.shape[0])
print("Standard Deviation of Data 2:",stdev(avg_influences2))
print("Mean of Data 2:", mn(avg_influences2))
print("Number of values under influence score of 1:",count_of_vals_under(1, avg_influences2))
print("Number of values under influence score of 0.5:",count_of_vals_under(0.5, avg_influences2))
print("Number of values under influence score of 0.1:",count_of_vals_under(0.1, avg_influences2))
print("Number of values under influence score of 0.05:",count_of_vals_under(0.05, avg_influences2))
print("Number of values under influence score of 0.01:",count_of_vals_under(0.01, avg_influences2))
print("Number of values under influence score of 0:",count_of_vals_under(0, avg_influences2))

print("\nData3(Hospital):")
print("Total number of values in Data 3:",X_train3.shape[0])
print("Standard Deviation of Data 3:",stdev(avg_influences3))
print("Mean of Data 3:", mn(avg_influences3))
print("Number of values under influence score of 1:",count_of_vals_under(1, avg_influences3))
print("Number of values under influence score of 0.5:",count_of_vals_under(0.5, avg_influences3))
print("Number of values under influence score of 0.1:",count_of_vals_under(0.1, avg_influences3))
print("Number of values under influence score of 0.05:",count_of_vals_under(0.05, avg_influences3))
print("Number of values under influence score of 0.01:",count_of_vals_under(0.01, avg_influences3))
print("Number of values with an influence score of 0:",count_of_vals_under(0, avg_influences3))
# Out:
# Data1(Adult):
# Total number of values in Data 1: 45222
# Standard Deviation of Data 1: 190.426797092564
# Mean of Data 1: 6.238587768209289
# Number of values under influence score of 1: 38106
# Number of values under influence score of 0.5: 32866
# Number of values under influence score of 0.1: 20411
# Number of values under influence score of 0.05: 15577
# Number of values under influence score of 0.01: 5830
# Number of values with an influence score of 0: 888
#
# Data2(Broward):
# Total number of values in Data 2: 7214
# Standard Deviation of Data 2: 0.06389953918766562
# Mean of Data 2: 0.040791887901062286
# Number of values under influence score of 1: 7210
# Number of values under influence score of 0.5: 7205
# Number of values under influence score of 0.1: 6680
# Number of values under influence score of 0.05: 5383
# Number of values under influence score of 0.01: 1452
# Number of values under influence score of 0: 0
#
# Data3(Hospital):
# Total number of values in Data 3: 52778
# Standard Deviation of Data 3: 0.05281212796238276
# Mean of Data 3: 0.04943694085584812
# Number of values under influence score of 1: 52776
# Number of values under influence score of 0.5: 52740
# Number of values under influence score of 0.1: 46355
# Number of values under influence score of 0.05: 34722
# Number of values under influence score of 0.01: 7100
# Number of values with an influence score of 0: 0

# %%
# Changing the influence scores below 0.01 in the data to False(data to be deleted)

def data_to_be_deleted(infl, threshold):
  for idx, val in enumerate(infl):
    if val <= threshold:
        infl[idx] = False
    else:
        infl[idx] = True

data_to_be_deleted(avg_influences1, 0.01)
data_to_be_deleted(avg_influences2, 0.01)
data_to_be_deleted(avg_influences3, 0.01)

# %%
# Verifying the data set to False
def verify(infl):
  count = 0
  for i in infl:
    if i == False:
      count += 1
  return count

print("\nTotal number of values to be deleted in data 1:",verify(avg_influences1))
print("\nTotal number of values to be deleted in data 2:",verify(avg_influences2))
print("\nTotal number of values to be deleted in data 3:",verify(avg_influences3))
# Out:
# Total number of values to be deleted in data 1: 5830
#
# Total number of values to be deleted in data 2: 1452
#
# Total number of values to be deleted in data 3: 7100
