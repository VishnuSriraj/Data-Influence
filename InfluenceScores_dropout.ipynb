# %% [markdown]
# <a href="https://colab.research.google.com/github/VishnuSriraj/Data-Influence/blob/main/InfluenceScores_dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pandas as pd
import scipy
import math
import copy
from torch.autograd import grad as gradient

# %%
class InfluenceFunction(object):
	def __init__(self, model, X_train, y_train, loss_func, layer_index):
		if not isinstance(model, torch.nn.Module):
			raise RuntimeError(f"Only torch.nn.Module models are supported, got f{type(model)}")
		if not isinstance(X_train, torch.Tensor):
			raise RuntimeError(f"X_train must be <torch.Tensor>, got f{type(X_train)}")
		if not isinstance(y_train, torch.Tensor):
			raise RuntimeError(f"y_train must be <torch.Tensor>, got f{type(y_train)}")

		try:
			layers = model.layers
		except:
			raise RuntimeError('The model must have an attribute "layers".')

		self._model = copy.deepcopy(model)
		self._X_train = X_train
		self._y_train = y_train
		self._loss_func = loss_func
		self._layer_index = layer_index
		
		self._total_training_loss_grad = None
		self._Hessian_matrix = self._calculate_Hessian_matrix()
		self._Hessian_inv = np.linalg.inv(self._Hessian_matrix)
		

	def _calculate_Hessian_matrix(self):

		X_train = self._X_train
		y_train = self._y_train
		model = self._model

		y_pred = model(X_train)
		loss = self._loss_func(y_pred, y_train)
		layer = model.layers[self._layer_index]

		if not isinstance(layer, torch.nn.Linear):
			raise RuntimeError(
				f"Only support layer type torch.nn.Linear, got f{type(layer)}."
			)

		weights = model.layers[self._layer_index].weight
		bias = model.layers[self._layer_index].bias

		grad_L_w_1 = gradient(
			loss, (weights, bias), retain_graph=True, create_graph=True
		)
		self._total_training_loss_grad = np.array(
			grad_L_w_1[0][0].tolist() + grad_L_w_1[1].tolist()
		)

		Hessian = []
		for i in range(0, grad_L_w_1[0].shape[1]):
			grad_L_w_2 = gradient(
				grad_L_w_1[0][0][i], (weights, bias), retain_graph=True
			)
			Hessian.append(grad_L_w_2[0][0].tolist() + grad_L_w_2[1].tolist())
		grad_L_w_2 = gradient(grad_L_w_1[1][0], (weights, bias), retain_graph=True)
		Hessian.append(grad_L_w_2[0][0].tolist() + grad_L_w_2[1].tolist())

		return np.array(Hessian)

	def influence_remove_single(self, index):
		return -self.influence_add_single(self._X_train[index], self._y_train[index])

	def influence_modify_single(self, index, new_x, new_y):
		return self.influence_add_single(new_x, new_y) + self.influence_remove_single(index)

	def influence_add_single(self, x, y):

		if not isinstance(x, torch.Tensor):
			raise RuntimeError(f"Added x must be <torch.Tensor>, got f{type(x)}")
		if not isinstance(y, torch.Tensor):
			raise RuntimeError(f"Added y must be <torch.Tensor>, got f{type(y)}")

		x = x.reshape(1, -1).detach()
		y = y.reshape(1, -1).detach()

		model = self._model

		y_pred = model(x)
		loss_single = self._loss_func(y_pred, y)

		weights = model.layers[self._layer_index].weight
		bias = model.layers[self._layer_index].bias

		grad = gradient(loss_single, (weights, bias), retain_graph=True)
		grad = np.array(grad[0][0].tolist() + grad[1].tolist())

		param_offset = - np.dot(self._Hessian_inv, grad)

		influence = np.dot(self._total_training_loss_grad, param_offset)

		return influence

# %%
class TorchNNCore(torch.nn.Module):
    def __init__(
        self, inps, hiddens=[], bias=True, seed=None, hidden_activation=torch.nn.ReLU
    ):
        super(TorchNNCore, self).__init__()
        if seed is not None:
            torch.manual_seed(seed)
        struct = [inps] + hiddens + [1]
        self.layers = [] # This layer attribute is required under 
        for i in range(1, len(struct)):
            self.layers.append(
                torch.nn.Linear(
                    in_features=struct[i - 1], out_features=struct[i], bias=bias
                )
            )
            if i == len(struct) - 1:
                self.layers.append(torch.nn.Sigmoid())
            else:
                self.layers.append(hidden_activation())
        self.model = torch.nn.Sequential(*self.layers)
        # Adding dropout
        self.dropout = torch.nn.Dropout(0.20)    
           
    def forward(self, x):
        x = self.dropout(x)
        output = self.model(x)
        return output

# %%
# Prepare training & testing dataset
data1 = pd.read_csv('./adult.csv').to_numpy()
data2 = pd.read_csv('./broward.csv').to_numpy()
data3 = pd.read_csv('./hospital.csv').to_numpy()

X_train1 = torch.tensor(data1[:,:-1], dtype=torch.float)
y_train1 = torch.tensor(data1[:,-1].reshape(-1,1), dtype=torch.float)

X_train2 = torch.tensor(data2[:,:-1], dtype=torch.float)
y_train2 = torch.tensor(data2[:,-1].reshape(-1,1), dtype=torch.float)

X_train3 = torch.tensor(data3[:,:-1], dtype=torch.float)
y_train3 = torch.tensor(data3[:,-1].reshape(-1,1), dtype=torch.float)

print("\nData1: ",X_train1.shape, y_train1.shape)
print("\nData2: ",X_train2.shape, y_train2.shape)
print("\nData3: ",X_train3.shape, y_train3.shape)
# Out:
# Data1:  torch.Size([45222, 98]) torch.Size([45222, 1])
#
# Data2:  torch.Size([7214, 8]) torch.Size([7214, 1])
#
# Data3:  torch.Size([52778, 124]) torch.Size([52778, 1])

# %%
# Specify loss function, define model and optimizer
loss_func = torch.nn.BCELoss()

model1 = TorchNNCore(inps=X_train1.shape[1], hiddens=[512, 256, 128], hidden_activation=torch.nn.LeakyReLU)
optim1 = torch.optim.Adam(model1.parameters(), lr=0.001)
model2 = TorchNNCore(inps=X_train2.shape[1], hiddens=[512, 256, 128], hidden_activation=torch.nn.LeakyReLU)
optim2 = torch.optim.Adam(model2.parameters(), lr=0.001)
model3 = TorchNNCore(inps=X_train3.shape[1], hiddens=[512, 256, 128], hidden_activation=torch.nn.LeakyReLU)
optim3 = torch.optim.Adam(model3.parameters(), lr=0.001)

# Before using influence function, we show the structure of the model
print(model1)
print(model2)
print(model3)

# And we print the "layer" attribute, which is used to fetch the layers above
print("\nModel 1:")
for item in model1.layers:
    print(item)
print("\nModel 2:")
for item in model2.layers:
    print(item)
print("\nModel 3:")
for item in model3.layers:
    print(item)
# Out:
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=98, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=8, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=124, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
#   (dropout): Dropout(p=0.2, inplace=False)
# )
#
# Model 1:
# Linear(in_features=98, out_features=512, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=512, out_features=256, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=256, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()
#
# Model 2:
# Linear(in_features=8, out_features=512, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=512, out_features=256, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=256, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()
#
# Model 3:
# Linear(in_features=124, out_features=512, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=512, out_features=256, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=256, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()

# %%
sum_influences1 = np.zeros(X_train1.shape[0])
sum_influences2 = np.zeros(X_train2.shape[0])
sum_influences3 = np.zeros(X_train3.shape[0])

# For 10 times averaged result
for i in range(0,10):
  y_train_np1 = y_train1.detach().numpy()
  y_train_np2 = y_train2.detach().numpy()
  y_train_np3 = y_train3.detach().numpy()
  
  # %%timeit
# Training for 455 epochs
  for epoch in range(0,455):
      optim1.zero_grad()
      y_pred1 = model1(X_train1)
      loss1 = loss_func(y_pred1, y_train1)
      loss1.backward()
      optim1.step()
      if epoch%10==0:
          y_pred_np1 = (y_pred1.detach().numpy()) > 0.5
          accuracy1 = sum(y_pred_np1 == y_train_np1)/y_train_np1.shape[0]
          print('Epoch = %d, loss1 = %.4f, accuracy=%.4f'%(epoch, loss1.tolist(), accuracy1))
  print('\n')

# Training for 1443 epochs
  for epoch in range(0,1443):
      optim2.zero_grad()
      y_pred2 = model2(X_train2)
      loss2 = loss_func(y_pred2, y_train2)
      loss2.backward()
      optim2.step()
      if epoch%10==0:
          y_pred_np2 = (y_pred2.detach().numpy()) > 0.5
          accuracy2 = sum(y_pred_np2 == y_train_np2)/y_train_np2.shape[0]
          print('Epoch = %d, loss2 = %.4f, accuracy=%.4f'%(epoch, loss2.tolist(), accuracy2))
  print('\n')        

# Training for 660 epochs
  for epoch in range(0,660):
      optim3.zero_grad()
      y_pred3 = model3(X_train3)
      loss3 = loss_func(y_pred3, y_train3)
      loss3.backward()
      optim3.step()
      if epoch%10==0:
          y_pred_np3 = (y_pred3.detach().numpy()) > 0.5
          accuracy3 = sum(y_pred_np3 == y_train_np3)/y_train_np3.shape[0]
          print('Epoch = %d, loss3 = %.4f, accuracy=%.4f'%(epoch, loss3.tolist(), accuracy3))
  print('\n')

  optim1.zero_grad()
  optim2.zero_grad()
  optim3.zero_grad()

  infl1 = InfluenceFunction(
      model = model1, 
      X_train = X_train1, 
      y_train = y_train1, 
      loss_func = loss_func,
      layer_index = -2 
  )
  infl2 = InfluenceFunction(
      model = model2, 
      X_train = X_train2, 
      y_train = y_train2, 
      loss_func = loss_func, 
      layer_index = -2
  )
  infl3 = InfluenceFunction(
      model = model3, 
      X_train = X_train3, 
      y_train = y_train3, 
      loss_func = loss_func, 
      layer_index = -2
  )

  # Measuring the influence of data by removing records
  influences1 = []
  influences2 = []
  influences3 = []

  for index in range(0, X_train1.shape[0]):
      influences1.append(infl1.influence_remove_single(index))

  for index in range(0, X_train2.shape[0]):
      influences2.append(infl2.influence_remove_single(index))

  for index in range(0, X_train3.shape[0]):
      influences3.append(infl3.influence_remove_single(index))

  # Note: The influence scores depend the current status of the model,
  # even for the same model configuration with different random seed,
  # the model may converge to different point in hyperspace, which will
  # result in different score for the same records.
  # Note2: The absolute value of the influece score is meaningless, but
  # they are comparable with each other.

  sum_influences1 = [sum_influences1[i] + influences1[i] for i in range(len(influences1))]
  sum_influences2 = [sum_influences2[i] + influences2[i] for i in range(len(influences2))]
  sum_influences3 = [sum_influences3[i] + influences3[i] for i in range(len(influences3))]
# Out:
# Epoch = 0, loss1 = 2.2777, accuracy=0.2365
# Epoch = 10, loss1 = 3.6823, accuracy=0.7746
# Epoch = 20, loss1 = 3.6089, accuracy=0.7734
# Epoch = 30, loss1 = 3.6063, accuracy=0.7734
# Epoch = 40, loss1 = 3.5229, accuracy=0.7752
# Epoch = 50, loss1 = 5.7546, accuracy=0.7537
# Epoch = 60, loss1 = 5.7507, accuracy=0.7522
# Epoch = 70, loss1 = 5.7502, accuracy=0.7522
# Epoch = 80, loss1 = 5.7493, accuracy=0.7537
# Epoch = 90, loss1 = 5.7478, accuracy=0.7540
# Epoch = 100, loss1 = 5.7475, accuracy=0.7555
# Epoch = 110, loss1 = 5.7476, accuracy=0.7543
# Epoch = 120, loss1 = 5.7475, accuracy=0.7551
# Epoch = 130, loss1 = 5.7475, accuracy=0.7552
# Epoch = 140, loss1 = 5.7476, accuracy=0.7552
# Epoch = 150, loss1 = 5.7473, accuracy=0.7556
# Epoch = 160, loss1 = 5.7472, accuracy=0.7556
# Epoch = 170, loss1 = 5.7471, accuracy=0.7551
# Epoch = 180, loss1 = 5.7033, accuracy=0.7555
# Epoch = 190, loss1 = 5.6866, accuracy=0.7553
# Epoch = 200, loss1 = 5.6726, accuracy=0.7555
# Epoch = 210, loss1 = 5.6604, accuracy=0.7555
# Epoch = 220, loss1 = 5.6497, accuracy=0.7556
# Epoch = 230, loss1 = 5.6398, accuracy=0.7555
# Epoch = 240, loss1 = 5.6076, accuracy=0.7556
# Epoch = 250, loss1 = 5.5930, accuracy=0.7556
# Epoch = 260, loss1 = 5.5707, accuracy=0.7556
# Epoch = 270, loss1 = 5.5520, accuracy=0.7555
# Epoch = 280, loss1 = 5.5348, accuracy=0.7555
# Epoch = 290, loss1 = 5.4812, accuracy=0.7554
# Epoch = 300, loss1 = 5.4600, accuracy=0.7555
# Epoch = 310, loss1 = 5.4382, accuracy=0.7556
# Epoch = 320, loss1 = 5.4181, accuracy=0.7556
# Epoch = 330, loss1 = 5.3987, accuracy=0.7556
# Epoch = 340, loss1 = 5.3807, accuracy=0.7556
# Epoch = 350, loss1 = 5.3591, accuracy=0.7557
# Epoch = 360, loss1 = 5.3384, accuracy=0.7557
# Epoch = 370, loss1 = 5.3200, accuracy=0.7556
# Epoch = 380, loss1 = 5.3028, accuracy=0.7559
# Epoch = 390, loss1 = 5.1829, accuracy=0.7556
# Epoch = 400, loss1 = 5.1245, accuracy=0.7556
# Epoch = 410, loss1 = 4.9838, accuracy=0.7558
# Epoch = 420, loss1 = 4.9197, accuracy=0.7557
# Epoch = 430, loss1 = 4.8511, accuracy=0.7557
# Epoch = 440, loss1 = 4.7302, accuracy=0.7558
# Epoch = 450, loss1 = 3.3573, accuracy=0.7550
#
#
# Epoch = 0, loss2 = 0.6899, accuracy=0.4745
# Epoch = 10, loss2 = 0.6368, accuracy=0.6640
# Epoch = 20, loss2 = 0.6071, accuracy=0.6806
# Epoch = 30, loss2 = 0.6068, accuracy=0.6784
# Epoch = 40, loss2 = 0.6068, accuracy=0.6795
# Epoch = 50, loss2 = 0.6072, accuracy=0.6808
# Epoch = 60, loss2 = 0.6066, accuracy=0.6798
# Epoch = 70, loss2 = 0.6065, accuracy=0.6802
# Epoch = 80, loss2 = 0.6067, accuracy=0.6809
# Epoch = 90, loss2 = 0.6067, accuracy=0.6808
# Epoch = 100, loss2 = 0.6067, accuracy=0.6806
# Epoch = 110, loss2 = 0.6068, accuracy=0.6808
# Epoch = 120, loss2 = 0.6068, accuracy=0.6808
# Epoch = 130, loss2 = 0.6069, accuracy=0.6808
# Epoch = 140, loss2 = 0.6070, accuracy=0.6805
# Epoch = 150, loss2 = 0.6071, accuracy=0.6802
# Epoch = 160, loss2 = 0.6072, accuracy=0.6805
# Epoch = 170, loss2 = 0.6073, accuracy=0.6806
# Epoch = 180, loss2 = 0.6075, accuracy=0.6803
# Epoch = 190, loss2 = 0.6077, accuracy=0.6809
# Epoch = 200, loss2 = 0.6079, accuracy=0.6808
# Epoch = 210, loss2 = 0.6081, accuracy=0.6809
# Epoch = 220, loss2 = 0.6084, accuracy=0.6806
# Epoch = 230, loss2 = 0.6087, accuracy=0.6808
# Epoch = 240, loss2 = 0.6089, accuracy=0.6795
# Epoch = 250, loss2 = 0.6092, accuracy=0.6785
# Epoch = 260, loss2 = 0.6095, accuracy=0.6781
# Epoch = 270, loss2 = 0.6098, accuracy=0.6780
# Epoch = 280, loss2 = 0.6101, accuracy=0.6791
# Epoch = 290, loss2 = 0.6105, accuracy=0.6785
# Epoch = 300, loss2 = 0.6109, accuracy=0.6783
# Epoch = 310, loss2 = 0.6113, accuracy=0.6787
# Epoch = 320, loss2 = 0.6116, accuracy=0.6784
# Epoch = 330, loss2 = 0.6120, accuracy=0.6784
# Epoch = 340, loss2 = 0.6125, accuracy=0.6785
# Epoch = 350, loss2 = 0.6129, accuracy=0.6784
# Epoch = 360, loss2 = 0.6133, accuracy=0.6787
# Epoch = 370, loss2 = 0.6138, accuracy=0.6791
# Epoch = 380, loss2 = 0.6142, accuracy=0.6783
# Epoch = 390, loss2 = 0.6146, accuracy=0.6787
# Epoch = 400, loss2 = 0.6151, accuracy=0.6787
# Epoch = 410, loss2 = 0.6156, accuracy=0.6787
# Epoch = 420, loss2 = 0.6160, accuracy=0.6784
# Epoch = 430, loss2 = 0.6164, accuracy=0.6785
# Epoch = 440, loss2 = 0.6168, accuracy=0.6783
# Epoch = 450, loss2 = 0.6173, accuracy=0.6780
# Epoch = 460, loss2 = 0.6177, accuracy=0.6777
# Epoch = 470, loss2 = 0.6181, accuracy=0.6776
# Epoch = 480, loss2 = 0.6185, accuracy=0.6765
# Epoch = 490, loss2 = 0.6189, accuracy=0.6769
# Epoch = 500, loss2 = 0.6193, accuracy=0.6774
# Epoch = 510, loss2 = 0.6196, accuracy=0.6772
# Epoch = 520, loss2 = 0.6199, accuracy=0.6773
# Epoch = 530, loss2 = 0.6202, accuracy=0.6776
# Epoch = 540, loss2 = 0.6205, accuracy=0.6769
# Epoch = 550, loss2 = 0.6208, accuracy=0.6772
# Epoch = 560, loss2 = 0.6211, accuracy=0.6770
# Epoch = 570, loss2 = 0.6213, accuracy=0.6767
# Epoch = 580, loss2 = 0.6216, accuracy=0.6763
# Epoch = 590, loss2 = 0.6218, accuracy=0.6766
# Epoch = 600, loss2 = 0.6220, accuracy=0.6763
# Epoch = 610, loss2 = 0.6222, accuracy=0.6759
# Epoch = 620, loss2 = 0.6224, accuracy=0.6755
# Epoch = 630, loss2 = 0.6225, accuracy=0.6755
# Epoch = 640, loss2 = 0.6227, accuracy=0.6759
# Epoch = 650, loss2 = 0.6229, accuracy=0.6759
# Epoch = 660, loss2 = 0.6231, accuracy=0.6762
# Epoch = 670, loss2 = 0.6232, accuracy=0.6763
# Epoch = 680, loss2 = 0.6234, accuracy=0.6763
# Epoch = 690, loss2 = 0.6235, accuracy=0.6763
# Epoch = 700, loss2 = 0.6237, accuracy=0.6765
# Epoch = 710, loss2 = 0.6238, accuracy=0.6765
# Epoch = 720, loss2 = 0.6239, accuracy=0.6763
# Epoch = 730, loss2 = 0.6240, accuracy=0.6763
# Epoch = 740, loss2 = 0.6241, accuracy=0.6765
# Epoch = 750, loss2 = 0.6242, accuracy=0.6763
# Epoch = 760, loss2 = 0.6244, accuracy=0.6766
# Epoch = 770, loss2 = 0.6245, accuracy=0.6767
# Epoch = 780, loss2 = 0.6246, accuracy=0.6765
# Epoch = 790, loss2 = 0.6247, accuracy=0.6763
# Epoch = 800, loss2 = 0.6248, accuracy=0.6763
# Epoch = 810, loss2 = 0.6250, accuracy=0.6763
# Epoch = 820, loss2 = 0.6251, accuracy=0.6765
# Epoch = 830, loss2 = 0.6252, accuracy=0.6763
# Epoch = 840, loss2 = 0.6253, accuracy=0.6762
# Epoch = 850, loss2 = 0.6254, accuracy=0.6763
# Epoch = 860, loss2 = 0.6256, accuracy=0.6766
# Epoch = 870, loss2 = 0.6257, accuracy=0.6766
# Epoch = 880, loss2 = 0.6258, accuracy=0.6765
# Epoch = 890, loss2 = 0.6259, accuracy=0.6762
# Epoch = 900, loss2 = 0.6261, accuracy=0.6763
# Epoch = 910, loss2 = 0.6262, accuracy=0.6760
# Epoch = 920, loss2 = 0.6263, accuracy=0.6759
# Epoch = 930, loss2 = 0.6265, accuracy=0.6759
# Epoch = 940, loss2 = 0.6266, accuracy=0.6759
# Epoch = 950, loss2 = 0.6268, accuracy=0.6756
# Epoch = 960, loss2 = 0.6269, accuracy=0.6752
# Epoch = 970, loss2 = 0.6271, accuracy=0.6755
# Epoch = 980, loss2 = 0.6273, accuracy=0.6751
# Epoch = 990, loss2 = 0.6275, accuracy=0.6742
# Epoch = 1000, loss2 = 0.6277, accuracy=0.6740
# Epoch = 1010, loss2 = 0.6279, accuracy=0.6738
# Epoch = 1020, loss2 = 0.6282, accuracy=0.6736
# Epoch = 1030, loss2 = 0.6285, accuracy=0.6741
# Epoch = 1040, loss2 = 0.6288, accuracy=0.6738
# Epoch = 1050, loss2 = 0.6291, accuracy=0.6727
# Epoch = 1060, loss2 = 0.6295, accuracy=0.6724
# Epoch = 1070, loss2 = 0.6300, accuracy=0.6717
# Epoch = 1080, loss2 = 0.6305, accuracy=0.6706
# Epoch = 1090, loss2 = 0.6311, accuracy=0.6708
# Epoch = 1100, loss2 = 0.6318, accuracy=0.6697
# Epoch = 1110, loss2 = 0.6325, accuracy=0.6691
# Epoch = 1120, loss2 = 0.6334, accuracy=0.6680
# Epoch = 1130, loss2 = 0.6344, accuracy=0.6666
# Epoch = 1140, loss2 = 0.6353, accuracy=0.6669
# Epoch = 1150, loss2 = 0.6365, accuracy=0.6644
# Epoch = 1160, loss2 = 0.6375, accuracy=0.6636
# Epoch = 1170, loss2 = 0.6385, accuracy=0.6620
# Epoch = 1180, loss2 = 0.6395, accuracy=0.6607
# Epoch = 1190, loss2 = 0.6404, accuracy=0.6598
# Epoch = 1200, loss2 = 0.6411, accuracy=0.6580
# Epoch = 1210, loss2 = 0.6415, accuracy=0.6576
# Epoch = 1220, loss2 = 0.6418, accuracy=0.6572
# Epoch = 1230, loss2 = 0.6418, accuracy=0.6573
# Epoch = 1240, loss2 = 0.6418, accuracy=0.6573
# Epoch = 1250, loss2 = 0.6418, accuracy=0.6577
# Epoch = 1260, loss2 = 0.6417, accuracy=0.6580
# Epoch = 1270, loss2 = 0.6416, accuracy=0.6586
# Epoch = 1280, loss2 = 0.6416, accuracy=0.6587
# Epoch = 1290, loss2 = 0.6415, accuracy=0.6584
# Epoch = 1300, loss2 = 0.6415, accuracy=0.6584
# Epoch = 1310, loss2 = 0.6414, accuracy=0.6586
# Epoch = 1320, loss2 = 0.6414, accuracy=0.6583
# Epoch = 1330, loss2 = 0.6413, accuracy=0.6582
# Epoch = 1340, loss2 = 0.6413, accuracy=0.6583
# Epoch = 1350, loss2 = 0.6413, accuracy=0.6583
# Epoch = 1360, loss2 = 0.6413, accuracy=0.6583
# Epoch = 1370, loss2 = 0.6412, accuracy=0.6582
# Epoch = 1380, loss2 = 0.6412, accuracy=0.6584
# Epoch = 1390, loss2 = 0.6412, accuracy=0.6582
# Epoch = 1400, loss2 = 0.6413, accuracy=0.6582
# Epoch = 1410, loss2 = 0.6413, accuracy=0.6580
# Epoch = 1420, loss2 = 0.6412, accuracy=0.6579
# Epoch = 1430, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1440, loss2 = 0.6412, accuracy=0.6582
#
#
# Epoch = 0, loss3 = 0.6816, accuracy=0.6544
# Epoch = 10, loss3 = 0.6721, accuracy=0.6544
# Epoch = 20, loss3 = 0.6678, accuracy=0.6544
# Epoch = 30, loss3 = 0.6651, accuracy=0.6544
# Epoch = 40, loss3 = 0.6635, accuracy=0.6544
# Epoch = 50, loss3 = 0.6627, accuracy=0.6544
# Epoch = 60, loss3 = 0.6626, accuracy=0.6544
# Epoch = 70, loss3 = 0.6628, accuracy=0.6544
# Epoch = 80, loss3 = 0.6631, accuracy=0.6544
# Epoch = 90, loss3 = 0.6632, accuracy=0.6544
# Epoch = 100, loss3 = 0.6633, accuracy=0.6544
# Epoch = 110, loss3 = 0.6633, accuracy=0.6544
# Epoch = 120, loss3 = 0.6632, accuracy=0.6544
# Epoch = 130, loss3 = 0.6630, accuracy=0.6544
# Epoch = 140, loss3 = 0.6629, accuracy=0.6544
# Epoch = 150, loss3 = 0.6627, accuracy=0.6544
# Epoch = 160, loss3 = 0.6624, accuracy=0.6544
# Epoch = 170, loss3 = 0.6622, accuracy=0.6544
# Epoch = 180, loss3 = 0.6619, accuracy=0.6544
# Epoch = 190, loss3 = 0.6616, accuracy=0.6544
# Epoch = 200, loss3 = 0.6612, accuracy=0.6544
# Epoch = 210, loss3 = 0.6608, accuracy=0.6544
# Epoch = 220, loss3 = 0.6604, accuracy=0.6544
# Epoch = 230, loss3 = 0.6599, accuracy=0.6544
# Epoch = 240, loss3 = 0.6595, accuracy=0.6544
# Epoch = 250, loss3 = 0.6590, accuracy=0.6544
# Epoch = 260, loss3 = 0.6585, accuracy=0.6544
# Epoch = 270, loss3 = 0.6580, accuracy=0.6544
# Epoch = 280, loss3 = 0.6575, accuracy=0.6544
# Epoch = 290, loss3 = 0.6570, accuracy=0.6544
# Epoch = 300, loss3 = 0.6565, accuracy=0.6544
# Epoch = 310, loss3 = 0.6561, accuracy=0.6544
# Epoch = 320, loss3 = 0.6557, accuracy=0.6544
# Epoch = 330, loss3 = 0.6552, accuracy=0.6544
# Epoch = 340, loss3 = 0.6549, accuracy=0.6544
# Epoch = 350, loss3 = 0.6545, accuracy=0.6544
# Epoch = 360, loss3 = 0.6542, accuracy=0.6544
# Epoch = 370, loss3 = 0.6538, accuracy=0.6544
# Epoch = 380, loss3 = 0.6535, accuracy=0.6544
# Epoch = 390, loss3 = 0.6532, accuracy=0.6544
# Epoch = 400, loss3 = 0.6530, accuracy=0.6544
# Epoch = 410, loss3 = 0.6527, accuracy=0.6544
# Epoch = 420, loss3 = 0.6525, accuracy=0.6544
# Epoch = 430, loss3 = 0.6522, accuracy=0.6544
# Epoch = 440, loss3 = 0.6520, accuracy=0.6544
# Epoch = 450, loss3 = 0.6518, accuracy=0.6544
# Epoch = 460, loss3 = 0.6516, accuracy=0.6544
# Epoch = 470, loss3 = 0.6514, accuracy=0.6544
# Epoch = 480, loss3 = 0.6513, accuracy=0.6544
# Epoch = 490, loss3 = 0.6511, accuracy=0.6544
# Epoch = 500, loss3 = 0.6510, accuracy=0.6544
# Epoch = 510, loss3 = 0.6508, accuracy=0.6544
# Epoch = 520, loss3 = 0.6507, accuracy=0.6544
# Epoch = 530, loss3 = 0.6506, accuracy=0.6544
# Epoch = 540, loss3 = 0.6504, accuracy=0.6544
# Epoch = 550, loss3 = 0.6503, accuracy=0.6544
# Epoch = 560, loss3 = 0.6502, accuracy=0.6544
# Epoch = 570, loss3 = 0.6501, accuracy=0.6544
# Epoch = 580, loss3 = 0.6501, accuracy=0.6544
# Epoch = 590, loss3 = 0.6500, accuracy=0.6544
# Epoch = 600, loss3 = 0.6499, accuracy=0.6544
# Epoch = 610, loss3 = 0.6498, accuracy=0.6544
# Epoch = 620, loss3 = 0.6498, accuracy=0.6544
# Epoch = 630, loss3 = 0.6497, accuracy=0.6544
# Epoch = 640, loss3 = 0.6496, accuracy=0.6544
# Epoch = 650, loss3 = 0.6496, accuracy=0.6544
#
#
# Epoch = 0, loss1 = 0.6598, accuracy=0.7755
# Epoch = 10, loss1 = 0.5370, accuracy=0.7746
# Epoch = 20, loss1 = 0.5297, accuracy=0.7768
# Epoch = 30, loss1 = 0.5277, accuracy=0.7796
# Epoch = 40, loss1 = 0.5289, accuracy=0.7868
# Epoch = 50, loss1 = 0.5277, accuracy=0.7843
# Epoch = 60, loss1 = 0.5280, accuracy=0.7841
# Epoch = 70, loss1 = 0.5273, accuracy=0.7827
# Epoch = 80, loss1 = 0.5264, accuracy=0.7884
# Epoch = 90, loss1 = 0.5290, accuracy=0.7790
# Epoch = 100, loss1 = 0.5277, accuracy=0.7775
# Epoch = 110, loss1 = 0.5280, accuracy=0.7778
# Epoch = 120, loss1 = 0.5267, accuracy=0.7796
# Epoch = 130, loss1 = 0.5270, accuracy=0.7792
# Epoch = 140, loss1 = 0.5263, accuracy=0.7788
# Epoch = 150, loss1 = 0.5264, accuracy=0.7775
# Epoch = 160, loss1 = 0.5260, accuracy=0.7776
# Epoch = 170, loss1 = 0.5259, accuracy=0.7776
# Epoch = 180, loss1 = 0.5257, accuracy=0.7776
# Epoch = 190, loss1 = 0.5256, accuracy=0.7778
# Epoch = 200, loss1 = 0.5254, accuracy=0.7801
# Epoch = 210, loss1 = 0.5252, accuracy=0.7799
# Epoch = 220, loss1 = 0.5251, accuracy=0.7789
# Epoch = 230, loss1 = 0.5249, accuracy=0.7801
# Epoch = 240, loss1 = 0.5248, accuracy=0.7801
# Epoch = 250, loss1 = 0.5246, accuracy=0.7790
# Epoch = 260, loss1 = 0.5244, accuracy=0.7886
# Epoch = 270, loss1 = 0.5243, accuracy=0.7899
# Epoch = 280, loss1 = 0.5242, accuracy=0.7884
# Epoch = 290, loss1 = 0.5241, accuracy=0.7882
# Epoch = 300, loss1 = 0.5240, accuracy=0.7887
# Epoch = 310, loss1 = 0.5239, accuracy=0.7852
# Epoch = 320, loss1 = 0.5238, accuracy=0.7838
# Epoch = 330, loss1 = 0.5237, accuracy=0.7822
# Epoch = 340, loss1 = 0.5236, accuracy=0.7828
# Epoch = 350, loss1 = 0.5235, accuracy=0.7829
# Epoch = 360, loss1 = 0.5231, accuracy=0.7813
# Epoch = 370, loss1 = 0.5231, accuracy=0.7904
# Epoch = 380, loss1 = 0.5236, accuracy=0.7849
# Epoch = 390, loss1 = 0.5232, accuracy=0.7839
# Epoch = 400, loss1 = 0.5213, accuracy=0.7950
# Epoch = 410, loss1 = 0.5234, accuracy=0.7937
# Epoch = 420, loss1 = 0.5237, accuracy=0.7853
# Epoch = 430, loss1 = 0.5233, accuracy=0.7822
# Epoch = 440, loss1 = 0.5231, accuracy=0.7807
# Epoch = 450, loss1 = 0.5231, accuracy=0.7824
#
#
# Epoch = 0, loss2 = 0.6412, accuracy=0.6583
# Epoch = 10, loss2 = 0.6412, accuracy=0.6583
# Epoch = 20, loss2 = 0.6412, accuracy=0.6583
# Epoch = 30, loss2 = 0.6412, accuracy=0.6583
# Epoch = 40, loss2 = 0.6412, accuracy=0.6583
# Epoch = 50, loss2 = 0.6412, accuracy=0.6583
# Epoch = 60, loss2 = 0.6412, accuracy=0.6583
# Epoch = 70, loss2 = 0.6412, accuracy=0.6583
# Epoch = 80, loss2 = 0.6412, accuracy=0.6583
# Epoch = 90, loss2 = 0.6412, accuracy=0.6584
# Epoch = 100, loss2 = 0.6412, accuracy=0.6583
# Epoch = 110, loss2 = 0.6412, accuracy=0.6583
# Epoch = 120, loss2 = 0.6412, accuracy=0.6582
# Epoch = 130, loss2 = 0.6412, accuracy=0.6583
# Epoch = 140, loss2 = 0.6412, accuracy=0.6583
# Epoch = 150, loss2 = 0.6412, accuracy=0.6584
# Epoch = 160, loss2 = 0.6412, accuracy=0.6584
# Epoch = 170, loss2 = 0.6412, accuracy=0.6583
# Epoch = 180, loss2 = 0.6412, accuracy=0.6583
# Epoch = 190, loss2 = 0.6412, accuracy=0.6583
# Epoch = 200, loss2 = 0.6412, accuracy=0.6582
# Epoch = 210, loss2 = 0.6412, accuracy=0.6582
# Epoch = 220, loss2 = 0.6412, accuracy=0.6582
# Epoch = 230, loss2 = 0.6412, accuracy=0.6582
# Epoch = 240, loss2 = 0.6412, accuracy=0.6583
# Epoch = 250, loss2 = 0.6412, accuracy=0.6583
# Epoch = 260, loss2 = 0.6412, accuracy=0.6583
# Epoch = 270, loss2 = 0.6412, accuracy=0.6583
# Epoch = 280, loss2 = 0.6412, accuracy=0.6583
# Epoch = 290, loss2 = 0.6412, accuracy=0.6583
# Epoch = 300, loss2 = 0.6412, accuracy=0.6583
# Epoch = 310, loss2 = 0.6412, accuracy=0.6583
# Epoch = 320, loss2 = 0.6412, accuracy=0.6583
# Epoch = 330, loss2 = 0.6412, accuracy=0.6583
# Epoch = 340, loss2 = 0.6412, accuracy=0.6583
# Epoch = 350, loss2 = 0.6412, accuracy=0.6583
# Epoch = 360, loss2 = 0.6412, accuracy=0.6583
# Epoch = 370, loss2 = 0.6412, accuracy=0.6583
# Epoch = 380, loss2 = 0.6412, accuracy=0.6583
# Epoch = 390, loss2 = 0.6412, accuracy=0.6583
# Epoch = 400, loss2 = 0.6412, accuracy=0.6583
# Epoch = 410, loss2 = 0.6412, accuracy=0.6583
# Epoch = 420, loss2 = 0.6412, accuracy=0.6583
# Epoch = 430, loss2 = 0.6412, accuracy=0.6583
# Epoch = 440, loss2 = 0.6412, accuracy=0.6583
# Epoch = 450, loss2 = 0.6412, accuracy=0.6583
# Epoch = 460, loss2 = 0.6412, accuracy=0.6583
# Epoch = 470, loss2 = 0.6412, accuracy=0.6583
# Epoch = 480, loss2 = 0.6412, accuracy=0.6583
# Epoch = 490, loss2 = 0.6412, accuracy=0.6583
# Epoch = 500, loss2 = 0.6412, accuracy=0.6583
# Epoch = 510, loss2 = 0.6412, accuracy=0.6583
# Epoch = 520, loss2 = 0.6412, accuracy=0.6583
# Epoch = 530, loss2 = 0.6412, accuracy=0.6583
# Epoch = 540, loss2 = 0.6412, accuracy=0.6583
# Epoch = 550, loss2 = 0.6412, accuracy=0.6583
# Epoch = 560, loss2 = 0.6412, accuracy=0.6583
# Epoch = 570, loss2 = 0.6412, accuracy=0.6583
# Epoch = 580, loss2 = 0.6412, accuracy=0.6583
# Epoch = 590, loss2 = 0.6412, accuracy=0.6583
# Epoch = 600, loss2 = 0.6412, accuracy=0.6583
# Epoch = 610, loss2 = 0.6412, accuracy=0.6583
# Epoch = 620, loss2 = 0.6412, accuracy=0.6583
# Epoch = 630, loss2 = 0.6412, accuracy=0.6583
# Epoch = 640, loss2 = 0.6412, accuracy=0.6583
# Epoch = 650, loss2 = 0.6412, accuracy=0.6583
# Epoch = 660, loss2 = 0.6412, accuracy=0.6583
# Epoch = 670, loss2 = 0.6412, accuracy=0.6583
# Epoch = 680, loss2 = 0.6412, accuracy=0.6583
# Epoch = 690, loss2 = 0.6412, accuracy=0.6583
# Epoch = 700, loss2 = 0.6412, accuracy=0.6583
# Epoch = 710, loss2 = 0.6412, accuracy=0.6583
# Epoch = 720, loss2 = 0.6412, accuracy=0.6583
# Epoch = 730, loss2 = 0.6412, accuracy=0.6583
# Epoch = 740, loss2 = 0.6412, accuracy=0.6583
# Epoch = 750, loss2 = 0.6412, accuracy=0.6583
# Epoch = 760, loss2 = 0.6412, accuracy=0.6583
# Epoch = 770, loss2 = 0.6412, accuracy=0.6583
# Epoch = 780, loss2 = 0.6412, accuracy=0.6583
# Epoch = 790, loss2 = 0.6412, accuracy=0.6583
# Epoch = 800, loss2 = 0.6412, accuracy=0.6583
# Epoch = 810, loss2 = 0.6412, accuracy=0.6583
# Epoch = 820, loss2 = 0.6412, accuracy=0.6583
# Epoch = 830, loss2 = 0.6412, accuracy=0.6583
# Epoch = 840, loss2 = 0.6412, accuracy=0.6583
# Epoch = 850, loss2 = 0.6412, accuracy=0.6583
# Epoch = 860, loss2 = 0.6412, accuracy=0.6583
# Epoch = 870, loss2 = 0.6412, accuracy=0.6583
# Epoch = 880, loss2 = 0.6412, accuracy=0.6583
# Epoch = 890, loss2 = 0.6412, accuracy=0.6583
# Epoch = 900, loss2 = 0.6412, accuracy=0.6583
# Epoch = 910, loss2 = 0.6412, accuracy=0.6583
# Epoch = 920, loss2 = 0.6412, accuracy=0.6583
# Epoch = 930, loss2 = 0.6412, accuracy=0.6583
# Epoch = 940, loss2 = 0.6412, accuracy=0.6583
# Epoch = 950, loss2 = 0.6412, accuracy=0.6583
# Epoch = 960, loss2 = 0.6412, accuracy=0.6583
# Epoch = 970, loss2 = 0.6412, accuracy=0.6583
# Epoch = 980, loss2 = 0.6412, accuracy=0.6583
# Epoch = 990, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1000, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1010, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1020, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1030, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1040, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1050, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1060, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1070, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1080, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1090, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1100, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1110, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1120, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1130, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1140, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1150, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1160, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1170, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1180, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1190, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1200, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1210, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1220, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1230, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1240, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1250, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1260, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1270, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1280, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1290, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1300, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1310, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1320, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1330, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1340, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1350, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1360, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1370, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1380, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1390, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1400, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1410, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1420, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1430, loss2 = 0.6412, accuracy=0.6583
# Epoch = 1440, loss2 = 0.6412, accuracy=0.6583
#
#
# Epoch = 0, loss3 = 0.6495, accuracy=0.6544
# Epoch = 10, loss3 = 0.6495, accuracy=0.6544
# Epoch = 20, loss3 = 0.6494, accuracy=0.6544
# Epoch = 30, loss3 = 0.6494, accuracy=0.6544
# Epoch = 40, loss3 = 0.6494, accuracy=0.6544
# Epoch = 50, loss3 = 0.6493, accuracy=0.6544
# Epoch = 60, loss3 = 0.6493, accuracy=0.6544
# Epoch = 70, loss3 = 0.6493, accuracy=0.6544
# Epoch = 80, loss3 = 0.6492, accuracy=0.6544
# Epoch = 90, loss3 = 0.6492, accuracy=0.6544
# Epoch = 100, loss3 = 0.6492, accuracy=0.6544
# Epoch = 110, loss3 = 0.6492, accuracy=0.6544
# Epoch = 120, loss3 = 0.6491, accuracy=0.6544
# Epoch = 130, loss3 = 0.6491, accuracy=0.6544
# Epoch = 140, loss3 = 0.6491, accuracy=0.6544
# Epoch = 150, loss3 = 0.6491, accuracy=0.6544
# Epoch = 160, loss3 = 0.6491, accuracy=0.6544
# Epoch = 170, loss3 = 0.6491, accuracy=0.6544

# %%
avg_influences1 = [val / 10 for val in sum_influences1]
avg_influences2 = [val / 10 for val in sum_influences2]
avg_influences3 = [val / 10 for val in sum_influences3]

# %%
# Creating a dictionary of average influence scores with index
result1 = {idx: val for idx, val in enumerate(avg_influences1)}
print(list(result1.items())[:])
result2 = {idx: val for idx, val in enumerate(avg_influences2)}
print(list(result2.items())[:])
result3 = {idx: val for idx, val in enumerate(avg_influences3)}
print(list(result3.items())[:])

# %%
print(avg_influences1)
print(avg_influences2)
print(avg_influences3)

# %%
np.savez("adult_scores_l2_0.0001.npz", x = avg_influences1)

# %%
np.savez("broward_scores_l2_0.0001.npz", x = avg_influences2)

# %%
np.savez("hospital_scores_l2_0.0001.npz", x = avg_influences3)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !cp adult_scores_l2_0.1.npz "drive/MyDrive/Colab Notebooks/Influence results"

# %%
# !cp broward_scores_l2_0.1.npz "drive/MyDrive/Colab Notebooks/Influence results"

# %%
# !cp hospital_scores_l2_0.1.npz "drive/MyDrive/Colab Notebooks/Influence results"
