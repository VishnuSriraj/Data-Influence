# %% [markdown]
# <a href="https://colab.research.google.com/github/VishnuSriraj/Data-Influence/blob/main/InfluenceScores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import pandas as pd
import scipy
import math
import copy
from torch.autograd import grad as gradient

# %%
class InfluenceFunction(object):
	def __init__(self, model, X_train, y_train, loss_func, layer_index):
		if not isinstance(model, torch.nn.Module):
			raise RuntimeError(f"Only torch.nn.Module models are supported, got f{type(model)}")
		if not isinstance(X_train, torch.Tensor):
			raise RuntimeError(f"X_train must be <torch.Tensor>, got f{type(X_train)}")
		if not isinstance(y_train, torch.Tensor):
			raise RuntimeError(f"y_train must be <torch.Tensor>, got f{type(y_train)}")

		try:
			layers = model.layers
		except:
			raise RuntimeError('The model must have an attribute "layers".')

		self._model = copy.deepcopy(model)
		self._X_train = X_train
		self._y_train = y_train
		self._loss_func = loss_func
		self._layer_index = layer_index
		
		self._total_training_loss_grad = None
		self._Hessian_matrix = self._calculate_Hessian_matrix()
		self._Hessian_inv = np.linalg.inv(self._Hessian_matrix)
		

	def _calculate_Hessian_matrix(self):

		X_train = self._X_train
		y_train = self._y_train
		model = self._model

		y_pred = model(X_train)
		loss = self._loss_func(y_pred, y_train)
		layer = model.layers[self._layer_index]

		if not isinstance(layer, torch.nn.Linear):
			raise RuntimeError(
				f"Only support layer type torch.nn.Linear, got f{type(layer)}."
			)

		weights = model.layers[self._layer_index].weight
		bias = model.layers[self._layer_index].bias

		grad_L_w_1 = gradient(
			loss, (weights, bias), retain_graph=True, create_graph=True
		)
		self._total_training_loss_grad = np.array(
			grad_L_w_1[0][0].tolist() + grad_L_w_1[1].tolist()
		)

		Hessian = []
		for i in range(0, grad_L_w_1[0].shape[1]):
			grad_L_w_2 = gradient(
				grad_L_w_1[0][0][i], (weights, bias), retain_graph=True
			)
			Hessian.append(grad_L_w_2[0][0].tolist() + grad_L_w_2[1].tolist())
		grad_L_w_2 = gradient(grad_L_w_1[1][0], (weights, bias), retain_graph=True)
		Hessian.append(grad_L_w_2[0][0].tolist() + grad_L_w_2[1].tolist())

		return np.array(Hessian)

	def influence_remove_single(self, index):
		return -self.influence_add_single(self._X_train[index], self._y_train[index])

	def influence_modify_single(self, index, new_x, new_y):
		return self.influence_add_single(new_x, new_y) + self.influence_remove_single(index)

	def influence_add_single(self, x, y):

		if not isinstance(x, torch.Tensor):
			raise RuntimeError(f"Added x must be <torch.Tensor>, got f{type(x)}")
		if not isinstance(y, torch.Tensor):
			raise RuntimeError(f"Added y must be <torch.Tensor>, got f{type(y)}")

		x = x.reshape(1, -1).detach()
		y = y.reshape(1, -1).detach()

		model = self._model

		y_pred = model(x)
		loss_single = self._loss_func(y_pred, y)

		weights = model.layers[self._layer_index].weight
		bias = model.layers[self._layer_index].bias

		grad = gradient(loss_single, (weights, bias), retain_graph=True)
		grad = np.array(grad[0][0].tolist() + grad[1].tolist())

		param_offset = - np.dot(self._Hessian_inv, grad)

		influence = np.dot(self._total_training_loss_grad, param_offset)

		return influence

# %%
class TorchNNCore(torch.nn.Module):
    def __init__(
        self, inps, hiddens=[], bias=True, seed=None, hidden_activation=torch.nn.ReLU
    ):
        super(TorchNNCore, self).__init__()
        if seed is not None:
            torch.manual_seed(seed)
        struct = [inps] + hiddens + [1]
        self.layers = [] # This layer attribute is required under 
        for i in range(1, len(struct)):
            self.layers.append(
                torch.nn.Linear(
                    in_features=struct[i - 1], out_features=struct[i], bias=bias
                )
            )
            if i == len(struct) - 1:
                self.layers.append(torch.nn.Sigmoid())
            else:
                self.layers.append(hidden_activation())
        self.model = torch.nn.Sequential(*self.layers)

    def forward(self, x):
        output = self.model(x)
        return output

# %%
# Prepare training & testing dataset
data1 = pd.read_csv('./adult.csv').to_numpy()
data2 = pd.read_csv('./broward.csv').to_numpy()
data3 = pd.read_csv('./hospital.csv').to_numpy()

X_train1 = torch.tensor(data1[:,:-1], dtype=torch.float)
y_train1 = torch.tensor(data1[:,-1].reshape(-1,1), dtype=torch.float)

X_train2 = torch.tensor(data2[:,:-1], dtype=torch.float)
y_train2 = torch.tensor(data2[:,-1].reshape(-1,1), dtype=torch.float)

X_train3 = torch.tensor(data3[:,:-1], dtype=torch.float)
y_train3 = torch.tensor(data3[:,-1].reshape(-1,1), dtype=torch.float)

print("\nData1: ",X_train1.shape, y_train1.shape)
print("\nData2: ",X_train2.shape, y_train2.shape)
print("\nData3: ",X_train3.shape, y_train3.shape)
# Out:
# Data1:  torch.Size([45222, 98]) torch.Size([45222, 1])
#
# Data2:  torch.Size([7214, 8]) torch.Size([7214, 1])
#
# Data3:  torch.Size([52778, 124]) torch.Size([52778, 1])

# %%
# Specify loss function, define model and optimizer
loss_func = torch.nn.BCELoss()

model1 = TorchNNCore(inps=X_train1.shape[1], hiddens=[512, 256, 128], hidden_activation=torch.nn.LeakyReLU)
optim1 = torch.optim.Adam(model1.parameters(),lr=0.001)
model2 = TorchNNCore(inps=X_train2.shape[1], hiddens=[512, 256, 128], hidden_activation=torch.nn.LeakyReLU)
optim2 = torch.optim.Adam(model2.parameters(),lr=0.001)
model3 = TorchNNCore(inps=X_train3.shape[1], hiddens=[512, 256, 128], hidden_activation=torch.nn.LeakyReLU)
optim3 = torch.optim.Adam(model3.parameters(),lr=0.001)

# Before using influence function, we show the structure of the model
print(model1)
print(model2)
print(model3)

# And we print the "layer" attribute, which is used to fetch the layers above
print("\nModel 1:")
for item in model1.layers:
    print(item)
print("\nModel 2:")
for item in model2.layers:
    print(item)
print("\nModel 3:")
for item in model3.layers:
    print(item)
# Out:
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=98, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=8, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )
# TorchNNCore(
#   (model): Sequential(
#     (0): Linear(in_features=124, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=256, out_features=128, bias=True)
#     (5): LeakyReLU(negative_slope=0.01)
#     (6): Linear(in_features=128, out_features=1, bias=True)
#     (7): Sigmoid()
#   )
# )
#
# Model 1:
# Linear(in_features=98, out_features=512, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=512, out_features=256, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=256, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()
#
# Model 2:
# Linear(in_features=8, out_features=512, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=512, out_features=256, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=256, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()
#
# Model 3:
# Linear(in_features=124, out_features=512, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=512, out_features=256, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=256, out_features=128, bias=True)
# LeakyReLU(negative_slope=0.01)
# Linear(in_features=128, out_features=1, bias=True)
# Sigmoid()

# %%
sum_influences1 = np.zeros(X_train1.shape[0])
sum_influences2 = np.zeros(X_train2.shape[0])
sum_influences3 = np.zeros(X_train3.shape[0])

# For 10 times averaged result
for i in range(0,10):
  y_train_np1 = y_train1.detach().numpy()
  y_train_np2 = y_train2.detach().numpy()
  y_train_np3 = y_train3.detach().numpy()
  
  # %%timeit
# Training for 455 epochs
  for epoch in range(0,455):
      optim1.zero_grad()
      y_pred1 = model1(X_train1)
      loss1 = loss_func(y_pred1, y_train1)
      loss1.backward()
      optim1.step()
      if epoch%10==0:
          y_pred_np1 = (y_pred1.detach().numpy()) > 0.5
          accuracy1 = sum(y_pred_np1 == y_train_np1)/y_train_np1.shape[0]
          print('Epoch = %d, loss1 = %.4f, accuracy=%.4f'%(epoch, loss1.tolist(), accuracy1))
  print('\n')

# Training for 1443 epochs
  for epoch in range(0,1443):
      optim2.zero_grad()
      y_pred2 = model2(X_train2)
      loss2 = loss_func(y_pred2, y_train2)
      loss2.backward()
      optim2.step()
      if epoch%10==0:
          y_pred_np2 = (y_pred2.detach().numpy()) > 0.5
          accuracy2 = sum(y_pred_np2 == y_train_np2)/y_train_np2.shape[0]
          print('Epoch = %d, loss2 = %.4f, accuracy=%.4f'%(epoch, loss2.tolist(), accuracy2))
  print('\n')        

# Training for 660 epochs
  for epoch in range(0,660):
      optim3.zero_grad()
      y_pred3 = model3(X_train3)
      loss3 = loss_func(y_pred3, y_train3)
      loss3.backward()
      optim3.step()
      if epoch%10==0:
          y_pred_np3 = (y_pred3.detach().numpy()) > 0.5
          accuracy3 = sum(y_pred_np3 == y_train_np3)/y_train_np3.shape[0]
          print('Epoch = %d, loss3 = %.4f, accuracy=%.4f'%(epoch, loss3.tolist(), accuracy3))
  print('\n')

  optim1.zero_grad()
  optim2.zero_grad()
  optim3.zero_grad()

  infl1 = InfluenceFunction(
      model = model1, 
      X_train = X_train1, 
      y_train = y_train1, 
      loss_func = loss_func,
      layer_index = -2 
  )
  infl2 = InfluenceFunction(
      model = model2, 
      X_train = X_train2, 
      y_train = y_train2, 
      loss_func = loss_func, 
      layer_index = -2
  )
  infl3 = InfluenceFunction(
      model = model3, 
      X_train = X_train3, 
      y_train = y_train3, 
      loss_func = loss_func, 
      layer_index = -2
  )

  # Measuring the influence of data by removing records
  influences1 = []
  influences2 = []
  influences3 = []

  for index in range(0, X_train1.shape[0]):
      influences1.append(infl1.influence_remove_single(index))

  for index in range(0, X_train2.shape[0]):
      influences2.append(infl2.influence_remove_single(index))

  for index in range(0, X_train3.shape[0]):
      influences3.append(infl3.influence_remove_single(index))

  # Note: The influence scores depend the current status of the model,
  # even for the same model configuration with different random seed,
  # the model may converge to different point in hyperspace, which will
  # result in different score for the same records.
  # Note2: The absolute value of the influece score is meaningless, but
  # they are comparable with each other.

  sum_influences1 = [sum_influences1[i] + influences1[i] for i in range(len(influences1))]
  sum_influences2 = [sum_influences2[i] + influences2[i] for i in range(len(influences2))]
  sum_influences3 = [sum_influences3[i] + influences3[i] for i in range(len(influences3))]
# Out:
# Epoch = 0, loss1 = 1.2856, accuracy=0.6182
# Epoch = 10, loss1 = 7.8009, accuracy=0.7522
# Epoch = 20, loss1 = 8.1035, accuracy=0.7522
# Epoch = 30, loss1 = 8.0868, accuracy=0.7522
# Epoch = 40, loss1 = 8.0258, accuracy=0.7606
# Epoch = 50, loss1 = 7.9773, accuracy=0.7878
# Epoch = 60, loss1 = 7.9680, accuracy=0.7913
# Epoch = 70, loss1 = 7.9606, accuracy=0.7933
# Epoch = 80, loss1 = 7.9574, accuracy=0.7950
# Epoch = 90, loss1 = 7.9543, accuracy=0.7959
# Epoch = 100, loss1 = 7.9571, accuracy=0.7949
# Epoch = 110, loss1 = 7.9515, accuracy=0.7967
# Epoch = 120, loss1 = 7.9507, accuracy=0.7968
# Epoch = 130, loss1 = 7.9495, accuracy=0.7971
# Epoch = 140, loss1 = 7.9489, accuracy=0.7973
# Epoch = 150, loss1 = 7.9495, accuracy=0.7975
# Epoch = 160, loss1 = 7.9496, accuracy=0.7970
# Epoch = 170, loss1 = 7.9489, accuracy=0.7977
# Epoch = 180, loss1 = 7.9466, accuracy=0.7982
# Epoch = 190, loss1 = 7.9463, accuracy=0.7987
# Epoch = 200, loss1 = 7.9455, accuracy=0.7986
# Epoch = 210, loss1 = 7.9466, accuracy=0.7978
# Epoch = 220, loss1 = 7.9449, accuracy=0.7994
# Epoch = 230, loss1 = 7.9443, accuracy=0.7996
# Epoch = 240, loss1 = 7.9438, accuracy=0.7991
# Epoch = 250, loss1 = 7.9436, accuracy=0.7995
# Epoch = 260, loss1 = 7.9444, accuracy=0.7994
# Epoch = 270, loss1 = 7.9435, accuracy=0.7991
# Epoch = 280, loss1 = 7.9419, accuracy=0.8003
# Epoch = 290, loss1 = 7.9422, accuracy=0.8005
# Epoch = 300, loss1 = 7.9422, accuracy=0.7999
# Epoch = 310, loss1 = 7.9422, accuracy=0.7999
# Epoch = 320, loss1 = 7.9430, accuracy=0.7989
# Epoch = 330, loss1 = 7.9413, accuracy=0.8007
# Epoch = 340, loss1 = 7.9394, accuracy=0.8021
# Epoch = 350, loss1 = 7.9391, accuracy=0.8011
# Epoch = 360, loss1 = 7.9383, accuracy=0.8021
# Epoch = 370, loss1 = 7.9419, accuracy=0.7995
# Epoch = 380, loss1 = 7.9380, accuracy=0.8013
# Epoch = 390, loss1 = 7.9371, accuracy=0.8026
# Epoch = 400, loss1 = 7.9366, accuracy=0.8026
# Epoch = 410, loss1 = 7.9364, accuracy=0.8025
# Epoch = 420, loss1 = 7.9355, accuracy=0.8030
# Epoch = 430, loss1 = 7.9375, accuracy=0.8014
# Epoch = 440, loss1 = 7.9484, accuracy=0.7961
# Epoch = 450, loss1 = 7.9367, accuracy=0.8029
#
#
# Epoch = 0, loss2 = 0.7269, accuracy=0.4507
# Epoch = 10, loss2 = 0.6345, accuracy=0.6722
# Epoch = 20, loss2 = 0.6154, accuracy=0.6772
# Epoch = 30, loss2 = 0.6050, accuracy=0.6808
# Epoch = 40, loss2 = 0.6017, accuracy=0.6823
# Epoch = 50, loss2 = 0.6007, accuracy=0.6828
# Epoch = 60, loss2 = 0.5992, accuracy=0.6828
# Epoch = 70, loss2 = 0.5981, accuracy=0.6841
# Epoch = 80, loss2 = 0.5974, accuracy=0.6855
# Epoch = 90, loss2 = 0.5967, accuracy=0.6873
# Epoch = 100, loss2 = 0.5960, accuracy=0.6876
# Epoch = 110, loss2 = 0.5953, accuracy=0.6866
# Epoch = 120, loss2 = 0.5946, accuracy=0.6870
# Epoch = 130, loss2 = 0.5938, accuracy=0.6859
# Epoch = 140, loss2 = 0.5930, accuracy=0.6866
# Epoch = 150, loss2 = 0.5925, accuracy=0.6845
# Epoch = 160, loss2 = 0.5917, accuracy=0.6860
# Epoch = 170, loss2 = 0.5910, accuracy=0.6863
# Epoch = 180, loss2 = 0.5907, accuracy=0.6857
# Epoch = 190, loss2 = 0.5899, accuracy=0.6876
# Epoch = 200, loss2 = 0.5891, accuracy=0.6863
# Epoch = 210, loss2 = 0.5885, accuracy=0.6866
# Epoch = 220, loss2 = 0.5884, accuracy=0.6864
# Epoch = 230, loss2 = 0.5877, accuracy=0.6862
# Epoch = 240, loss2 = 0.5879, accuracy=0.6856
# Epoch = 250, loss2 = 0.5864, accuracy=0.6863
# Epoch = 260, loss2 = 0.5860, accuracy=0.6881
# Epoch = 270, loss2 = 0.5853, accuracy=0.6895
# Epoch = 280, loss2 = 0.5850, accuracy=0.6888
# Epoch = 290, loss2 = 0.5852, accuracy=0.6882
# Epoch = 300, loss2 = 0.5841, accuracy=0.6891
# Epoch = 310, loss2 = 0.5836, accuracy=0.6903
# Epoch = 320, loss2 = 0.5907, accuracy=0.6838
# Epoch = 330, loss2 = 0.5825, accuracy=0.6892
# Epoch = 340, loss2 = 0.5825, accuracy=0.6912
# Epoch = 350, loss2 = 0.5815, accuracy=0.6906
# Epoch = 360, loss2 = 0.5806, accuracy=0.6907
# Epoch = 370, loss2 = 0.5803, accuracy=0.6917
# Epoch = 380, loss2 = 0.5803, accuracy=0.6937
# Epoch = 390, loss2 = 0.5809, accuracy=0.6938
# Epoch = 400, loss2 = 0.5816, accuracy=0.6923
# Epoch = 410, loss2 = 0.5791, accuracy=0.6942
# Epoch = 420, loss2 = 0.5797, accuracy=0.6925
# Epoch = 430, loss2 = 0.5775, accuracy=0.6952
# Epoch = 440, loss2 = 0.5803, accuracy=0.6937
# Epoch = 450, loss2 = 0.5780, accuracy=0.6934
# Epoch = 460, loss2 = 0.5824, accuracy=0.6891
# Epoch = 470, loss2 = 0.5787, accuracy=0.6935
# Epoch = 480, loss2 = 0.5763, accuracy=0.6956
# Epoch = 490, loss2 = 0.5744, accuracy=0.6949
# Epoch = 500, loss2 = 0.5745, accuracy=0.6960
# Epoch = 510, loss2 = 0.5752, accuracy=0.6960
# Epoch = 520, loss2 = 0.5755, accuracy=0.6971
# Epoch = 530, loss2 = 0.5747, accuracy=0.6959
# Epoch = 540, loss2 = 0.5718, accuracy=0.6978
# Epoch = 550, loss2 = 0.5716, accuracy=0.6967
# Epoch = 560, loss2 = 0.5750, accuracy=0.6967
# Epoch = 570, loss2 = 0.5730, accuracy=0.6963
# Epoch = 580, loss2 = 0.5714, accuracy=0.6988
# Epoch = 590, loss2 = 0.5719, accuracy=0.6967
# Epoch = 600, loss2 = 0.5691, accuracy=0.6998
# Epoch = 610, loss2 = 0.5741, accuracy=0.6939
# Epoch = 620, loss2 = 0.5711, accuracy=0.6978
# Epoch = 630, loss2 = 0.5688, accuracy=0.7013
# Epoch = 640, loss2 = 0.5697, accuracy=0.6996
# Epoch = 650, loss2 = 0.5698, accuracy=0.6993
# Epoch = 660, loss2 = 0.5667, accuracy=0.6999
# Epoch = 670, loss2 = 0.5712, accuracy=0.6968
# Epoch = 680, loss2 = 0.5658, accuracy=0.7020
# Epoch = 690, loss2 = 0.5686, accuracy=0.6985
# Epoch = 700, loss2 = 0.5691, accuracy=0.7010
# Epoch = 710, loss2 = 0.5650, accuracy=0.7002
# Epoch = 720, loss2 = 0.5674, accuracy=0.6993
# Epoch = 730, loss2 = 0.5686, accuracy=0.6977
# Epoch = 740, loss2 = 0.5632, accuracy=0.7036
# Epoch = 750, loss2 = 0.5673, accuracy=0.7031
# Epoch = 760, loss2 = 0.5644, accuracy=0.7010
# Epoch = 770, loss2 = 0.5634, accuracy=0.7054
# Epoch = 780, loss2 = 0.5614, accuracy=0.7043
# Epoch = 790, loss2 = 0.5606, accuracy=0.7052
# Epoch = 800, loss2 = 0.5645, accuracy=0.7047
# Epoch = 810, loss2 = 0.5620, accuracy=0.7056
# Epoch = 820, loss2 = 0.5630, accuracy=0.7038
# Epoch = 830, loss2 = 0.5606, accuracy=0.7072
# Epoch = 840, loss2 = 0.5639, accuracy=0.7021
# Epoch = 850, loss2 = 0.5627, accuracy=0.7020
# Epoch = 860, loss2 = 0.5591, accuracy=0.7061
# Epoch = 870, loss2 = 0.5579, accuracy=0.7074
# Epoch = 880, loss2 = 0.5621, accuracy=0.7035
# Epoch = 890, loss2 = 0.5644, accuracy=0.7006
# Epoch = 900, loss2 = 0.5664, accuracy=0.6991
# Epoch = 910, loss2 = 0.5577, accuracy=0.7065
# Epoch = 920, loss2 = 0.5565, accuracy=0.7083
# Epoch = 930, loss2 = 0.5553, accuracy=0.7099
# Epoch = 940, loss2 = 0.5593, accuracy=0.7043
# Epoch = 950, loss2 = 0.5609, accuracy=0.7072
# Epoch = 960, loss2 = 0.5557, accuracy=0.7089
# Epoch = 970, loss2 = 0.5579, accuracy=0.7068
# Epoch = 980, loss2 = 0.5544, accuracy=0.7095
# Epoch = 990, loss2 = 0.5531, accuracy=0.7097
# Epoch = 1000, loss2 = 0.5585, accuracy=0.7046
# Epoch = 1010, loss2 = 0.5561, accuracy=0.7097
# Epoch = 1020, loss2 = 0.5538, accuracy=0.7115
# Epoch = 1030, loss2 = 0.5522, accuracy=0.7114
# Epoch = 1040, loss2 = 0.5513, accuracy=0.7106
# Epoch = 1050, loss2 = 0.5549, accuracy=0.7100
# Epoch = 1060, loss2 = 0.5524, accuracy=0.7113
# Epoch = 1070, loss2 = 0.5550, accuracy=0.7085
# Epoch = 1080, loss2 = 0.5522, accuracy=0.7118
# Epoch = 1090, loss2 = 0.5505, accuracy=0.7107
# Epoch = 1100, loss2 = 0.5504, accuracy=0.7146
# Epoch = 1110, loss2 = 0.5546, accuracy=0.7063
# Epoch = 1120, loss2 = 0.5527, accuracy=0.7113
# Epoch = 1130, loss2 = 0.5493, accuracy=0.7140
# Epoch = 1140, loss2 = 0.5509, accuracy=0.7143
# Epoch = 1150, loss2 = 0.5482, accuracy=0.7135
# Epoch = 1160, loss2 = 0.5533, accuracy=0.7110
# Epoch = 1170, loss2 = 0.5492, accuracy=0.7136
# Epoch = 1180, loss2 = 0.5467, accuracy=0.7164
# Epoch = 1190, loss2 = 0.5551, accuracy=0.7067
# Epoch = 1200, loss2 = 0.5461, accuracy=0.7140
# Epoch = 1210, loss2 = 0.5456, accuracy=0.7164
# Epoch = 1220, loss2 = 0.5476, accuracy=0.7144
# Epoch = 1230, loss2 = 0.5446, accuracy=0.7147
# Epoch = 1240, loss2 = 0.5453, accuracy=0.7153
# Epoch = 1250, loss2 = 0.5465, accuracy=0.7158
# Epoch = 1260, loss2 = 0.5470, accuracy=0.7133
# Epoch = 1270, loss2 = 0.5470, accuracy=0.7142
# Epoch = 1280, loss2 = 0.5531, accuracy=0.7093
# Epoch = 1290, loss2 = 0.5448, accuracy=0.7149
# Epoch = 1300, loss2 = 0.5442, accuracy=0.7178
# Epoch = 1310, loss2 = 0.5488, accuracy=0.7093
# Epoch = 1320, loss2 = 0.5415, accuracy=0.7189
# Epoch = 1330, loss2 = 0.5394, accuracy=0.7214
# Epoch = 1340, loss2 = 0.5416, accuracy=0.7203
# Epoch = 1350, loss2 = 0.5436, accuracy=0.7182
# Epoch = 1360, loss2 = 0.5570, accuracy=0.7050
# Epoch = 1370, loss2 = 0.5496, accuracy=0.7103
# Epoch = 1380, loss2 = 0.5446, accuracy=0.7180
# Epoch = 1390, loss2 = 0.5418, accuracy=0.7196
# Epoch = 1400, loss2 = 0.5402, accuracy=0.7211
# Epoch = 1410, loss2 = 0.5390, accuracy=0.7207
# Epoch = 1420, loss2 = 0.5750, accuracy=0.6912
# Epoch = 1430, loss2 = 0.5490, accuracy=0.7156
# Epoch = 1440, loss2 = 0.5454, accuracy=0.7168
#
#
# Epoch = 0, loss3 = 0.6924, accuracy=0.5929
# Epoch = 10, loss3 = 0.6365, accuracy=0.6544
# Epoch = 20, loss3 = 0.6232, accuracy=0.6544
# Epoch = 30, loss3 = 0.6010, accuracy=0.6616
# Epoch = 40, loss3 = 0.5828, accuracy=0.6833
# Epoch = 50, loss3 = 0.5719, accuracy=0.6903
# Epoch = 60, loss3 = 0.5649, accuracy=0.6946
# Epoch = 70, loss3 = 0.5572, accuracy=0.7000
# Epoch = 80, loss3 = 0.5459, accuracy=0.7108
# Epoch = 90, loss3 = 0.5328, accuracy=0.7246
# Epoch = 100, loss3 = 0.5118, accuracy=0.7409
# Epoch = 110, loss3 = 0.4960, accuracy=0.7529
# Epoch = 120, loss3 = 0.4822, accuracy=0.7636
# Epoch = 130, loss3 = 0.4740, accuracy=0.7673
# Epoch = 140, loss3 = 0.4544, accuracy=0.7826
# Epoch = 150, loss3 = 0.4466, accuracy=0.7844
# Epoch = 160, loss3 = 0.4309, accuracy=0.7950
# Epoch = 170, loss3 = 0.4176, accuracy=0.8044
# Epoch = 180, loss3 = 0.4130, accuracy=0.8048
# Epoch = 190, loss3 = 0.4179, accuracy=0.7995
# Epoch = 200, loss3 = 0.3915, accuracy=0.8178
# Epoch = 210, loss3 = 0.3906, accuracy=0.8160
# Epoch = 220, loss3 = 0.4116, accuracy=0.8007
# Epoch = 230, loss3 = 0.3738, accuracy=0.8264
# Epoch = 240, loss3 = 0.3563, accuracy=0.8390
# Epoch = 250, loss3 = 0.3578, accuracy=0.8362
# Epoch = 260, loss3 = 0.3740, accuracy=0.8226
# Epoch = 270, loss3 = 0.3401, accuracy=0.8468
# Epoch = 280, loss3 = 0.3485, accuracy=0.8376
# Epoch = 290, loss3 = 0.3274, accuracy=0.8540
# Epoch = 300, loss3 = 0.3433, accuracy=0.8403
# Epoch = 310, loss3 = 0.3163, accuracy=0.8595
# Epoch = 320, loss3 = 0.3113, accuracy=0.8624
# Epoch = 330, loss3 = 0.3049, accuracy=0.8655
# Epoch = 340, loss3 = 0.2999, accuracy=0.8684
# Epoch = 350, loss3 = 0.2998, accuracy=0.8675
# Epoch = 360, loss3 = 0.3145, accuracy=0.8558
# Epoch = 370, loss3 = 0.2964, accuracy=0.8674
# Epoch = 380, loss3 = 0.3011, accuracy=0.8627
# Epoch = 390, loss3 = 0.2909, accuracy=0.8687
# Epoch = 400, loss3 = 0.2908, accuracy=0.8687
# Epoch = 410, loss3 = 0.2994, accuracy=0.8623
# Epoch = 420, loss3 = 0.2724, accuracy=0.8798
# Epoch = 430, loss3 = 0.2770, accuracy=0.8753
# Epoch = 440, loss3 = 0.2839, accuracy=0.8707
# Epoch = 450, loss3 = 0.2833, accuracy=0.8707
# Epoch = 460, loss3 = 0.2593, accuracy=0.8864
# Epoch = 470, loss3 = 0.2914, accuracy=0.8676
# Epoch = 480, loss3 = 0.2693, accuracy=0.8761
# Epoch = 490, loss3 = 0.2526, accuracy=0.8886
# Epoch = 500, loss3 = 0.2513, accuracy=0.8892
# Epoch = 510, loss3 = 0.4569, accuracy=0.7906
# Epoch = 520, loss3 = 0.4498, accuracy=0.7588
# Epoch = 530, loss3 = 0.3631, accuracy=0.8315
# Epoch = 540, loss3 = 0.3108, accuracy=0.8568
# Epoch = 550, loss3 = 0.2810, accuracy=0.8725
# Epoch = 560, loss3 = 0.2637, accuracy=0.8814
# Epoch = 570, loss3 = 0.2554, accuracy=0.8857
# Epoch = 580, loss3 = 0.2492, accuracy=0.8886
# Epoch = 590, loss3 = 0.2451, accuracy=0.8908
# Epoch = 600, loss3 = 0.2417, accuracy=0.8931
# Epoch = 610, loss3 = 0.2388, accuracy=0.8947
# Epoch = 620, loss3 = 0.2397, accuracy=0.8931
# Epoch = 630, loss3 = 0.2356, accuracy=0.8945
# Epoch = 640, loss3 = 0.2323, accuracy=0.8976
# Epoch = 650, loss3 = 0.2390, accuracy=0.8924
#
#
# Epoch = 0, loss1 = 7.9366, accuracy=0.8019
# Epoch = 10, loss1 = 7.9346, accuracy=0.8040
# Epoch = 20, loss1 = 7.9335, accuracy=0.8042
# Epoch = 30, loss1 = 7.9335, accuracy=0.8047
# Epoch = 40, loss1 = 7.9325, accuracy=0.8049
# Epoch = 50, loss1 = 7.9319, accuracy=0.8048
# Epoch = 60, loss1 = 7.9366, accuracy=0.8021
# Epoch = 70, loss1 = 7.9346, accuracy=0.8024
# Epoch = 80, loss1 = 7.9325, accuracy=0.8043
# Epoch = 90, loss1 = 7.9305, accuracy=0.8053
# Epoch = 100, loss1 = 7.9300, accuracy=0.8054
# Epoch = 110, loss1 = 7.9292, accuracy=0.8061
# Epoch = 120, loss1 = 7.9298, accuracy=0.8052
# Epoch = 130, loss1 = 7.9282, accuracy=0.8065
# Epoch = 140, loss1 = 7.9339, accuracy=0.8033
# Epoch = 150, loss1 = 7.9318, accuracy=0.8040
# Epoch = 160, loss1 = 7.9277, accuracy=0.8066
# Epoch = 170, loss1 = 7.9287, accuracy=0.8049
# Epoch = 180, loss1 = 7.9312, accuracy=0.8048
# Epoch = 190, loss1 = 7.9257, accuracy=0.8068
# Epoch = 200, loss1 = 7.9269, accuracy=0.8061
# Epoch = 210, loss1 = 7.9262, accuracy=0.8063
# Epoch = 220, loss1 = 7.9281, accuracy=0.8064
# Epoch = 230, loss1 = 7.9248, accuracy=0.8062
# Epoch = 240, loss1 = 7.9256, accuracy=0.8061
# Epoch = 250, loss1 = 7.9237, accuracy=0.8074
# Epoch = 260, loss1 = 7.9279, accuracy=0.8063
# Epoch = 270, loss1 = 7.9212, accuracy=0.8091
# Epoch = 280, loss1 = 7.9203, accuracy=0.8094
# Epoch = 290, loss1 = 7.9197, accuracy=0.8101
# Epoch = 300, loss1 = 7.9236, accuracy=0.8082
# Epoch = 310, loss1 = 7.9208, accuracy=0.8075
# Epoch = 320, loss1 = 7.9187, accuracy=0.8095
# Epoch = 330, loss1 = 7.9184, accuracy=0.8100
# Epoch = 340, loss1 = 7.9232, accuracy=0.8080
# Epoch = 350, loss1 = 7.9171, accuracy=0.8098
# Epoch = 360, loss1 = 7.9180, accuracy=0.8093
# Epoch = 370, loss1 = 7.9265, accuracy=0.8052
# Epoch = 380, loss1 = 7.9210, accuracy=0.8103
# Epoch = 390, loss1 = 7.9147, accuracy=0.8125
# Epoch = 400, loss1 = 7.9154, accuracy=0.8120
# Epoch = 410, loss1 = 7.9173, accuracy=0.8088
# Epoch = 420, loss1 = 7.9186, accuracy=0.8114
# Epoch = 430, loss1 = 7.9171, accuracy=0.8085
# Epoch = 440, loss1 = 7.9165, accuracy=0.8097
# Epoch = 450, loss1 = 7.9111, accuracy=0.8131
#
#
# Epoch = 0, loss2 = 0.5453, accuracy=0.7162
# Epoch = 10, loss2 = 0.5405, accuracy=0.7189
# Epoch = 20, loss2 = 0.5386, accuracy=0.7222
# Epoch = 30, loss2 = 0.5374, accuracy=0.7229
# Epoch = 40, loss2 = 0.5462, accuracy=0.7108
# Epoch = 50, loss2 = 0.5446, accuracy=0.7150
# Epoch = 60, loss2 = 0.5480, accuracy=0.7115
# Epoch = 70, loss2 = 0.5538, accuracy=0.7025
# Epoch = 80, loss2 = 0.5482, accuracy=0.7106
# Epoch = 90, loss2 = 0.5433, accuracy=0.7161
# Epoch = 100, loss2 = 0.5383, accuracy=0.7203
# Epoch = 110, loss2 = 0.5352, accuracy=0.7243
# Epoch = 120, loss2 = 0.5519, accuracy=0.7057
# Epoch = 130, loss2 = 0.5461, accuracy=0.7118
# Epoch = 140, loss2 = 0.5394, accuracy=0.7203
# Epoch = 150, loss2 = 0.5372, accuracy=0.7207
# Epoch = 160, loss2 = 0.5337, accuracy=0.7243
# Epoch = 170, loss2 = 0.5399, accuracy=0.7201
# Epoch = 180, loss2 = 0.5502, accuracy=0.7101
# Epoch = 190, loss2 = 0.5361, accuracy=0.7215
# Epoch = 200, loss2 = 0.5405, accuracy=0.7187
# Epoch = 210, loss2 = 0.5346, accuracy=0.7254
# Epoch = 220, loss2 = 0.5368, accuracy=0.7228
# Epoch = 230, loss2 = 0.5336, accuracy=0.7233
# Epoch = 240, loss2 = 0.5345, accuracy=0.7211
# Epoch = 250, loss2 = 0.5336, accuracy=0.7241
# Epoch = 260, loss2 = 0.5298, accuracy=0.7297
# Epoch = 270, loss2 = 0.5310, accuracy=0.7259
# Epoch = 280, loss2 = 0.5417, accuracy=0.7178
# Epoch = 290, loss2 = 0.5349, accuracy=0.7235
# Epoch = 300, loss2 = 0.5308, accuracy=0.7250
# Epoch = 310, loss2 = 0.5296, accuracy=0.7278
# Epoch = 320, loss2 = 0.5457, accuracy=0.7101
# Epoch = 330, loss2 = 0.5410, accuracy=0.7187
# Epoch = 340, loss2 = 0.5333, accuracy=0.7262
# Epoch = 350, loss2 = 0.5294, accuracy=0.7282
# Epoch = 360, loss2 = 0.5311, accuracy=0.7262
# Epoch = 370, loss2 = 0.5264, accuracy=0.7302
# Epoch = 380, loss2 = 0.5264, accuracy=0.7284
# Epoch = 390, loss2 = 0.5241, accuracy=0.7329
# Epoch = 400, loss2 = 0.5258, accuracy=0.7312
# Epoch = 410, loss2 = 0.5362, accuracy=0.7189
# Epoch = 420, loss2 = 0.5506, accuracy=0.7124
# Epoch = 430, loss2 = 0.5341, accuracy=0.7199
# Epoch = 440, loss2 = 0.5280, accuracy=0.7290
# Epoch = 450, loss2 = 0.5260, accuracy=0.7308
# Epoch = 460, loss2 = 0.5231, accuracy=0.7327
# Epoch = 470, loss2 = 0.5245, accuracy=0.7307
# Epoch = 480, loss2 = 0.5332, accuracy=0.7217
# Epoch = 490, loss2 = 0.5279, accuracy=0.7283
# Epoch = 500, loss2 = 0.5325, accuracy=0.7255
# Epoch = 510, loss2 = 0.5256, accuracy=0.7283
# Epoch = 520, loss2 = 0.5286, accuracy=0.7255
# Epoch = 530, loss2 = 0.5277, accuracy=0.7311
# Epoch = 540, loss2 = 0.5232, accuracy=0.7308
# Epoch = 550, loss2 = 0.5207, accuracy=0.7339
# Epoch = 560, loss2 = 0.5207, accuracy=0.7334
# Epoch = 570, loss2 = 0.5265, accuracy=0.7282
# Epoch = 580, loss2 = 0.5442, accuracy=0.7124
# Epoch = 590, loss2 = 0.5281, accuracy=0.7290
# Epoch = 600, loss2 = 0.5222, accuracy=0.7332
# Epoch = 610, loss2 = 0.5225, accuracy=0.7333
# Epoch = 620, loss2 = 0.5195, accuracy=0.7340
# Epoch = 630, loss2 = 0.5191, accuracy=0.7330
# Epoch = 640, loss2 = 0.5169, accuracy=0.7344
# Epoch = 650, loss2 = 0.5422, accuracy=0.7158
# Epoch = 660, loss2 = 0.5224, accuracy=0.7290
# Epoch = 670, loss2 = 0.5168, accuracy=0.7358
# Epoch = 680, loss2 = 0.5181, accuracy=0.7348
# Epoch = 690, loss2 = 0.5160, accuracy=0.7369
# Epoch = 700, loss2 = 0.5151, accuracy=0.7365
# Epoch = 710, loss2 = 0.5610, accuracy=0.7017
# Epoch = 720, loss2 = 0.5263, accuracy=0.7265
# Epoch = 730, loss2 = 0.5188, accuracy=0.7366
# Epoch = 740, loss2 = 0.5160, accuracy=0.7354
# Epoch = 750, loss2 = 0.5160, accuracy=0.7368
# Epoch = 760, loss2 = 0.5137, accuracy=0.7384
# Epoch = 770, loss2 = 0.5231, accuracy=0.7297
# Epoch = 780, loss2 = 0.5244, accuracy=0.7262
# Epoch = 790, loss2 = 0.5482, accuracy=0.7178
# Epoch = 800, loss2 = 0.5215, accuracy=0.7312
# Epoch = 810, loss2 = 0.5202, accuracy=0.7329
# Epoch = 820, loss2 = 0.5130, accuracy=0.7370
# Epoch = 830, loss2 = 0.5141, accuracy=0.7337
# Epoch = 840, loss2 = 0.5134, accuracy=0.7394
# Epoch = 850, loss2 = 0.5125, accuracy=0.7384
# Epoch = 860, loss2 = 0.5144, accuracy=0.7358
# Epoch = 870, loss2 = 0.5239, accuracy=0.7305
# Epoch = 880, loss2 = 0.5334, accuracy=0.7200
# Epoch = 890, loss2 = 0.5203, accuracy=0.7289
# Epoch = 900, loss2 = 0.5131, accuracy=0.7363
# Epoch = 910, loss2 = 0.5113, accuracy=0.7383
# Epoch = 920, loss2 = 0.5122, accuracy=0.7384
# Epoch = 930, loss2 = 0.5129, accuracy=0.7379
# Epoch = 940, loss2 = 0.5093, accuracy=0.7401
# Epoch = 950, loss2 = 0.5113, accuracy=0.7383
# Epoch = 960, loss2 = 0.5160, accuracy=0.7320
# Epoch = 970, loss2 = 0.5093, accuracy=0.7406
# Epoch = 980, loss2 = 0.5077, accuracy=0.7418
# Epoch = 990, loss2 = 0.5061, accuracy=0.7418
# Epoch = 1000, loss2 = 0.5134, accuracy=0.7361
# Epoch = 1010, loss2 = 0.5135, accuracy=0.7345
# Epoch = 1020, loss2 = 0.5087, accuracy=0.7411
# Epoch = 1030, loss2 = 0.5062, accuracy=0.7420
# Epoch = 1040, loss2 = 0.5126, accuracy=0.7366
# Epoch = 1050, loss2 = 0.5050, accuracy=0.7444
# Epoch = 1060, loss2 = 0.5063, accuracy=0.7398
# Epoch = 1070, loss2 = 0.5134, accuracy=0.7369
# Epoch = 1080, loss2 = 0.5142, accuracy=0.7344
# Epoch = 1090, loss2 = 0.5138, accuracy=0.7350
# Epoch = 1100, loss2 = 0.5094, accuracy=0.7416
# Epoch = 1110, loss2 = 0.5367, accuracy=0.7233
# Epoch = 1120, loss2 = 0.5407, accuracy=0.7308
# Epoch = 1130, loss2 = 0.5096, accuracy=0.7400
# Epoch = 1140, loss2 = 0.5055, accuracy=0.7400
# Epoch = 1150, loss2 = 0.5027, accuracy=0.7444
# Epoch = 1160, loss2 = 0.5013, accuracy=0.7458
# Epoch = 1170, loss2 = 0.5044, accuracy=0.7418
# Epoch = 1180, loss2 = 0.5001, accuracy=0.7448
# Epoch = 1190, loss2 = 0.5217, accuracy=0.7266
# Epoch = 1200, loss2 = 0.5452, accuracy=0.7161
# Epoch = 1210, loss2 = 0.5214, accuracy=0.7286
# Epoch = 1220, loss2 = 0.5084, accuracy=0.7366
# Epoch = 1230, loss2 = 0.5098, accuracy=0.7383
# Epoch = 1240, loss2 = 0.5084, accuracy=0.7362
# Epoch = 1250, loss2 = 0.5014, accuracy=0.7449
# Epoch = 1260, loss2 = 0.4997, accuracy=0.7469
# Epoch = 1270, loss2 = 0.4986, accuracy=0.7476
# Epoch = 1280, loss2 = 0.4976, accuracy=0.7487
# Epoch = 1290, loss2 = 0.5000, accuracy=0.7452
# Epoch = 1300, loss2 = 0.4969, accuracy=0.7479
# Epoch = 1310, loss2 = 0.5003, accuracy=0.7452
# Epoch = 1320, loss2 = 0.4992, accuracy=0.7444
# Epoch = 1330, loss2 = 0.5003, accuracy=0.7433
# Epoch = 1340, loss2 = 0.4990, accuracy=0.7458
# Epoch = 1350, loss2 = 0.4997, accuracy=0.7440
# Epoch = 1360, loss2 = 0.5035, accuracy=0.7452
# Epoch = 1370, loss2 = 0.5085, accuracy=0.7348
# Epoch = 1380, loss2 = 0.4987, accuracy=0.7477
# Epoch = 1390, loss2 = 0.4943, accuracy=0.7497
# Epoch = 1400, loss2 = 0.4950, accuracy=0.7473
# Epoch = 1410, loss2 = 0.4956, accuracy=0.7473
# Epoch = 1420, loss2 = 0.4970, accuracy=0.7470
# Epoch = 1430, loss2 = 0.5049, accuracy=0.7419
# Epoch = 1440, loss2 = 0.4931, accuracy=0.7498
#
#
# Epoch = 0, loss3 = 0.2293, accuracy=0.8976
# Epoch = 10, loss3 = 0.2388, accuracy=0.8918
# Epoch = 20, loss3 = 0.2350, accuracy=0.8937
# Epoch = 30, loss3 = 0.2318, accuracy=0.8937
# Epoch = 40, loss3 = 0.2315, accuracy=0.8953
# Epoch = 50, loss3 = 0.2224, accuracy=0.9006
# Epoch = 60, loss3 = 0.2217, accuracy=0.9001
# Epoch = 70, loss3 = 0.2207, accuracy=0.9002
# Epoch = 80, loss3 = 0.2866, accuracy=0.8624
# Epoch = 90, loss3 = 0.3698, accuracy=0.8159
# Epoch = 100, loss3 = 0.7641, accuracy=0.6932
# Epoch = 110, loss3 = 0.5262, accuracy=0.6907
# Epoch = 120, loss3 = 0.4892, accuracy=0.7433
# Epoch = 130, loss3 = 0.4468, accuracy=0.7833
# Epoch = 140, loss3 = 0.3847, accuracy=0.8203
# Epoch = 150, loss3 = 0.3311, accuracy=0.8517
# Epoch = 160, loss3 = 0.3004, accuracy=0.8664
# Epoch = 170, loss3 = 0.2803, accuracy=0.8767
# Epoch = 180, loss3 = 0.2672, accuracy=0.8825
# Epoch = 190, loss3 = 0.2630, accuracy=0.8819
# Epoch = 200, loss3 = 0.2510, accuracy=0.8880
# Epoch = 210, loss3 = 0.2434, accuracy=0.8927
# Epoch = 220, loss3 = 0.2421, accuracy=0.8918
# Epoch = 230, loss3 = 0.2393, accuracy=0.8914
# Epoch = 240, loss3 = 0.2353, accuracy=0.8945
# Epoch = 250, loss3 = 0.2340, accuracy=0.8927
# Epoch = 260, loss3 = 0.2273, accuracy=0.8980
# Epoch = 270, loss3 = 0.2248, accuracy=0.8986
# Epoch = 280, loss3 = 0.2556, accuracy=0.8800
# Epoch = 290, loss3 = 0.2316, accuracy=0.8915
# Epoch = 300, loss3 = 0.2250, accuracy=0.8954
# Epoch = 310, loss3 = 0.2203, accuracy=0.8988
# Epoch = 320, loss3 = 0.2148, accuracy=0.9021
# Epoch = 330, loss3 = 0.4159, accuracy=0.8195
# Epoch = 340, loss3 = 0.2836, accuracy=0.8669
# Epoch = 350, loss3 = 0.3929, accuracy=0.7950
# Epoch = 360, loss3 = 0.3019, accuracy=0.8739
# Epoch = 370, loss3 = 0.2749, accuracy=0.8813
# Epoch = 380, loss3 = 0.2573, accuracy=0.8867
# Epoch = 390, loss3 = 0.2396, accuracy=0.8913
# Epoch = 400, loss3 = 0.2286, accuracy=0.8945
# Epoch = 410, loss3 = 0.2214, accuracy=0.8976
# Epoch = 420, loss3 = 0.2159, accuracy=0.8998
# Epoch = 430, loss3 = 0.2123, accuracy=0.9019
# Epoch = 440, loss3 = 0.2097, accuracy=0.9032
# Epoch = 450, loss3 = 0.2076, accuracy=0.9043
# Epoch = 460, loss3 = 0.2064, accuracy=0.9042
# Epoch = 470, loss3 = 0.2041, accuracy=0.9055
# Epoch = 480, loss3 = 0.2051, accuracy=0.9043
# Epoch = 490, loss3 = 0.2019, accuracy=0.9061
# Epoch = 500, loss3 = 0.2015, accuracy=0.9069
# Epoch = 510, loss3 = 0.2012, accuracy=0.9061
# Epoch = 520, loss3 = 0.2029, accuracy=0.9038
# Epoch = 530, loss3 = 0.2014, accuracy=0.9057
# Epoch = 540, loss3 = 0.2159, accuracy=0.8944
# Epoch = 550, loss3 = 0.1980, accuracy=0.9076
# Epoch = 560, loss3 = 0.2092, accuracy=0.8980
# Epoch = 570, loss3 = 0.1963, accuracy=0.9085
# Epoch = 580, loss3 = 0.1971, accuracy=0.9073
# Epoch = 590, loss3 = 0.1995, accuracy=0.9038
# Epoch = 600, loss3 = 0.2015, accuracy=0.9048
# Epoch = 610, loss3 = 0.1966, accuracy=0.9064
# Epoch = 620, loss3 = 0.2198, accuracy=0.8922
# Epoch = 630, loss3 = 0.2001, accuracy=0.9047
# Epoch = 640, loss3 = 0.2150, accuracy=0.8943
# Epoch = 650, loss3 = 0.1962, accuracy=0.9062
#
#
# Epoch = 0, loss1 = 7.9142, accuracy=0.8122
# Epoch = 10, loss1 = 7.9151, accuracy=0.8098
# Epoch = 20, loss1 = 7.9208, accuracy=0.8101
# Epoch = 30, loss1 = 7.9149, accuracy=0.8129
# Epoch = 40, loss1 = 7.9095, accuracy=0.8148
# Epoch = 50, loss1 = 7.9122, accuracy=0.8111
# Epoch = 60, loss1 = 7.9165, accuracy=0.8123
# Epoch = 70, loss1 = 7.9080, accuracy=0.8141
# Epoch = 80, loss1 = 7.9155, accuracy=0.8103
# Epoch = 90, loss1 = 7.9066, accuracy=0.8150
# Epoch = 100, loss1 = 7.9058, accuracy=0.8157
# Epoch = 110, loss1 = 7.9057, accuracy=0.8163
# Epoch = 120, loss1 = 7.9105, accuracy=0.8141
# Epoch = 130, loss1 = 7.9064, accuracy=0.8165
# Epoch = 140, loss1 = 7.9043, accuracy=0.8166
# Epoch = 150, loss1 = 7.9114, accuracy=0.8114
# Epoch = 160, loss1 = 7.9036, accuracy=0.8169
# Epoch = 170, loss1 = 7.9093, accuracy=0.8146
# Epoch = 180, loss1 = 7.9041, accuracy=0.8155
# Epoch = 190, loss1 = 7.9068, accuracy=0.8143
# Epoch = 200, loss1 = 7.9043, accuracy=0.8174
# Epoch = 210, loss1 = 7.9040, accuracy=0.8173
# Epoch = 220, loss1 = 7.9084, accuracy=0.8133
# Epoch = 230, loss1 = 7.9008, accuracy=0.8184
# Epoch = 240, loss1 = 7.9060, accuracy=0.8163
# Epoch = 250, loss1 = 7.9011, accuracy=0.8182
# Epoch = 260, loss1 = 7.8998, accuracy=0.8180
# Epoch = 270, loss1 = 7.9082, accuracy=0.8144
# Epoch = 280, loss1 = 7.9003, accuracy=0.8185
# Epoch = 290, loss1 = 7.9018, accuracy=0.8181
# Epoch = 300, loss1 = 7.8987, accuracy=0.8182
# Epoch = 310, loss1 = 7.9109, accuracy=0.8142
# Epoch = 320, loss1 = 7.9012, accuracy=0.8185
# Epoch = 330, loss1 = 7.9000, accuracy=0.8187
# Epoch = 340, loss1 = 7.8980, accuracy=0.8183
# Epoch = 350, loss1 = 7.8985, accuracy=0.8184
# Epoch = 360, loss1 = 7.9017, accuracy=0.8188
# Epoch = 370, loss1 = 7.9008, accuracy=0.8177
# Epoch = 380, loss1 = 7.8948, accuracy=0.8204
# Epoch = 390, loss1 = 7.8944, accuracy=0.8205
# Epoch = 400, loss1 = 7.9023, accuracy=0.8166
# Epoch = 410, loss1 = 7.8940, accuracy=0.8209
# Epoch = 420, loss1 = 7.9016, accuracy=0.8157
# Epoch = 430, loss1 = 7.8975, accuracy=0.8178
# Epoch = 440, loss1 = 7.8927, accuracy=0.8207
# Epoch = 450, loss1 = 7.8957, accuracy=0.8207
#
#
# Epoch = 0, loss2 = 0.4928, accuracy=0.7494
# Epoch = 10, loss2 = 0.4961, accuracy=0.7491
# Epoch = 20, loss2 = 0.4949, accuracy=0.7506
# Epoch = 30, loss2 = 0.4945, accuracy=0.7501
# Epoch = 40, loss2 = 0.5064, accuracy=0.7413
# Epoch = 50, loss2 = 0.5416, accuracy=0.7217
# Epoch = 60, loss2 = 0.5116, accuracy=0.7377
# Epoch = 70, loss2 = 0.5001, accuracy=0.7463
# Epoch = 80, loss2 = 0.4943, accuracy=0.7497
# Epoch = 90, loss2 = 0.4920, accuracy=0.7523
# Epoch = 100, loss2 = 0.4907, accuracy=0.7519
# Epoch = 110, loss2 = 0.4900, accuracy=0.7512
# Epoch = 120, loss2 = 0.4952, accuracy=0.7451
# Epoch = 130, loss2 = 0.4955, accuracy=0.7483
# Epoch = 140, loss2 = 0.4978, accuracy=0.7424
# Epoch = 150, loss2 = 0.4987, accuracy=0.7438
# Epoch = 160, loss2 = 0.4928, accuracy=0.7515
# Epoch = 170, loss2 = 0.4911, accuracy=0.7506
# Epoch = 180, loss2 = 0.4872, accuracy=0.7537
# Epoch = 190, loss2 = 0.4982, accuracy=0.7452
# Epoch = 200, loss2 = 0.4880, accuracy=0.7527
# Epoch = 210, loss2 = 0.4954, accuracy=0.7480
# Epoch = 220, loss2 = 0.4878, accuracy=0.7533
# Epoch = 230, loss2 = 0.4924, accuracy=0.7515
# Epoch = 240, loss2 = 0.4949, accuracy=0.7451
# Epoch = 250, loss2 = 0.4948, accuracy=0.7499
# Epoch = 260, loss2 = 0.4855, accuracy=0.7552
# Epoch = 270, loss2 = 0.4910, accuracy=0.7497
# Epoch = 280, loss2 = 0.4915, accuracy=0.7517
# Epoch = 290, loss2 = 0.4891, accuracy=0.7503
# Epoch = 300, loss2 = 0.4934, accuracy=0.7517
# Epoch = 310, loss2 = 0.4995, accuracy=0.7430
# Epoch = 320, loss2 = 0.4919, accuracy=0.7519
# Epoch = 330, loss2 = 0.4852, accuracy=0.7548
# Epoch = 340, loss2 = 0.4825, accuracy=0.7589
# Epoch = 350, loss2 = 0.4953, accuracy=0.7442
# Epoch = 360, loss2 = 0.4981, accuracy=0.7462
# Epoch = 370, loss2 = 0.5222, accuracy=0.7305
# Epoch = 380, loss2 = 0.4943, accuracy=0.7463
# Epoch = 390, loss2 = 0.5073, accuracy=0.7401
# Epoch = 400, loss2 = 0.4972, accuracy=0.7479
# Epoch = 410, loss2 = 0.4919, accuracy=0.7473
# Epoch = 420, loss2 = 0.4865, accuracy=0.7546
# Epoch = 430, loss2 = 0.4840, accuracy=0.7555
# Epoch = 440, loss2 = 0.4802, accuracy=0.7576
# Epoch = 450, loss2 = 0.4808, accuracy=0.7567
# Epoch = 460, loss2 = 0.4798, accuracy=0.7574
# Epoch = 470, loss2 = 0.4795, accuracy=0.7576
# Epoch = 480, loss2 = 0.4778, accuracy=0.7603
# Epoch = 490, loss2 = 0.4902, accuracy=0.7470
# Epoch = 500, loss2 = 0.4959, accuracy=0.7427
# Epoch = 510, loss2 = 0.4988, accuracy=0.7466
# Epoch = 520, loss2 = 0.4905, accuracy=0.7520
# Epoch = 530, loss2 = 0.4848, accuracy=0.7552
# Epoch = 540, loss2 = 0.4780, accuracy=0.7594
# Epoch = 550, loss2 = 0.4777, accuracy=0.7577
# Epoch = 560, loss2 = 0.4760, accuracy=0.7594
# Epoch = 570, loss2 = 0.4862, accuracy=0.7512
# Epoch = 580, loss2 = 0.4887, accuracy=0.7517
# Epoch = 590, loss2 = 0.4767, accuracy=0.7580
# Epoch = 600, loss2 = 0.4762, accuracy=0.7595
# Epoch = 610, loss2 = 0.4767, accuracy=0.7599
# Epoch = 620, loss2 = 0.4779, accuracy=0.7603
# Epoch = 630, loss2 = 0.4773, accuracy=0.7569
# Epoch = 640, loss2 = 0.4944, accuracy=0.7448
# Epoch = 650, loss2 = 0.4884, accuracy=0.7503
# Epoch = 660, loss2 = 0.4810, accuracy=0.7548
# Epoch = 670, loss2 = 0.4744, accuracy=0.7613
# Epoch = 680, loss2 = 0.4758, accuracy=0.7598
# Epoch = 690, loss2 = 0.4740, accuracy=0.7614
# Epoch = 700, loss2 = 0.4723, accuracy=0.7632
# Epoch = 710, loss2 = 0.4878, accuracy=0.7510
# Epoch = 720, loss2 = 0.4864, accuracy=0.7509
# Epoch = 730, loss2 = 0.4739, accuracy=0.7612
# Epoch = 740, loss2 = 0.4743, accuracy=0.7632
# Epoch = 750, loss2 = 0.4752, accuracy=0.7609
# Epoch = 760, loss2 = 0.4740, accuracy=0.7613
# Epoch = 770, loss2 = 0.4798, accuracy=0.7548
# Epoch = 780, loss2 = 0.4802, accuracy=0.7591
# Epoch = 790, loss2 = 0.4805, accuracy=0.7537
# Epoch = 800, loss2 = 0.4823, accuracy=0.7582
# Epoch = 810, loss2 = 0.4763, accuracy=0.7607
# Epoch = 820, loss2 = 0.4945, accuracy=0.7488
# Epoch = 830, loss2 = 0.4740, accuracy=0.7589
# Epoch = 840, loss2 = 0.4724, accuracy=0.7628
# Epoch = 850, loss2 = 0.4701, accuracy=0.7641
# Epoch = 860, loss2 = 0.4717, accuracy=0.7627
# Epoch = 870, loss2 = 0.4702, accuracy=0.7645
# Epoch = 880, loss2 = 0.4673, accuracy=0.7638
# Epoch = 890, loss2 = 0.4719, accuracy=0.7638
# Epoch = 900, loss2 = 0.4824, accuracy=0.7495
# Epoch = 910, loss2 = 0.4788, accuracy=0.7591
# Epoch = 920, loss2 = 0.4710, accuracy=0.7630
# Epoch = 930, loss2 = 0.4676, accuracy=0.7660
# Epoch = 940, loss2 = 0.4690, accuracy=0.7625
# Epoch = 950, loss2 = 0.4740, accuracy=0.7609
# Epoch = 960, loss2 = 0.4681, accuracy=0.7652
# Epoch = 970, loss2 = 0.4658, accuracy=0.7681
# Epoch = 980, loss2 = 0.4671, accuracy=0.7693
# Epoch = 990, loss2 = 0.4837, accuracy=0.7582
# Epoch = 1000, loss2 = 0.4692, accuracy=0.7648
# Epoch = 1010, loss2 = 0.4702, accuracy=0.7616
# Epoch = 1020, loss2 = 0.4705, accuracy=0.7631
# Epoch = 1030, loss2 = 0.4662, accuracy=0.7632
# Epoch = 1040, loss2 = 0.4697, accuracy=0.7610
# Epoch = 1050, loss2 = 0.4631, accuracy=0.7674
# Epoch = 1060, loss2 = 0.4845, accuracy=0.7574
# Epoch = 1070, loss2 = 0.4641, accuracy=0.7688
# Epoch = 1080, loss2 = 0.4729, accuracy=0.7588
# Epoch = 1090, loss2 = 0.4695, accuracy=0.7660
# Epoch = 1100, loss2 = 0.4676, accuracy=0.7627
# Epoch = 1110, loss2 = 0.4627, accuracy=0.7693
# Epoch = 1120, loss2 = 0.4642, accuracy=0.7655
# Epoch = 1130, loss2 = 0.4793, accuracy=0.7531
# Epoch = 1140, loss2 = 0.4667, accuracy=0.7667
# Epoch = 1150, loss2 = 0.4726, accuracy=0.7577
# Epoch = 1160, loss2 = 0.4627, accuracy=0.7689
# Epoch = 1170, loss2 = 0.4616, accuracy=0.7685
# Epoch = 1180, loss2 = 0.4740, accuracy=0.7570
# Epoch = 1190, loss2 = 0.4710, accuracy=0.7643
# Epoch = 1200, loss2 = 0.4662, accuracy=0.7619
# Epoch = 1210, loss2 = 0.4594, accuracy=0.7722
# Epoch = 1220, loss2 = 0.4750, accuracy=0.7620
# Epoch = 1230, loss2 = 0.4862, accuracy=0.7503
# Epoch = 1240, loss2 = 0.4790, accuracy=0.7589
# Epoch = 1250, loss2 = 0.4658, accuracy=0.7684
# Epoch = 1260, loss2 = 0.4607, accuracy=0.7674
# Epoch = 1270, loss2 = 0.4600, accuracy=0.7721
# Epoch = 1280, loss2 = 0.4624, accuracy=0.7673
# Epoch = 1290, loss2 = 0.4567, accuracy=0.7739
# Epoch = 1300, loss2 = 0.4662, accuracy=0.7668
# Epoch = 1310, loss2 = 0.4568, accuracy=0.7725
# Epoch = 1320, loss2 = 0.4573, accuracy=0.7702
# Epoch = 1330, loss2 = 0.4584, accuracy=0.7727
# Epoch = 1340, loss2 = 0.4577, accuracy=0.7706
# Epoch = 1350, loss2 = 0.4556, accuracy=0.7756
# Epoch = 1360, loss2 = 0.4654, accuracy=0.7670
# Epoch = 1370, loss2 = 0.4685, accuracy=0.7605
# Epoch = 1380, loss2 = 0.4688, accuracy=0.7657
# Epoch = 1390, loss2 = 0.4644, accuracy=0.7641
# Epoch = 1400, loss2 = 0.4589, accuracy=0.7720
# Epoch = 1410, loss2 = 0.4543, accuracy=0.7741
# Epoch = 1420, loss2 = 0.4589, accuracy=0.7678
# Epoch = 1430, loss2 = 0.4663, accuracy=0.7678
# Epoch = 1440, loss2 = 0.4907, accuracy=0.7704
#
#
# Epoch = 0, loss3 = 0.1932, accuracy=0.9081
# Epoch = 10, loss3 = 0.1958, accuracy=0.9066
# Epoch = 20, loss3 = 0.1904, accuracy=0.9105
# Epoch = 30, loss3 = 0.1941, accuracy=0.9088
# Epoch = 40, loss3 = 0.1912, accuracy=0.9103
# Epoch = 50, loss3 = 0.1931, accuracy=0.9078
# Epoch = 60, loss3 = 0.1917, accuracy=0.9080
# Epoch = 70, loss3 = 0.1869, accuracy=0.9119
# Epoch = 80, loss3 = 1.1679, accuracy=0.7332
# Epoch = 90, loss3 = 0.4902, accuracy=0.7343
# Epoch = 100, loss3 = 0.4153, accuracy=0.7962
# Epoch = 110, loss3 = 0.3687, accuracy=0.8393
# Epoch = 120, loss3 = 0.3338, accuracy=0.8548
# Epoch = 130, loss3 = 0.3034, accuracy=0.8676
# Epoch = 140, loss3 = 0.2761, accuracy=0.8798
# Epoch = 150, loss3 = 0.2561, accuracy=0.8881
# Epoch = 160, loss3 = 0.2410, accuracy=0.8931
# Epoch = 170, loss3 = 0.2297, accuracy=0.8961
# Epoch = 180, loss3 = 0.2211, accuracy=0.8996
# Epoch = 190, loss3 = 0.2144, accuracy=0.9021
# Epoch = 200, loss3 = 0.2093, accuracy=0.9039
# Epoch = 210, loss3 = 0.2053, accuracy=0.9053
# Epoch = 220, loss3 = 0.2020, accuracy=0.9066
# Epoch = 230, loss3 = 0.1992, accuracy=0.9078
# Epoch = 240, loss3 = 0.1968, accuracy=0.9084
# Epoch = 250, loss3 = 0.1947, accuracy=0.9089
# Epoch = 260, loss3 = 0.1929, accuracy=0.9095
# Epoch = 270, loss3 = 0.1912, accuracy=0.9101
# Epoch = 280, loss3 = 0.1898, accuracy=0.9105
# Epoch = 290, loss3 = 0.1886, accuracy=0.9111
# Epoch = 300, loss3 = 0.1874, accuracy=0.9117
# Epoch = 310, loss3 = 0.1863, accuracy=0.9121
# Epoch = 320, loss3 = 0.1860, accuracy=0.9124
# Epoch = 330, loss3 = 0.1847, accuracy=0.9129
# Epoch = 340, loss3 = 0.1843, accuracy=0.9135
# Epoch = 350, loss3 = 0.1902, accuracy=0.9082
# Epoch = 360, loss3 = 0.1919, accuracy=0.9058
# Epoch = 370, loss3 = 0.1902, accuracy=0.9073
# Epoch = 380, loss3 = 0.1960, accuracy=0.9029
# Epoch = 390, loss3 = 0.1834, accuracy=0.9126
# Epoch = 400, loss3 = 0.1813, accuracy=0.9135
# Epoch = 410, loss3 = 0.1806, accuracy=0.9142
# Epoch = 420, loss3 = 0.1999, accuracy=0.9005
# Epoch = 430, loss3 = 0.1937, accuracy=0.9048
# Epoch = 440, loss3 = 0.1867, accuracy=0.9110
# Epoch = 450, loss3 = 0.1824, accuracy=0.9125
# Epoch = 460, loss3 = 0.1796, accuracy=0.9147
# Epoch = 470, loss3 = 0.1802, accuracy=0.9142
# Epoch = 480, loss3 = 0.1852, accuracy=0.9104
# Epoch = 490, loss3 = 0.1841, accuracy=0.9115
# Epoch = 500, loss3 = 0.1769, accuracy=0.9165
# Epoch = 510, loss3 = 0.1907, accuracy=0.9058
# Epoch = 520, loss3 = 0.2019, accuracy=0.8996
# Epoch = 530, loss3 = 0.1871, accuracy=0.9081
# Epoch = 540, loss3 = 0.1884, accuracy=0.9064
# Epoch = 550, loss3 = 0.1930, accuracy=0.9038
# Epoch = 560, loss3 = 0.1919, accuracy=0.9044
# Epoch = 570, loss3 = 0.1804, accuracy=0.9135
# Epoch = 580, loss3 = 0.1960, accuracy=0.9019
# Epoch = 590, loss3 = 0.1907, accuracy=0.9051
# Epoch = 600, loss3 = 0.1934, accuracy=0.9035
# Epoch = 610, loss3 = 0.1887, accuracy=0.9062
# Epoch = 620, loss3 = 0.1893, accuracy=0.9059
# Epoch = 630, loss3 = 0.1888, accuracy=0.9061
# Epoch = 640, loss3 = 0.1918, accuracy=0.9041
# Epoch = 650, loss3 = 0.1858, accuracy=0.9079
#
#
# Epoch = 0, loss1 = 7.9004, accuracy=0.8181
# Epoch = 10, loss1 = 7.8967, accuracy=0.8197
# Epoch = 20, loss1 = 7.8912, accuracy=0.8218
# Epoch = 30, loss1 = 7.8977, accuracy=0.8174
# Epoch = 40, loss1 = 7.8940, accuracy=0.8196
# Epoch = 50, loss1 = 7.8933, accuracy=0.8219
# Epoch = 60, loss1 = 7.9003, accuracy=0.8185
# Epoch = 70, loss1 = 7.8977, accuracy=0.8188
# Epoch = 80, loss1 = 7.8922, accuracy=0.8220
# Epoch = 90, loss1 = 7.8907, accuracy=0.8208
# Epoch = 100, loss1 = 7.8984, accuracy=0.8173
# Epoch = 110, loss1 = 7.8917, accuracy=0.8205
# Epoch = 120, loss1 = 7.8880, accuracy=0.8233
# Epoch = 130, loss1 = 7.8961, accuracy=0.8206
# Epoch = 140, loss1 = 7.8951, accuracy=0.8203
# Epoch = 150, loss1 = 7.8911, accuracy=0.8222
# Epoch = 160, loss1 = 7.8872, accuracy=0.8240
# Epoch = 170, loss1 = 7.8869, accuracy=0.8232
# Epoch = 180, loss1 = 7.8912, accuracy=0.8206
# Epoch = 190, loss1 = 7.8930, accuracy=0.8195
# Epoch = 200, loss1 = 7.8882, accuracy=0.8219
# Epoch = 210, loss1 = 7.8858, accuracy=0.8249
# Epoch = 220, loss1 = 7.8944, accuracy=0.8200
# Epoch = 230, loss1 = 7.8946, accuracy=0.8196
# Epoch = 240, loss1 = 7.8908, accuracy=0.8227
# Epoch = 250, loss1 = 7.8851, accuracy=0.8245
# Epoch = 260, loss1 = 7.8885, accuracy=0.8210
# Epoch = 270, loss1 = 7.8923, accuracy=0.8198
# Epoch = 280, loss1 = 7.8867, accuracy=0.8224
# Epoch = 290, loss1 = 7.8829, accuracy=0.8254
# Epoch = 300, loss1 = 7.8856, accuracy=0.8252
# Epoch = 310, loss1 = 7.8827, accuracy=0.8260
# Epoch = 320, loss1 = 7.8854, accuracy=0.8249
# Epoch = 330, loss1 = 7.8815, accuracy=0.8258
# Epoch = 340, loss1 = 7.8830, accuracy=0.8243
# Epoch = 350, loss1 = 7.8873, accuracy=0.8221
# Epoch = 360, loss1 = 7.8878, accuracy=0.8216
# Epoch = 370, loss1 = 7.8899, accuracy=0.8194
# Epoch = 380, loss1 = 7.8871, accuracy=0.8222
# Epoch = 390, loss1 = 7.8809, accuracy=0.8259
# Epoch = 400, loss1 = 7.8886, accuracy=0.8230
# Epoch = 410, loss1 = 7.8851, accuracy=0.8245
# Epoch = 420, loss1 = 7.8879, accuracy=0.8227
# Epoch = 430, loss1 = 7.8833, accuracy=0.8257
# Epoch = 440, loss1 = 7.8770, accuracy=0.8280
# Epoch = 450, loss1 = 7.8834, accuracy=0.8240
#
#
# Epoch = 0, loss2 = 0.4886, accuracy=0.7616
# Epoch = 10, loss2 = 0.4664, accuracy=0.7631
# Epoch = 20, loss2 = 0.4608, accuracy=0.7688
# Epoch = 30, loss2 = 0.4869, accuracy=0.7484
# Epoch = 40, loss2 = 0.4620, accuracy=0.7702
# Epoch = 50, loss2 = 0.4539, accuracy=0.7742
# Epoch = 60, loss2 = 0.4527, accuracy=0.7767
# Epoch = 70, loss2 = 0.4520, accuracy=0.7761
# Epoch = 80, loss2 = 0.4538, accuracy=0.7746
# Epoch = 90, loss2 = 0.4534, accuracy=0.7750
# Epoch = 100, loss2 = 0.4568, accuracy=0.7729
# Epoch = 110, loss2 = 0.4502, accuracy=0.7764
# Epoch = 120, loss2 = 0.4723, accuracy=0.7581
# Epoch = 130, loss2 = 0.4654, accuracy=0.7661
# Epoch = 140, loss2 = 0.4583, accuracy=0.7713
# Epoch = 150, loss2 = 0.4583, accuracy=0.7689
# Epoch = 160, loss2 = 0.4514, accuracy=0.7754
# Epoch = 170, loss2 = 0.4530, accuracy=0.7729
# Epoch = 180, loss2 = 0.4487, accuracy=0.7783
# Epoch = 190, loss2 = 0.4487, accuracy=0.7782
# Epoch = 200, loss2 = 0.4527, accuracy=0.7778
# Epoch = 210, loss2 = 0.4750, accuracy=0.7635
# Epoch = 220, loss2 = 0.4526, accuracy=0.7774
# Epoch = 230, loss2 = 0.4533, accuracy=0.7753
# Epoch = 240, loss2 = 0.4490, accuracy=0.7763
# Epoch = 250, loss2 = 0.4480, accuracy=0.7770
# Epoch = 260, loss2 = 0.4494, accuracy=0.7772
# Epoch = 270, loss2 = 0.4479, accuracy=0.7774
# Epoch = 280, loss2 = 0.4504, accuracy=0.7750
# Epoch = 290, loss2 = 0.4568, accuracy=0.7695
# Epoch = 300, loss2 = 0.4532, accuracy=0.7765
# Epoch = 310, loss2 = 0.4469, accuracy=0.7814
# Epoch = 320, loss2 = 0.4466, accuracy=0.7783
# Epoch = 330, loss2 = 0.4468, accuracy=0.7767
# Epoch = 340, loss2 = 0.4533, accuracy=0.7759
# Epoch = 350, loss2 = 0.4486, accuracy=0.7729
# Epoch = 360, loss2 = 0.4528, accuracy=0.7763
# Epoch = 370, loss2 = 0.4582, accuracy=0.7678
# Epoch = 380, loss2 = 0.4554, accuracy=0.7754
# Epoch = 390, loss2 = 0.4538, accuracy=0.7699
# Epoch = 400, loss2 = 0.4533, accuracy=0.7788
# Epoch = 410, loss2 = 0.4523, accuracy=0.7746
# Epoch = 420, loss2 = 0.4459, accuracy=0.7778
# Epoch = 430, loss2 = 0.4447, accuracy=0.7793
# Epoch = 440, loss2 = 0.4442, accuracy=0.7799
# Epoch = 450, loss2 = 0.4462, accuracy=0.7772
# Epoch = 460, loss2 = 0.4458, accuracy=0.7801
# Epoch = 470, loss2 = 0.4440, accuracy=0.7781
# Epoch = 480, loss2 = 0.4432, accuracy=0.7789
# Epoch = 490, loss2 = 0.4467, accuracy=0.7789
# Epoch = 500, loss2 = 0.4571, accuracy=0.7674
# Epoch = 510, loss2 = 0.4606, accuracy=0.7717
# Epoch = 520, loss2 = 0.4479, accuracy=0.7764
# Epoch = 530, loss2 = 0.4444, accuracy=0.7817
# Epoch = 540, loss2 = 0.4406, accuracy=0.7820
# Epoch = 550, loss2 = 0.4494, accuracy=0.7763
# Epoch = 560, loss2 = 0.4482, accuracy=0.7793
# Epoch = 570, loss2 = 0.4575, accuracy=0.7695
# Epoch = 580, loss2 = 0.4481, accuracy=0.7781
# Epoch = 590, loss2 = 0.4464, accuracy=0.7783
# Epoch = 600, loss2 = 0.4456, accuracy=0.7792
# Epoch = 610, loss2 = 0.4434, accuracy=0.7771
# Epoch = 620, loss2 = 0.4387, accuracy=0.7831
# Epoch = 630, loss2 = 0.4485, accuracy=0.7772
# Epoch = 640, loss2 = 0.4698, accuracy=0.7607
# Epoch = 650, loss2 = 0.4419, accuracy=0.7831
# Epoch = 660, loss2 = 0.4418, accuracy=0.7838
# Epoch = 670, loss2 = 0.4416, accuracy=0.7800
# Epoch = 680, loss2 = 0.4386, accuracy=0.7867
# Epoch = 690, loss2 = 0.4407, accuracy=0.7828
# Epoch = 700, loss2 = 0.4373, accuracy=0.7861
# Epoch = 710, loss2 = 0.4543, accuracy=0.7721
# Epoch = 720, loss2 = 0.4431, accuracy=0.7790
# Epoch = 730, loss2 = 0.4377, accuracy=0.7847
# Epoch = 740, loss2 = 0.4419, accuracy=0.7808
# Epoch = 750, loss2 = 0.4449, accuracy=0.7760
# Epoch = 760, loss2 = 0.4401, accuracy=0.7818
# Epoch = 770, loss2 = 0.4368, accuracy=0.7854
# Epoch = 780, loss2 = 0.4363, accuracy=0.7839
# Epoch = 790, loss2 = 0.4454, accuracy=0.7783
# Epoch = 800, loss2 = 0.4365, accuracy=0.7832
# Epoch = 810, loss2 = 0.4352, accuracy=0.7853
# Epoch = 820, loss2 = 0.4365, accuracy=0.7821
# Epoch = 830, loss2 = 0.4357, accuracy=0.7840
# Epoch = 840, loss2 = 0.4378, accuracy=0.7824
# Epoch = 850, loss2 = 0.4400, accuracy=0.7821
# Epoch = 860, loss2 = 0.4342, accuracy=0.7878
# Epoch = 870, loss2 = 0.4469, accuracy=0.7768
# Epoch = 880, loss2 = 0.4452, accuracy=0.7765
# Epoch = 890, loss2 = 0.4527, accuracy=0.7734
# Epoch = 900, loss2 = 0.4484, accuracy=0.7768
# Epoch = 910, loss2 = 0.4369, accuracy=0.7831
# Epoch = 920, loss2 = 0.4332, accuracy=0.7875
# Epoch = 930, loss2 = 0.4331, accuracy=0.7850
# Epoch = 940, loss2 = 0.4311, accuracy=0.7881
# Epoch = 950, loss2 = 0.4365, accuracy=0.7847
# Epoch = 960, loss2 = 0.4327, accuracy=0.7903
# Epoch = 970, loss2 = 0.4484, accuracy=0.7739
# Epoch = 980, loss2 = 0.4494, accuracy=0.7752
# Epoch = 990, loss2 = 0.4456, accuracy=0.7757
# Epoch = 1000, loss2 = 0.4342, accuracy=0.7850
# Epoch = 1010, loss2 = 0.4327, accuracy=0.7890
# Epoch = 1020, loss2 = 0.4323, accuracy=0.7896
# Epoch = 1030, loss2 = 0.4303, accuracy=0.7923
# Epoch = 1040, loss2 = 0.4315, accuracy=0.7876
# Epoch = 1050, loss2 = 0.4350, accuracy=0.7849
# Epoch = 1060, loss2 = 0.4416, accuracy=0.7781
# Epoch = 1070, loss2 = 0.4376, accuracy=0.7844
# Epoch = 1080, loss2 = 0.4383, accuracy=0.7801
# Epoch = 1090, loss2 = 0.4358, accuracy=0.7849
# Epoch = 1100, loss2 = 0.4333, accuracy=0.7854
# Epoch = 1110, loss2 = 0.4297, accuracy=0.7897
# Epoch = 1120, loss2 = 0.4375, accuracy=0.7821
# Epoch = 1130, loss2 = 0.4294, accuracy=0.7882
# Epoch = 1140, loss2 = 0.4344, accuracy=0.7840
# Epoch = 1150, loss2 = 0.4638, accuracy=0.7627
# Epoch = 1160, loss2 = 1.4408, accuracy=0.6611
# Epoch = 1170, loss2 = 0.8943, accuracy=0.6177
# Epoch = 1180, loss2 = 0.7908, accuracy=0.7038
# Epoch = 1190, loss2 = 0.7606, accuracy=0.7101
# Epoch = 1200, loss2 = 0.7501, accuracy=0.7175
# Epoch = 1210, loss2 = 0.6924, accuracy=0.7241
# Epoch = 1220, loss2 = 0.6599, accuracy=0.7257
# Epoch = 1230, loss2 = 0.6536, accuracy=0.7275
# Epoch = 1240, loss2 = 0.6492, accuracy=0.7318
# Epoch = 1250, loss2 = 0.6469, accuracy=0.7308
# Epoch = 1260, loss2 = 0.6443, accuracy=0.7325
# Epoch = 1270, loss2 = 0.6412, accuracy=0.7329
# Epoch = 1280, loss2 = 0.6389, accuracy=0.7347
# Epoch = 1290, loss2 = 0.6368, accuracy=0.7379
# Epoch = 1300, loss2 = 0.6354, accuracy=0.7401
# Epoch = 1310, loss2 = 0.6342, accuracy=0.7381
# Epoch = 1320, loss2 = 0.6326, accuracy=0.7401
# Epoch = 1330, loss2 = 0.6310, accuracy=0.7390
# Epoch = 1340, loss2 = 0.6298, accuracy=0.7391
# Epoch = 1350, loss2 = 0.6287, accuracy=0.7430
# Epoch = 1360, loss2 = 0.6305, accuracy=0.7424
# Epoch = 1370, loss2 = 0.6266, accuracy=0.7412
# Epoch = 1380, loss2 = 0.6256, accuracy=0.7430
# Epoch = 1390, loss2 = 0.6249, accuracy=0.7449
# Epoch = 1400, loss2 = 0.6252, accuracy=0.7449
# Epoch = 1410, loss2 = 0.6237, accuracy=0.7459
# Epoch = 1420, loss2 = 0.6241, accuracy=0.7470
# Epoch = 1430, loss2 = 0.6224, accuracy=0.7481
# Epoch = 1440, loss2 = 0.6215, accuracy=0.7469
#
#
# Epoch = 0, loss3 = 0.1830, accuracy=0.9098
# Epoch = 10, loss3 = 0.1896, accuracy=0.9055
# Epoch = 20, loss3 = 0.1797, accuracy=0.9118
# Epoch = 30, loss3 = 0.1830, accuracy=0.9101
# Epoch = 40, loss3 = 0.1908, accuracy=0.9044
# Epoch = 50, loss3 = 0.1769, accuracy=0.9160
# Epoch = 60, loss3 = 0.1761, accuracy=0.9150
# Epoch = 70, loss3 = 0.1710, accuracy=0.9197
# Epoch = 80, loss3 = 0.1868, accuracy=0.9075
# Epoch = 90, loss3 = 0.1716, accuracy=0.9191
# Epoch = 100, loss3 = 0.1712, accuracy=0.9184
# Epoch = 110, loss3 = 0.1793, accuracy=0.9113
# Epoch = 120, loss3 = 0.1859, accuracy=0.9079
# Epoch = 130, loss3 = 0.1791, accuracy=0.9116
# Epoch = 140, loss3 = 0.1770, accuracy=0.9142
# Epoch = 150, loss3 = 0.1884, accuracy=0.9054
# Epoch = 160, loss3 = 0.1811, accuracy=0.9109
# Epoch = 170, loss3 = 0.1935, accuracy=0.9027
# Epoch = 180, loss3 = 0.1803, accuracy=0.9114
# Epoch = 190, loss3 = 0.1914, accuracy=0.9039
# Epoch = 200, loss3 = 0.1770, accuracy=0.9135
# Epoch = 210, loss3 = 0.1910, accuracy=0.9039
# Epoch = 220, loss3 = 0.1721, accuracy=0.9173
# Epoch = 230, loss3 = 0.1836, accuracy=0.9084
# Epoch = 240, loss3 = 0.1686, accuracy=0.9201
# Epoch = 250, loss3 = 0.1835, accuracy=0.9085
# Epoch = 260, loss3 = 0.1693, accuracy=0.9187
# Epoch = 270, loss3 = 0.1683, accuracy=0.9207
# Epoch = 280, loss3 = 0.1671, accuracy=0.9212
# Epoch = 290, loss3 = 0.2364, accuracy=0.8889
# Epoch = 300, loss3 = 0.1786, accuracy=0.9118
# Epoch = 310, loss3 = 0.1783, accuracy=0.9106
# Epoch = 320, loss3 = 0.1723, accuracy=0.9163
# Epoch = 330, loss3 = 0.1798, accuracy=0.9100
# Epoch = 340, loss3 = 0.1780, accuracy=0.9136
# Epoch = 350, loss3 = 0.1670, accuracy=0.9212
# Epoch = 360, loss3 = 0.1727, accuracy=0.9161
# Epoch = 370, loss3 = 0.1813, accuracy=0.9090
# Epoch = 380, loss3 = 0.1795, accuracy=0.9107
# Epoch = 390, loss3 = 0.1812, accuracy=0.9092
# Epoch = 400, loss3 = 0.1795, accuracy=0.9107
# Epoch = 410, loss3 = 0.1810, accuracy=0.9091
# Epoch = 420, loss3 = 0.1793, accuracy=0.9108
# Epoch = 430, loss3 = 0.1797, accuracy=0.9096
# Epoch = 440, loss3 = 0.1783, accuracy=0.9112
# Epoch = 450, loss3 = 0.1799, accuracy=0.9096
# Epoch = 460, loss3 = 0.1789, accuracy=0.9109
# Epoch = 470, loss3 = 0.1814, accuracy=0.9087
# Epoch = 480, loss3 = 0.1796, accuracy=0.9104
# Epoch = 490, loss3 = 0.1812, accuracy=0.9088
# Epoch = 500, loss3 = 0.1800, accuracy=0.9098
# Epoch = 510, loss3 = 0.1822, accuracy=0.9081
# Epoch = 520, loss3 = 0.1811, accuracy=0.9092
# Epoch = 530, loss3 = 0.1812, accuracy=0.9087
# Epoch = 540, loss3 = 0.1820, accuracy=0.9086
# Epoch = 550, loss3 = 0.1801, accuracy=0.9095
# Epoch = 560, loss3 = 0.1820, accuracy=0.9087
# Epoch = 570, loss3 = 0.1755, accuracy=0.9123
# Epoch = 580, loss3 = 0.1793, accuracy=0.9102
# Epoch = 590, loss3 = 0.1732, accuracy=0.9138
# Epoch = 600, loss3 = 0.1746, accuracy=0.9139
# Epoch = 610, loss3 = 0.1691, accuracy=0.9167
# Epoch = 620, loss3 = 0.1774, accuracy=0.9119
# Epoch = 630, loss3 = 0.1621, accuracy=0.9232
# Epoch = 640, loss3 = 0.1625, accuracy=0.9230
# Epoch = 650, loss3 = 0.1616, accuracy=0.9236
#
#
# Epoch = 0, loss1 = 7.8823, accuracy=0.8242
# Epoch = 10, loss1 = 7.8833, accuracy=0.8236
# Epoch = 20, loss1 = 7.8798, accuracy=0.8259
# Epoch = 30, loss1 = 7.8771, accuracy=0.8289
# Epoch = 40, loss1 = 7.8880, accuracy=0.8234
# Epoch = 50, loss1 = 7.8851, accuracy=0.8250
# Epoch = 60, loss1 = 7.8808, accuracy=0.8267
# Epoch = 70, loss1 = 7.8781, accuracy=0.8282
# Epoch = 80, loss1 = 7.8765, accuracy=0.8273
# Epoch = 90, loss1 = 7.8749, accuracy=0.8290
# Epoch = 100, loss1 = 7.8828, accuracy=0.8247
# Epoch = 110, loss1 = 7.8774, accuracy=0.8279
# Epoch = 120, loss1 = 7.8734, accuracy=0.8291
# Epoch = 130, loss1 = 7.8785, accuracy=0.8262
# Epoch = 140, loss1 = 7.8798, accuracy=0.8289
# Epoch = 150, loss1 = 7.8740, accuracy=0.8294
# Epoch = 160, loss1 = 7.8773, accuracy=0.8279
# Epoch = 170, loss1 = 7.8754, accuracy=0.8296
# Epoch = 180, loss1 = 7.8731, accuracy=0.8288
# Epoch = 190, loss1 = 7.8746, accuracy=0.8281
# Epoch = 200, loss1 = 7.8715, accuracy=0.8310
# Epoch = 210, loss1 = 7.8710, accuracy=0.8314
# Epoch = 220, loss1 = 7.8736, accuracy=0.8285
# Epoch = 230, loss1 = 7.8776, accuracy=0.8267
# Epoch = 240, loss1 = 7.8812, accuracy=0.8244
# Epoch = 250, loss1 = 7.8763, accuracy=0.8273
# Epoch = 260, loss1 = 7.8708, accuracy=0.8316
# Epoch = 270, loss1 = 7.8712, accuracy=0.8309
# Epoch = 280, loss1 = 7.8700, accuracy=0.8317
# Epoch = 290, loss1 = 7.8723, accuracy=0.8310
# Epoch = 300, loss1 = 7.8770, accuracy=0.8276
# Epoch = 310, loss1 = 7.8823, accuracy=0.8247
# Epoch = 320, loss1 = 7.8708, accuracy=0.8299
# Epoch = 330, loss1 = 7.8808, accuracy=0.8246
# Epoch = 340, loss1 = 7.8710, accuracy=0.8300
# Epoch = 350, loss1 = 7.8685, accuracy=0.8321
# Epoch = 360, loss1 = 7.8703, accuracy=0.8325
# ...
# Epoch = 1140, loss2 = 0.6326, accuracy=0.8151
# Epoch = 1150, loss2 = 0.6289, accuracy=0.8212
# Epoch = 1160, loss2 = 0.6197, accuracy=0.8235
# Epoch = 1170, loss2 = 0.6115, accuracy=0.8307
# Epoch = 1180, loss2 = 0.6111, accuracy=0.8302
# Epoch = 1190, loss2 = 0.6213, accuracy=0.8228
# Epoch = 1200, loss2 = 0.6099, accuracy=0.8307
# Epoch = 1210, loss2 = 0.6246, accuracy=0.8246
# Epoch = 1220, loss2 = 0.6185, accuracy=0.8242
# Epoch = 1230, loss2 = 0.6091, accuracy=0.8305
# Epoch = 1240, loss2 = 0.6165, accuracy=0.8283
# Epoch = 1250, loss2 = 0.6322, accuracy=0.8129
# Epoch = 1260, loss2 = 0.6305, accuracy=0.8202
# Epoch = 1270, loss2 = 0.6272, accuracy=0.8173
# Epoch = 1280, loss2 = 0.6209, accuracy=0.8266
# Epoch = 1290, loss2 = 0.6145, accuracy=0.8249
# Epoch = 1300, loss2 = 0.6080, accuracy=0.8295
# Epoch = 1310, loss2 = 0.6142, accuracy=0.8298
# Epoch = 1320, loss2 = 0.6087, accuracy=0.8307
# Epoch = 1330, loss2 = 0.6135, accuracy=0.8298
# Epoch = 1340, loss2 = 0.6126, accuracy=0.8299
# Epoch = 1350, loss2 = 0.6141, accuracy=0.8262
# Epoch = 1360, loss2 = 0.6097, accuracy=0.8316
# Epoch = 1370, loss2 = 0.6091, accuracy=0.8301
# Epoch = 1380, loss2 = 0.6117, accuracy=0.8301
# Epoch = 1390, loss2 = 0.6071, accuracy=0.8298
# Epoch = 1400, loss2 = 0.6214, accuracy=0.8223
# Epoch = 1410, loss2 = 0.6078, accuracy=0.8303
# Epoch = 1420, loss2 = 0.6237, accuracy=0.8223
# Epoch = 1430, loss2 = 0.6106, accuracy=0.8269
# Epoch = 1440, loss2 = 0.6095, accuracy=0.8284
#
#
# Epoch = 0, loss3 = 0.2835, accuracy=0.8738
# Epoch = 10, loss3 = 0.2797, accuracy=0.8750
# Epoch = 20, loss3 = 0.2768, accuracy=0.8763
# Epoch = 30, loss3 = 0.2752, accuracy=0.8784
# Epoch = 40, loss3 = 0.2955, accuracy=0.8620
# Epoch = 50, loss3 = 0.2788, accuracy=0.8749
# Epoch = 60, loss3 = 0.2712, accuracy=0.8802
# Epoch = 70, loss3 = 0.2707, accuracy=0.8785
# Epoch = 80, loss3 = 0.2699, accuracy=0.8814
# Epoch = 90, loss3 = 0.2725, accuracy=0.8789
# Epoch = 100, loss3 = 0.2651, accuracy=0.8828
# Epoch = 110, loss3 = 0.2648, accuracy=0.8807
# Epoch = 120, loss3 = 0.2780, accuracy=0.8748
# Epoch = 130, loss3 = 0.2649, accuracy=0.8806
# Epoch = 140, loss3 = 0.2652, accuracy=0.8825
# Epoch = 150, loss3 = 0.2616, accuracy=0.8820
# Epoch = 160, loss3 = 0.2598, accuracy=0.8855
# Epoch = 170, loss3 = 0.2586, accuracy=0.8859
# Epoch = 180, loss3 = 0.2638, accuracy=0.8828
# Epoch = 190, loss3 = 0.2551, accuracy=0.8873
# Epoch = 200, loss3 = 0.2639, accuracy=0.8807
# Epoch = 210, loss3 = 0.2527, accuracy=0.8873
# Epoch = 220, loss3 = 0.2604, accuracy=0.8838
# Epoch = 230, loss3 = 0.2507, accuracy=0.8884
# Epoch = 240, loss3 = 0.2542, accuracy=0.8853
# Epoch = 250, loss3 = 0.2528, accuracy=0.8880
# Epoch = 260, loss3 = 0.2534, accuracy=0.8873
# Epoch = 270, loss3 = 0.2534, accuracy=0.8854
# Epoch = 280, loss3 = 0.2492, accuracy=0.8877
# Epoch = 290, loss3 = 0.2472, accuracy=0.8899
# Epoch = 300, loss3 = 0.2605, accuracy=0.8810
# Epoch = 310, loss3 = 0.2567, accuracy=0.8832
# Epoch = 320, loss3 = 0.2493, accuracy=0.8887
# Epoch = 330, loss3 = 0.2424, accuracy=0.8919
# Epoch = 340, loss3 = 0.2450, accuracy=0.8894
# Epoch = 350, loss3 = 0.2487, accuracy=0.8877
# Epoch = 360, loss3 = 0.2480, accuracy=0.8888
# Epoch = 370, loss3 = 0.2489, accuracy=0.8868
# Epoch = 380, loss3 = 0.2380, accuracy=0.8942
# Epoch = 390, loss3 = 0.2494, accuracy=0.8868
# Epoch = 400, loss3 = 0.2369, accuracy=0.8941
# Epoch = 410, loss3 = 0.2399, accuracy=0.8910
# Epoch = 420, loss3 = 0.2411, accuracy=0.8920
# Epoch = 430, loss3 = 0.2382, accuracy=0.8932
# Epoch = 440, loss3 = 0.2443, accuracy=0.8888
# Epoch = 450, loss3 = 0.2340, accuracy=0.8948
# Epoch = 460, loss3 = 0.2359, accuracy=0.8944
# Epoch = 470, loss3 = 0.2395, accuracy=0.8915
# Epoch = 480, loss3 = 0.2333, accuracy=0.8948
# Epoch = 490, loss3 = 0.2314, accuracy=0.8962
# Epoch = 500, loss3 = 0.2318, accuracy=0.8951
# Epoch = 510, loss3 = 0.2343, accuracy=0.8944
# Epoch = 520, loss3 = 0.2315, accuracy=0.8945
# Epoch = 530, loss3 = 0.2405, accuracy=0.8905
# Epoch = 540, loss3 = 0.2310, accuracy=0.8956
# Epoch = 550, loss3 = 0.2366, accuracy=0.8926
# Epoch = 560, loss3 = 0.2302, accuracy=0.8947
# Epoch = 570, loss3 = 0.2381, accuracy=0.8912
# Epoch = 580, loss3 = 0.2306, accuracy=0.8960
# Epoch = 590, loss3 = 0.2312, accuracy=0.8955
# Epoch = 600, loss3 = 0.2288, accuracy=0.8952
# Epoch = 610, loss3 = 0.2348, accuracy=0.8923
# Epoch = 620, loss3 = 0.2347, accuracy=0.8927
# Epoch = 630, loss3 = 0.2227, accuracy=0.9007
# Epoch = 640, loss3 = 0.2372, accuracy=0.8910
# Epoch = 650, loss3 = 0.2224, accuracy=0.9001
#
#
# Epoch = 0, loss1 = 7.8259, accuracy=0.8512
# Epoch = 10, loss1 = 7.8314, accuracy=0.8482
# Epoch = 20, loss1 = 7.8535, accuracy=0.8372
# Epoch = 30, loss1 = 7.8697, accuracy=0.8292
# Epoch = 40, loss1 = 7.8564, accuracy=0.8362
# Epoch = 50, loss1 = 7.8577, accuracy=0.8362
# Epoch = 60, loss1 = 7.8338, accuracy=0.8476
# Epoch = 70, loss1 = 7.8314, accuracy=0.8481
# Epoch = 80, loss1 = 7.8268, accuracy=0.8509
# Epoch = 90, loss1 = 7.8250, accuracy=0.8513
# Epoch = 100, loss1 = 7.8236, accuracy=0.8527
# Epoch = 110, loss1 = 7.8236, accuracy=0.8524
# Epoch = 120, loss1 = 7.8275, accuracy=0.8502
# Epoch = 130, loss1 = 7.8427, accuracy=0.8415
# Epoch = 140, loss1 = 7.8449, accuracy=0.8397
# Epoch = 150, loss1 = 7.8369, accuracy=0.8450
# Epoch = 160, loss1 = 7.8309, accuracy=0.8480
# Epoch = 170, loss1 = 7.8285, accuracy=0.8494
# Epoch = 180, loss1 = 7.8232, accuracy=0.8525
# Epoch = 190, loss1 = 7.8300, accuracy=0.8496
# Epoch = 200, loss1 = 7.8350, accuracy=0.8480
# Epoch = 210, loss1 = 7.8337, accuracy=0.8476
# Epoch = 220, loss1 = 7.8291, accuracy=0.8498
# Epoch = 230, loss1 = 7.8262, accuracy=0.8518
# Epoch = 240, loss1 = 7.8261, accuracy=0.8519
# Epoch = 250, loss1 = 7.8296, accuracy=0.8501
# Epoch = 260, loss1 = 7.8297, accuracy=0.8492
# Epoch = 270, loss1 = 7.8267, accuracy=0.8506
# Epoch = 280, loss1 = 7.8237, accuracy=0.8520
# Epoch = 290, loss1 = 7.8294, accuracy=0.8498
# Epoch = 300, loss1 = 7.8285, accuracy=0.8503
# Epoch = 310, loss1 = 7.8221, accuracy=0.8532
# Epoch = 320, loss1 = 7.8212, accuracy=0.8537
# Epoch = 330, loss1 = 7.8185, accuracy=0.8551
# Epoch = 340, loss1 = 7.8198, accuracy=0.8541
# Epoch = 350, loss1 = 7.8499, accuracy=0.8384
# Epoch = 360, loss1 = 7.8635, accuracy=0.8406
# Epoch = 370, loss1 = 7.8336, accuracy=0.8481
# Epoch = 380, loss1 = 7.8257, accuracy=0.8512
# Epoch = 390, loss1 = 7.8211, accuracy=0.8533
# Epoch = 400, loss1 = 7.8190, accuracy=0.8550
# Epoch = 410, loss1 = 7.8180, accuracy=0.8551
# Epoch = 420, loss1 = 7.8174, accuracy=0.8554
# Epoch = 430, loss1 = 7.8238, accuracy=0.8520
# Epoch = 440, loss1 = 7.8433, accuracy=0.8402
# Epoch = 450, loss1 = 7.8252, accuracy=0.8507
#
#
# Epoch = 0, loss2 = 0.6076, accuracy=0.8294
# Epoch = 10, loss2 = 0.6141, accuracy=0.8267
# Epoch = 20, loss2 = 0.6205, accuracy=0.8260
# Epoch = 30, loss2 = 0.6202, accuracy=0.8230
# Epoch = 40, loss2 = 0.6123, accuracy=0.8299
# Epoch = 50, loss2 = 0.6060, accuracy=0.8299
# Epoch = 60, loss2 = 0.6074, accuracy=0.8307
# Epoch = 70, loss2 = 0.6171, accuracy=0.8285
# Epoch = 80, loss2 = 0.6177, accuracy=0.8252
# Epoch = 90, loss2 = 0.6078, accuracy=0.8331
# Epoch = 100, loss2 = 0.6074, accuracy=0.8301
# Epoch = 110, loss2 = 0.6181, accuracy=0.8249
# Epoch = 120, loss2 = 0.6052, accuracy=0.8303
# Epoch = 130, loss2 = 0.6175, accuracy=0.8269
# Epoch = 140, loss2 = 0.6055, accuracy=0.8306
# Epoch = 150, loss2 = 0.6093, accuracy=0.8289
# Epoch = 160, loss2 = 0.6148, accuracy=0.8281
# Epoch = 170, loss2 = 0.6173, accuracy=0.8258
# Epoch = 180, loss2 = 0.6115, accuracy=0.8316
# Epoch = 190, loss2 = 0.6042, accuracy=0.8321
# Epoch = 200, loss2 = 0.6137, accuracy=0.8267
# Epoch = 210, loss2 = 0.6037, accuracy=0.8307
# Epoch = 220, loss2 = 0.6164, accuracy=0.8285
# Epoch = 230, loss2 = 0.6123, accuracy=0.8273
# Epoch = 240, loss2 = 0.6045, accuracy=0.8332
# Epoch = 250, loss2 = 0.6129, accuracy=0.8324
# Epoch = 260, loss2 = 0.6176, accuracy=0.8228
# Epoch = 270, loss2 = 0.6129, accuracy=0.8312
# Epoch = 280, loss2 = 0.6085, accuracy=0.8301
# Epoch = 290, loss2 = 0.6072, accuracy=0.8337
# Epoch = 300, loss2 = 0.6113, accuracy=0.8278
# Epoch = 310, loss2 = 0.6041, accuracy=0.8338
# Epoch = 320, loss2 = 0.6070, accuracy=0.8346
# Epoch = 330, loss2 = 0.6094, accuracy=0.8289
# Epoch = 340, loss2 = 0.6035, accuracy=0.8313
# Epoch = 350, loss2 = 0.6191, accuracy=0.8271
# Epoch = 360, loss2 = 0.6161, accuracy=0.8244
# Epoch = 370, loss2 = 0.6048, accuracy=0.8321
# Epoch = 380, loss2 = 0.6028, accuracy=0.8342
# Epoch = 390, loss2 = 0.6232, accuracy=0.8181
# Epoch = 400, loss2 = 0.6130, accuracy=0.8302
# Epoch = 410, loss2 = 0.6117, accuracy=0.8280
# Epoch = 420, loss2 = 0.6109, accuracy=0.8316
# Epoch = 430, loss2 = 0.6110, accuracy=0.8277
# Epoch = 440, loss2 = 0.6089, accuracy=0.8337
# Epoch = 450, loss2 = 0.6043, accuracy=0.8325
# Epoch = 460, loss2 = 0.6011, accuracy=0.8323
# Epoch = 470, loss2 = 0.6062, accuracy=0.8346
# Epoch = 480, loss2 = 0.6003, accuracy=0.8337
# Epoch = 490, loss2 = 0.6138, accuracy=0.8273
# Epoch = 500, loss2 = 1.6851, accuracy=0.7643
# Epoch = 510, loss2 = 1.2121, accuracy=0.7858
# Epoch = 520, loss2 = 0.8128, accuracy=0.8011
# Epoch = 530, loss2 = 0.9182, accuracy=0.7616
# Epoch = 540, loss2 = 0.8104, accuracy=0.7925
# Epoch = 550, loss2 = 0.7179, accuracy=0.8206
# Epoch = 560, loss2 = 0.6739, accuracy=0.8118
# Epoch = 570, loss2 = 0.6540, accuracy=0.8224
# Epoch = 580, loss2 = 0.6462, accuracy=0.8262
# Epoch = 590, loss2 = 0.6440, accuracy=0.8276
# Epoch = 600, loss2 = 0.6419, accuracy=0.8280
# Epoch = 610, loss2 = 0.6408, accuracy=0.8285
# Epoch = 620, loss2 = 0.6400, accuracy=0.8285
# Epoch = 630, loss2 = 0.6401, accuracy=0.8294
# Epoch = 640, loss2 = 0.6399, accuracy=0.8277
# Epoch = 650, loss2 = 0.6391, accuracy=0.8299
# Epoch = 660, loss2 = 0.6443, accuracy=0.8260
# Epoch = 670, loss2 = 0.6369, accuracy=0.8299
# Epoch = 680, loss2 = 0.6470, accuracy=0.8258
# Epoch = 690, loss2 = 0.6369, accuracy=0.8302
# Epoch = 700, loss2 = 0.6376, accuracy=0.8294
# Epoch = 710, loss2 = 0.6447, accuracy=0.8267
# Epoch = 720, loss2 = 0.6500, accuracy=0.8240
# Epoch = 730, loss2 = 0.6482, accuracy=0.8251
# Epoch = 740, loss2 = 0.6425, accuracy=0.8274
# Epoch = 750, loss2 = 0.6352, accuracy=0.8321
# Epoch = 760, loss2 = 0.6358, accuracy=0.8309
# Epoch = 770, loss2 = 0.6417, accuracy=0.8273
# Epoch = 780, loss2 = 0.6336, accuracy=0.8323
# Epoch = 790, loss2 = 0.6364, accuracy=0.8312
# Epoch = 800, loss2 = 0.6371, accuracy=0.8306
# Epoch = 810, loss2 = 0.6479, accuracy=0.8227
# Epoch = 820, loss2 = 0.6466, accuracy=0.8255
# Epoch = 830, loss2 = 0.6415, accuracy=0.8280
# Epoch = 840, loss2 = 0.6345, accuracy=0.8324
# Epoch = 850, loss2 = 0.6318, accuracy=0.8312
# Epoch = 860, loss2 = 0.6364, accuracy=0.8309
# Epoch = 870, loss2 = 0.6412, accuracy=0.8296
# Epoch = 880, loss2 = 0.6307, accuracy=0.8337
# Epoch = 890, loss2 = 0.6436, accuracy=0.8251
# Epoch = 900, loss2 = 0.6379, accuracy=0.8317
# Epoch = 910, loss2 = 0.6301, accuracy=0.8346
# Epoch = 920, loss2 = 0.6399, accuracy=0.8288
# Epoch = 930, loss2 = 0.6363, accuracy=0.8319
# Epoch = 940, loss2 = 0.6296, accuracy=0.8349
# Epoch = 950, loss2 = 0.6412, accuracy=0.8260
# Epoch = 960, loss2 = 0.6458, accuracy=0.8271
# Epoch = 970, loss2 = 0.6433, accuracy=0.8238
# Epoch = 980, loss2 = 0.6349, accuracy=0.8338
# Epoch = 990, loss2 = 0.6299, accuracy=0.8337
# Epoch = 1000, loss2 = 0.6311, accuracy=0.8348
# Epoch = 1010, loss2 = 0.6382, accuracy=0.8335
# Epoch = 1020, loss2 = 0.6285, accuracy=0.8328
# Epoch = 1030, loss2 = 0.6474, accuracy=0.8215
# Epoch = 1040, loss2 = 0.6336, accuracy=0.8346
# Epoch = 1050, loss2 = 0.6280, accuracy=0.8357
# Epoch = 1060, loss2 = 0.6307, accuracy=0.8355
# Epoch = 1070, loss2 = 0.6417, accuracy=0.8291
# Epoch = 1080, loss2 = 0.6331, accuracy=0.8331
# Epoch = 1090, loss2 = 0.6298, accuracy=0.8334
# Epoch = 1100, loss2 = 0.6378, accuracy=0.8331
# Epoch = 1110, loss2 = 0.6271, accuracy=0.8346
# Epoch = 1120, loss2 = 0.6422, accuracy=0.8252
# Epoch = 1130, loss2 = 0.6335, accuracy=0.8352
# Epoch = 1140, loss2 = 0.6263, accuracy=0.8363
# Epoch = 1150, loss2 = 0.6423, accuracy=0.8246
# Epoch = 1160, loss2 = 0.6330, accuracy=0.8343
# Epoch = 1170, loss2 = 0.6282, accuracy=0.8373
# Epoch = 1180, loss2 = 0.6392, accuracy=0.8269
# Epoch = 1190, loss2 = 0.6288, accuracy=0.8371
# Epoch = 1200, loss2 = 0.6331, accuracy=0.8366
# Epoch = 1210, loss2 = 0.6269, accuracy=0.8368
# Epoch = 1220, loss2 = 0.6523, accuracy=0.8154
# Epoch = 1230, loss2 = 0.6416, accuracy=0.8321
# Epoch = 1240, loss2 = 0.6361, accuracy=0.8285
# Epoch = 1250, loss2 = 0.6347, accuracy=0.8346
# Epoch = 1260, loss2 = 0.6311, accuracy=0.8343
# Epoch = 1270, loss2 = 0.6268, accuracy=0.8359
# Epoch = 1280, loss2 = 0.6255, accuracy=0.8362
# Epoch = 1290, loss2 = 0.6335, accuracy=0.8309
# Epoch = 1300, loss2 = 0.6261, accuracy=0.8360
# Epoch = 1310, loss2 = 0.6364, accuracy=0.8324
# Epoch = 1320, loss2 = 0.6237, accuracy=0.8374
# Epoch = 1330, loss2 = 0.6318, accuracy=0.8324
# Epoch = 1340, loss2 = 0.6110, accuracy=0.8370
# Epoch = 1350, loss2 = 0.6121, accuracy=0.8373
# Epoch = 1360, loss2 = 0.6197, accuracy=0.8362
# Epoch = 1370, loss2 = 0.6244, accuracy=0.8262
# Epoch = 1380, loss2 = 0.6169, accuracy=0.8377
# Epoch = 1390, loss2 = 0.6153, accuracy=0.8342
# Epoch = 1400, loss2 = 0.6122, accuracy=0.8380
# Epoch = 1410, loss2 = 0.6101, accuracy=0.8373
# Epoch = 1420, loss2 = 0.6086, accuracy=0.8380
# Epoch = 1430, loss2 = 0.6363, accuracy=0.8174
# Epoch = 1440, loss2 = 0.6353, accuracy=0.8271
#
#
# Epoch = 0, loss3 = 0.2220, accuracy=0.9003
# Epoch = 10, loss3 = 0.2321, accuracy=0.8933
# Epoch = 20, loss3 = 0.2201, accuracy=0.9013
# Epoch = 30, loss3 = 0.2327, accuracy=0.8930
# Epoch = 40, loss3 = 0.2211, accuracy=0.8998
# Epoch = 50, loss3 = 0.2193, accuracy=0.9020
# Epoch = 60, loss3 = 0.2197, accuracy=0.9009
# Epoch = 70, loss3 = 0.2285, accuracy=0.8949
# Epoch = 80, loss3 = 0.2181, accuracy=0.9015
# Epoch = 90, loss3 = 0.2250, accuracy=0.8976
# Epoch = 100, loss3 = 0.2177, accuracy=0.9023
# Epoch = 110, loss3 = 0.2234, accuracy=0.8969
# Epoch = 120, loss3 = 0.2247, accuracy=0.8975
# Epoch = 130, loss3 = 0.2172, accuracy=0.9019
# Epoch = 140, loss3 = 0.2225, accuracy=0.8965
# Epoch = 150, loss3 = 0.2174, accuracy=0.9006
# Epoch = 160, loss3 = 0.2246, accuracy=0.8968
# Epoch = 170, loss3 = 0.2187, accuracy=0.8989
# Epoch = 180, loss3 = 0.2224, accuracy=0.8969
# Epoch = 190, loss3 = 0.2202, accuracy=0.8995
# Epoch = 200, loss3 = 0.2169, accuracy=0.9011
# Epoch = 210, loss3 = 0.2234, accuracy=0.8960
# Epoch = 220, loss3 = 0.2134, accuracy=0.9028
# Epoch = 230, loss3 = 0.2235, accuracy=0.8965
# Epoch = 240, loss3 = 0.2114, accuracy=0.9051
# Epoch = 250, loss3 = 0.2267, accuracy=0.8945
# Epoch = 260, loss3 = 0.2105, accuracy=0.9058
# Epoch = 270, loss3 = 0.2301, accuracy=0.8902
# Epoch = 280, loss3 = 0.2142, accuracy=0.9008
# Epoch = 290, loss3 = 0.2098, accuracy=0.9048
# Epoch = 300, loss3 = 0.2231, accuracy=0.8959
# Epoch = 310, loss3 = 0.2088, accuracy=0.9058
# Epoch = 320, loss3 = 0.2297, accuracy=0.8933
# Epoch = 330, loss3 = 0.2103, accuracy=0.9044
# Epoch = 340, loss3 = 0.2151, accuracy=0.9017
# Epoch = 350, loss3 = 0.2101, accuracy=0.9032
# Epoch = 360, loss3 = 0.2298, accuracy=0.8934
# Epoch = 370, loss3 = 0.2229, accuracy=0.8951
# Epoch = 380, loss3 = 0.2120, accuracy=0.9016
# Epoch = 390, loss3 = 0.2125, accuracy=0.9011
# Epoch = 400, loss3 = 0.2096, accuracy=0.9043
# Epoch = 410, loss3 = 0.2174, accuracy=0.8995
# Epoch = 420, loss3 = 0.2218, accuracy=0.8964
# Epoch = 430, loss3 = 0.2113, accuracy=0.9033
# Epoch = 440, loss3 = 0.2097, accuracy=0.9040
# Epoch = 450, loss3 = 0.2098, accuracy=0.9025
# Epoch = 460, loss3 = 0.2115, accuracy=0.9017
# Epoch = 470, loss3 = 0.2174, accuracy=0.8981
# Epoch = 480, loss3 = 0.2087, accuracy=0.9029
# Epoch = 490, loss3 = 0.2119, accuracy=0.9015
# Epoch = 500, loss3 = 0.2087, accuracy=0.9047
# Epoch = 510, loss3 = 0.2092, accuracy=0.9043
# Epoch = 520, loss3 = 0.2181, accuracy=0.8978
# Epoch = 530, loss3 = 0.2024, accuracy=0.9087
# Epoch = 540, loss3 = 0.2210, accuracy=0.8940
# Epoch = 550, loss3 = 0.2055, accuracy=0.9045
# Epoch = 560, loss3 = 0.2020, accuracy=0.9074
# Epoch = 570, loss3 = 0.2151, accuracy=0.8988
# Epoch = 580, loss3 = 0.2012, accuracy=0.9081
# Epoch = 590, loss3 = 0.2266, accuracy=0.8939
# Epoch = 600, loss3 = 0.2070, accuracy=0.9052
# Epoch = 610, loss3 = 0.2005, accuracy=0.9090
# Epoch = 620, loss3 = 0.2176, accuracy=0.8978
# Epoch = 630, loss3 = 0.2001, accuracy=0.9091
# Epoch = 640, loss3 = 0.2189, accuracy=0.8946
# Epoch = 650, loss3 = 0.2036, accuracy=0.9053

# %%
avg_influences1 = [val / 10 for val in sum_influences1]
avg_influences2 = [val / 10 for val in sum_influences2]
avg_influences3 = [val / 10 for val in sum_influences3]

# %%
# Creating a dictionary of average influence scores with index
result1 = {idx: val for idx, val in enumerate(avg_influences1)}
print(list(result1.items())[:])
result2 = {idx: val for idx, val in enumerate(avg_influences2)}
print(list(result2.items())[:])
result3 = {idx: val for idx, val in enumerate(avg_influences3)}
print(list(result3.items())[:])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(avg_influences1)
print(avg_influences2)
print(avg_influences3)
# Out:
# [0.00019227558521135634, -0.012497829727915372, 0.09543006877618078, 0.0, 0.0006304936444511982, 0.0, -0.00024014016707007082, -0.0009023703283396372, 0.0, 0.11712168349990688, -0.0002651824654001999, 0.0, 0.041937662858905454, 4.430858372436635e-05, -0.08322427955901754, 0.00018865469552137624, 0.015040886648139013, 0.0001003354731701401, -0.0010725801434288708, -0.06708982129166341, 0.0, 1.6033748559695452e-06, -0.0007481256201348292, -0.007826059864506926, -0.03790655145719825, 0.0, 0.0028783670049184517, -0.0019087924641739372, -0.012021497896269741, 0.0009162227732388567, 0.03881462761773852, -0.0051059069540833925, -1.0368220083458447e-05, -0.00032153746933271396, -0.024652668086965375, 0.08683368866847421, -0.005241937839778508, 0.0007471747803643395, -3.474413391418518e-05, 0.13310434840966812, 0.0015425390418385906, 0.0, 4.358306877354e-05, 0.008569176676535851, 7.720424551921775e-06, 0.00018016222943930305, 0.0, 0.0, 0.0012775889078466018, -0.00018704488529546566, 0.0297654145594299, 0.0, 0.0, -0.038205231333117796, -0.044351556285647534, 0.003395212446446933, 0.008518223344185654, 0.0005547750358313437, -0.012280548753530952, 0.0, 1.617868715866819e-05, 0.0019053624708795657, -0.05312215179507077, 0.0, -0.03713727998065854, 0.003909765746198317, -0.0002536640384573954, 0.0016206955862187826, -0.056992701045508555, -0.10007626728776572, -0.03378132425128081, -0.00046392912120848544, 0.01387005541900764, 0.0007295417813500194, 0.0, -0.017327540709504125, 0.0025451584633860752, 7.899141289695108e-05, 0.08111711619457322, -0.0011648223981388665, 0.01964837745132256, -0.00793162554742231, 0.0, -0.00994117990567044, 0.01073292484702867, -7.41419546922025e-05, 0.0013268633904705393, -0.003670602356785125, 0.07005022769397776, -0.00027156916961624156, 0.00039488052199571305, -0.0007280855327875967, -0.00038791666071346796, 0.012247508312072443, 0.00022204830662198838, -0.02728685952653558, 0.0, -6.260357077304356e-06, 4.186918439120299e-05, -0.0001268332494554947, -0.005919015597634277, 0.11173776901235888, 0.011519890438356687, -0.0004359375288860132, -0.00890923811823614, 0.0002946429557669688, 0.00040196926883699966, 0.2818737278794545, -0.025174413832689996, -8.889178537941351e-05, 0.0003691992427471329, 0.005168510278211908, -0.0001703166007599224, -0.00014881494115219794, 0.013539916897087601, 0.0027087103115269245, 0.09981320402939767, 0.0, 0.0021395839649746328, -0.0003960832687948058, -0.0020177935097809583, 0.01950027058485828, 0.006759503391642897, 0.03184315990829958, 0.012163016841925653, 0.0032979842404787076, -0.0003123334837455525, -0.048092083376261585, 1.5440014080445758e-05, 0.0, 0.0, 0.005434592301921072, 0.0007717815793459724, 0.006297947208565408, 0.07902420242992982, 0.0, 0.0, 0.0004650947799793228, -0.0009070899073376524, -0.002204887006307095, 0.0008474671027038855, 0.0, -0.0002756620208708198, 0.00033306965610774037, -0.0022537204140763113, 0.0, 0.02894736099054681, 0.0054659067088505455, -0.021568124750215207, 0.004901404496675763, 0.007262257609834413, 0.036643751207742534, -0.029133316448537384, 0.06177221214822741, -0.010057928556797923, 1.1383493556145392e-05, 0.009595163913544303, 0.0, 0.00021104568321528224, -0.0003666101886116692, -0.024764079312773486, 4.334882655314328e-05, 0.016199236958875676, -0.0022756916287535035, 0.020521343641207498, 0.14592981328234142, 0.0, 0.0, 0.0, -0.017462945738792902, 0.0005886346133065349, 0.005432882216064594, -0.0007539071745778869, -0.00013888949445802675, 0.0, 0.05861220442934979, 0.001418112993538445, 5.498340091147617e-05, 0.0018079864417354981, 0.0036050382408438788, 0.005129961455335323, -0.00013331123667337255, 0.19873810316460722, 0.04512879399243326, -0.013972474972242303, 0.059838657813274, -0.007799634206353705, 0.028143923742631576, 0.12013173593228377, 0.0014739786650283747, 0.005017938067921041, 0.021794776064844434, 0.050905228467987895, 0.00017809783470077367, 0.0006870821023320626, 0.0, 0.016988103735684844, -0.00037971756814703084, 0.005 ...
# [0.008550307609716224, -0.010063370777114583, 0.03076753626866947, 0.02882901716118093, 0.020690470172749203, 0.013995050635217231, 0.013866174806516671, 0.02093900686521314, -0.005767157134633593, 0.05475098204578181, 0.04949942835795863, 0.0809555947821797, 0.007555443169100172, -0.03140486748468298, 0.08537230311477345, -0.09730806366717973, 0.01606421935881889, 0.08531881560810974, 0.05419107979700468, -0.09816924875321728, 0.08209653926782623, 0.05120055299837791, 0.05146673415337925, 0.0007190218893044499, 0.05492241117173287, 0.0008632799127427752, -0.0025679222175410397, 0.019549212824501578, 0.05137673008018852, 0.021812449692349467, 0.0693847206227899, -0.048758024205425146, 0.03290691197409558, 0.015599537569997967, 0.05148879760287561, 0.054254303933463074, 0.11830484300482405, 0.008388002478336161, 0.00026118523279103356, 0.0006329993361259509, 0.01465131905624141, 0.02022028167151552, 0.1288313098196464, 0.05595268242616506, 0.11188054197198563, 0.0, 0.008710286609045558, 0.01809723567501363, 0.12660096501020035, -0.07114310102307866, 0.07970339036073408, -0.01835738714286276, 0.012372175863089188, -0.010340294796897498, 0.4725111961859154, 0.05868764611309681, -0.08043508209481305, 0.051103952543476036, -0.14638854992389536, 0.0652704039994732, 0.1774103732041101, 0.0005851198119292908, -0.13475294279408248, 0.11456943785032152, 0.0025256270941442695, -0.007837523339564518, -1.090204080194182e-05, 0.09555208638592506, 0.019116489824206096, 0.027152164979865744, 0.10896361685762317, 0.013818033830665571, 0.018978798545093926, 0.03418918368982285, 0.0460231891905011, 0.027831629003891623, 0.09347844392380195, 0.009525257136031326, 0.060498243742252655, 0.05652475005875222, -0.1546490718005778, -0.004879920546502091, -0.002436132145257906, -0.0777901675527489, 0.0, 0.031185723596260418, 0.026073692283147383, 0.04529015659039047, 0.018471358256285632, -0.021777798558715714, 0.03550914236834382, 0.08143555852813453, -0.0038864072589972903, 0.007766171152279178, -0.025625438431455698, 0.04459936100523647, 0.04296611479356666, 0.02720225721469462, 0.02783837882093812, 0.044352707318621426, -0.013020526406722802, 0.06563793762127791, 0.0025245378153424315, -0.0025875311307958547, 0.047328819178840235, 0.04937670727105518, 0.08693106772281914, 0.02094629492181132, 0.019511310230511506, 0.01910935649874553, 0.10572643813350109, 0.06020768792665469, 0.037904453183492226, -0.01426066404044526, -0.00468343017602064, 0.037447674896936706, 0.03441630826660913, 0.0, 0.06107353560661558, 0.03643124883599988, 0.015000398015991043, 0.05381471573831255, -0.002071149534991537, 0.04799925935146748, 0.0068593037781097725, 0.030060320307966355, 0.02144506071369598, 0.022726830482218158, 0.02981331470432601, -0.002559205460883301, -0.010939778103880754, 0.03402836060895726, 0.030079052569676763, 0.01056690338235437, 0.009783788458807837, -0.11668293188304686, 0.06274673435100345, 0.06208368003732968, 0.13075912067772583, 0.008741414623541058, 0.05375100729837327, 0.03605113135847477, -0.09065452297082259, 0.028618502305144632, 0.018257490217785038, 0.028464460701223278, -0.15042684087535205, 0.15750108517144476, -0.057146183951900895, 0.1255548118630349, -0.010906156263829367, 0.012785004663124128, 0.3086713740550078, 0.12157022958693553, -0.01575809299492175, 0.03039462692158242, -0.0327848079957085, -0.07125959293750775, 0.08158765867762402, 0.029752205188180454, 0.0015385718784746993, 0.031921770106301685, 0.020342547414610064, 0.022275721764917662, 0.02965755908682401, 0.11272755296796848, 0.06450492302161556, 0.06406314180435058, 0.09376096954281367, 0.031676412454019684, -0.010216602116492824, -0.022342455174361307, 0.03872460983716262, 0.037852944769060475, -0.0035657407457775265, 0.0530151797178692, 0.0531776518086672, 0.04794781228499147, 0.034745241868698123, 0.15805143961533935, 0.015382313739362241, 0.023578758785149267, 4.3930102490753556e-05, 0.05673413767619303, 0.036907621974258585, 0.08059672851916111, -0.00812325827488 ...
# [0.01748761249427331, 0.02987917678556442, -0.003409893935930394, 0.11964484839636982, 0.08742490724277084, 0.0895122259240206, 0.0961568201333483, -0.031919064536996264, 0.09416159020500123, 0.10898310099417834, -2.125532372606945e-05, -0.03596032101630732, -0.06470042900392706, -0.16854199125885935, -0.008322870118460052, -0.07657713779542621, 0.01110387212012923, 0.06112489856392075, 0.06659886636253051, 0.046849333267994994, 0.10388004582458006, 0.08039566679331007, 0.06135270128016039, 0.041131394659149036, 0.07939509509495372, 0.10179233679293238, 0.012767470242164031, 0.18902131218088578, -0.23622704851930373, 0.021665902646328422, 0.003119070634644133, 0.024974275213875193, 0.05089401996514883, 0.05329314054574015, 0.03197604962897489, 0.03395711078493903, -0.02959745158458682, 0.01634087071088551, -0.006930001893983961, 0.07853757456454973, -0.019521874179652628, -0.0008212457985866115, 0.029803162827715106, 0.0100155091791253, 0.036495195920648364, 0.009155343474183883, 0.015611085090374056, 0.03946478331358817, 0.04681974272729952, -0.061681300640856654, -0.0025214148423183653, 0.03141233297252135, -0.1578561742693024, 0.03765037156842815, -0.22588710619528413, 0.0005134668296990056, -0.056387185241223936, -0.04116454484490019, -0.013639741032484932, -0.0924250004221102, -0.03566375938371188, 0.05020120826963378, 0.014617680882664404, -0.006792172038295297, 0.00496198724503717, 0.040336940204454594, -0.05140335303167224, 0.1450100518638092, 0.014740488012655859, 0.011760601264821428, -0.038556133340560024, -0.021370542090817603, 0.06764137604217563, 0.045014607572905554, 0.12123891965969495, 0.03578323851217393, 0.014162884690598765, -0.03082068116776075, 0.032331965953067456, 0.04587521074523974, 0.021902437862682853, -0.0010365094223432157, 0.009484468332996505, 0.020207885330239383, 0.025932562335590846, 0.006249010350625551, 0.009380937650631102, 0.02415637217187806, 0.0013551627292900377, -0.029666110816396012, -0.06630507387092502, 0.09122575560928532, 0.006830497666006886, -0.012396515950614247, -0.06969657253554873, 0.08131849612895714, 0.04419603346903989, 0.07286290292181537, 0.029349436943590212, 0.04271623037595247, 0.0009543487416947043, 0.00452381895036302, 0.0374158450214362, 0.016263061951432577, -0.01700326483419946, 0.009994578514240305, 0.0729258848341515, -0.06310292615388703, 0.014932740168939779, 0.018196022647016852, 0.0499166171584901, 0.01601561410177689, -0.02372109345988687, -0.020526866662133117, 0.12157883255882554, 0.047684507962854956, 0.017802774617319543, -0.0034911945137724313, 0.00958363110150144, 0.11396600294130035, 0.04928283452158408, 0.011111238137312915, 0.022956085714052485, 0.020918629172066106, 0.003231956156893304, 0.018247644749414905, -0.002449681719735255, 0.07314053144049944, -0.0769460911752001, 0.028788658753598855, 0.004041096851098514, 0.0615930958090392, -0.026113670954169187, -0.017630172903921642, 0.01652709029925995, -0.003523017852053628, 0.002096883069509006, 0.012744608818068565, 0.0029322334665628598, -0.016634525525363215, 0.008988111751430767, -0.002750534208313283, 0.018314827125709393, 0.03028972897060454, -0.01502767056068185, -0.052342881787712806, 0.012398907415241755, 0.03228783634715965, -0.014299821392046197, -0.00925609848718825, 0.012139812744041212, 0.02219382123344702, 0.050225567330577384, -0.010773947397149104, 0.032513869744616605, 0.01731177686866655, 0.032012362895217486, 0.06235549042834008, 0.03726745638466852, 0.021589249098819423, 0.06165925263173749, 0.11632761795139934, -0.02955938506040782, 0.022957996390604144, 0.05856924219627111, -0.0062638618313320665, 0.02881183400553434, -0.004899939524598332, 0.055891324926838196, -0.037631469274531926, -0.05184457079222088, -0.11035048297861394, 0.13829169979162453, 0.016468646187017495, -0.038034536186903646, 0.008241572122390014, -0.07063565538826036, 0.042042873493878655, 0.03942212447303543, -0.028559647133697526, 0.07921203910742332, -0.12036773005463801, -0.016334519391502395, -0.008 ...

# %%
np.savez("adult_scores.npz", x = avg_influences1)

# %%
np.savez("broward_scores.npz", x = avg_influences2)

# %%
np.savez("hospital_scores.npz", x = avg_influences3)
